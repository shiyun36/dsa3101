# %%
from pdfminer.high_level import extract_text
from pdfminer.layout import LAParams

laparams = LAParams(line_margin = 0.2, boxes_flow = 0.6, detect_vertical = True, all_texts = True)

text = extract_text("2023-2024_Sustainability_Report_(ENG)_.pdf", laparams = laparams)
print(text)


# Bad method because it scrapes line by line in each page. 
# For paragraphs that are organised in chunks from left to right, pdf reader would still read from left to right, instead of reading by paragraphs

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO

def convert_pdf_to_txt(path,output_path, boxes_flow = 0.2):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams(boxes_flow=boxes_flow)
    device = TextConverter(rsrcmgr, retstr, codec=codec , laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    caching = True
    pagenos=set()

    for PageNumer,page in enumerate(PDFPage.get_pages(fp, pagenos , password=password,caching=caching, check_extractable=True)):
        interpreter.process_page(page)

    text = retstr.getvalue()

    with open(output_path, 'w', encoding='utf-8') as txt_file:
        txt_file.write(text)

    fp.close()
    device.close()
    retstr.close()
    return text

input_pdf_path = "/Users/jeremiahtay/DSA3101/LG_2023_ocr.pdf"
output_txt_path = "/Users/jeremiahtay/DSA3101/datadog_Sustainability Report.txt"

converted_file = convert_pdf_to_txt(input_pdf_path, output_txt_path)
print(converted_file)
# Out:
# 2023  —M—W—— LG Electronics Sustainability Report  ——————_  2024
#
# LIFE
# FOR ALL
#
# Lite’s
# Good.
#
# 2
#
# 2023-2024 LG Electronics Sustainability Report
#
# Environmental
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# oO  eG  <  >)
#
# Table of Contents
#
# Overview
#
# Environmental
#
# 12  =  Social
#
# 29
#
# Governance
#
# 80   ESG Data
#
# 100
#
# Appendix
#
# Message from the CEO
#
# Company Overview
#
# ESG Strategy
#
# 3
#
# 4
#
# 8
#
# Environmental Management Policy  13
#
# Human Rights
#
# 30  ~~ Corporate Governance
#
# 81
#
# Sustainability Management Data
#
# 101
#
# GRI Index
#
# Addressing Climate Change
#
# Resource Circulation
#
# 15
#
# 18
#
# Employee
#
# Supply Chain
#
# 44
#
# —Jeong-Do Management
#
# 86
#
# Membership-Awards & Recognition  124  = SASB Index
#
# 56
#
# Compliance Management  88
#
#  SHEE-Quality Certification Status  125  = UNSDGs Index
#
# Sustainable Business
#
# 10.
#
# Product Stewardship
#
# 23
#
# Customer
#
# 66  —  Risk Management
#
# Business Sites Operation
#
# 26  — Local Community
#
# 75
#
# Information Security
#
# 92
#
# 95.
#
#  Materiality Assessment
#
# 126
#
# TCFD Report
#
# Stakeholder Communication
#
# 129
#
# Greenhouse Gas Verification
# Statement
#
# 130
#
# 131
#
# 134
#
# 135
#
# 137
#
# 146
#
# Independent Assurance Statement  149
#
# Report Overview
#
# Reporting Period
#
# LG Electronics has expressed its  commitment to making changes that will  help it  to achieve sustainable growth and
#
# This report covers our activities from January 2023 through December 2023, and for some key activities extends to our efforts
#
# a  better life  for all,  and has established and implemented goals and action plans to realize them. In  the Sustainability
#
# through the first half of 2024. For quantitative performance, we provide three years of data from 2021 through 2023 to observe
#
# Report, LG Electronics includes its  management approach (MA), goals, activities, progress, and performance on tasks and
#
# performance trends,
#
# objectives in the areas of environment, society, and governance. These are linked to the material issues derived from the
#
# materiality assessment with LG Electronics’ six ESG strategic tasks. LG Electronics will continue to transparently disclose
#
# Scope of Report
#
# its sustainability management activities and performance through the publication of this report each year.
#
# Reporting Principles and Standards
#
# The scope of this report covers the headquarters, production sites in  Korea and overseas, and sales subsidiaries operated
#
# by LG Electronics. Financial information is presented on a consolidated financial statement basis in accordance with Korean
#
# International Financial  Reporting Standards (K-IFRS), and some financial information prepared on a separate financial
#
# LG Electronics’  2023-2024 Sustainability Report adheres to GRI Standards 2021, an international standard quideline,
#
# statement basis is presented in the footnotes. All financial information in  USD has been calculated using the yearly average
#
# and reflects the reporting standards and frameworks set forth by the Sustainability Accounting Standards Board (SASB)
#
# exchange rate. Where there are limitations in  data collection or changes to the calculation criteria, we have noted the
#
# and the Task Force on Climate-related Financial  Disclosures (TCFD). We also reported out progress in  implementing The
#
# reporting scope and the reason for the change in the footnotes,
#
# Ten Principles of the United Nations Global Compact (UNGC) in  four areas: human rights,  labor, environment, and anti-
#
# corruption. In  addition, we meet the four principles of inclusivity,  materiality,  responsiveness, and impact as outlined  in
#
# Third Party Assurance
#
# the AAIOOOAP (AccountAbility Principles Standard), which also outlines the obligation of companies to disclose their
#
# approaches to sustainability management.
#
# To ensure the accuracy, objectivity and reliability of the report preparation process and all  presented information, LG
#
# Electronics commissioned an  independent assurance organization (Korea  Management Registrar) to complete the
#
# assurance in  accordance with international assurance standards. The results of the third-party assurance are presented
#
# in  detail  on page 149 of this  report. The financial  information in  this  report has been audited, and the verification
#
# of greenhouse gas emissions and energy usage was conducted in  accordance with the assurance principles of the
#
# Administrative Guideline for the Greenhouse Gas Target Management System.
#
# 3
#
# 2023-2024 LG Electronics Sustainability Report
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# oO  eG  <  >)
#
# Message from the CEO
#
# As a Smart Life Solution Company, LG Electronics will promote sustainable management to ensure a ‘Better Life for All’
#
# Honorable LG Electronics Stakeholders,
#
# and the 3Ds (Decent Workplace, Diversity & Inclusion,  Design for All) for
#
# In  recent years, recession has plagued the global market with prolonged
#
# people as our ESG strategic tasks. LG Electronics is  implementing these
#
# inflation  and high interest rates,  leading to a slowdown in  consumption.
#
# tasks to achieve mid-to-long term goals.
#
# Concurrently, demands for decarbonization and digital transformation
#
# are intensifying in  the market, and customers are pursuing engagement-
#
# For the Planet
#
# centered consumption such as experience consumption. To proactively
#
# respond to these changes in  the market and with  customers,
#
# LG Electronics declared its  vision  last year to transform from a  ‘Global
#
# Leading Home Appliance Brand’ to a ‘Smart Life Solution Company’ that
#
# LG Electronics  is  pursuing a  broad range of activities to protect our
#
# planet. To achieve carbon neutrality at the product production stage by
#
# 2030, we are reducing carbon emissions through energy-efficient facilities
#
# at our production sites and expanding the use of renewable energy. LG
#
# connects and expands the diverse experiences of customers.
#
# Electronics is  leveraging the
#
# development of energy-efficient products and electrification to reduce
#
# Transformation from home appliances to a  Smart Life Solution
#
# carbon emissions by 20% during the product use stage by 2030.
#
# Company
#
# Additionally, we are actively increasing the use of recycled plastic in  our
#
# Meanwhile, as the importance of supply chain due diligence continues to
#
# For the mid-to-long term future,  LG Electronics is  focusing on the
#
# products, having used a cumulative total of 114,000 tons of recycled
#
# grow, LG Electronics is  constantly checking and improving risk factors
#
# inflection points of servitization, digitalization and electrification.  During
#
# plastic over the past three years. Plastic cushioning materials used in  our
#
# at its  production sites and suppliers. As  a  member of the Responsible
#
# this transition, we will  seek new touch points and pursue changes to
#
# packaging are being replaced with paper alternatives as well.  Last year,
#
# Business Alliance (RBA), LG Electronics will comply with Codes of Conduct
#
# create customer value in  the '3C 2S'  (Connectivity, Care, Customization,
#
# LGE developed the industry's first pulp mold (paper cushioning material)
#
# for labor rights,  safety and health, environment, business ethics,  and
#
# Servitization, Sustainability) experience area.  In  particular, we will focus on
#
# that can cushion over 20kg.  Starting with air purifiers, use of pulp mold
#
# management systems in  its  global supply chain and strive to minimize
#
# innovating non-HW business models, growing B2B business, and securing
#
# will be expanded to larger products.
#
# supply chain risks.
#
# new growth engines as the three pillars to expand customer touchpoints
#
# and experiences. On the financial front, we will  leap forward to become a
#
# For People
#
# As we work towards achieving our business vision of becoming a Smart
#
# USD 766 billion  company by 2030, achieving the ‘Triple 7’  goal (CAGR and
#
# LG Electronics is  committed to providing  convenient products and
#
# Life  Solution Company, we are fully dedicated to pursuing  sustainable
#
# operating profit margin exceeding 7%, and enterprise value greater than 7x).
#
# services for everyone. Last year, we enhanced the accessibility of our
#
# management in pursuit of a better life for all. Thank you.
#
# ‘Better Life for All’
#
# products by launching the LG Comfort Kit,  which greatly increases user
#
# convenience for our home appliances.  In  addition, we are operating a
#
# To maintain sustainable growth,  LG  Electronics conducts ESG
#
# Sign Language Consultation Center at our service touch points, and are
#
# management under the vision of a ‘Better Life for All’  We have chosen
#
# offering the Best Companion Care Service, which provides one-on-one
#
# the 3Cs (Carbon Neutrality, Circularity,  Clean Technology) for the planet
#
# assistance from the vehicle to the store by a dedicated manager.
#
# Chief Executive Officer of LG Electronics
# William (Joowan) Cho
#
# 4
#
# 2023-2024 LG Electronics Sustainability Report
#
# Environmental
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# oO  eG  <  >)
#
# Company Overview
#
# LG Way
#
# LG Electronics Mission and Vision
#
# The LG Way is  LG's unique management philosophy, and guides the thoughts and actions of all  LG associates.
#
# Based on the brand philosophy of "Life's Good,” LG Electronics always strives to provide customers with the First,
#
# The LG Way aims to achieve LG's vision of "No. 1  LG” by practicing 'People-oriented Management’, and ‘Creating
#
# Unique, and New (F-U-N) experiences to make their lives better. We will become a ‘Smart Life Solution’ company
#
# Values for Customers’ through “Jeong-Do Management.”
#
# that connects to and extends customers’ experiences in  every space of their lives,  beyond home appliances,
#
# to include their homes, commercial spaces, mobile spaces including vehicles, and even the virtual space, the
#
# Metaverse.
#
# Behavioral Mode ®
#
# Ethical management and
#
# code of conduct to enable
# capability development
#
# and fair competition
#
# Jeong-Do Management
#
# The ultimate goal of LG is to be
#
# recognized as the market leader in
#
# business performance as well as in
#
# management practice.
#
# Customer-Value Creation |
# People-Oriented Management
#
# cocco0c000d oe  Management
#
# Principles
# The fundamental
#
# organizational principle
#
# guiding LG from its
#
# beginning as a firm
#
# Innovation for a Better Life
#
# Our reason for existing, and our promise to the customers,
#
# Mission
#
# Vision
# Smart Life Solution Company
#
# By 2030, we are committed to becoming a company with USD 76.6 billion in  revenue,
#
# achieving the ‘Triple 7". a 7% CAGR, a 7% operating margin, and an EBITDA multiple of 7x.
#
# Always put the
# customer first
#
# We always put our customers first and make our judgments
# based on them.
#
# Core Value
#
# More exciting
# challenges
#
# We are courageous and positive, constantly finding
# and executing better ideas,
#
# The best that exceeds
# expectations
#
# We aim to be the best and most recognized by exceeding
# everyone's expectations,
#
# Warm
# respect
#
# We genuinely respect each other's personality and diversity.
#
# Confidence in taking
# the right way
#
# We take pride in competing and winning fairly.
#
# 2023-2024 LG Electronics Sustainability Report
#
# Environmental
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# oO  eG  <  >)
#
# Introduction to the Corporation
#
# Name
#
# LG Electronics Inc
#
# Shareholder Status
# Status of Shareholders Holding 5% or more
#
# Largest Shareholders and Affiliated Persons
#
# Location of
# Headquarters
#
# LG Twin Towers, 128 Yeoui-daero, Yeongdeungpo-gu,
# Seoul, Korea
#
# Shareholder
#
# Number of Shares  Shareholding Ratio
# (%)
#
# (Shares)
#
# Shareholder
#
# Relationship
#
# Ownership  Shareholding Ratio
# (%)
#
# (Shares)
#
# Industry
#
# Manufacturing
#
# Major Products
#
# Refrigerators, Washing Machines, Air Conditioners,
# Vacuum Cleaners, TVs, Audio Sound Systems, Automotive
# Components, Monitors, PCs, Signage, etc.
#
# CEO
#
# William Uoowan) Cho
#
# Foundation
#
# October 1, 1958
#
# Credit Rating
# (Global Bond)
#
# S&P: BBB(Stable) / Moody's: Baa2(Stable)
#
# LG Corp
#
# 55,094,582
#
# National Pension
# Service
#
# 11,191,518
#
# 33.67
#
# 6.84
#
# LG Corp
#
# Holding company
#
# 55,094,582
#
# Bong Seok Kwon  enescupie
#
# Affiliated company
#
# 9876
#
# 33.67
#
# 0.01
#
# (Voting share, as of December 31, 2023)
#
# eta
# (Joowan) Cho
#
# Alls company
# executive
#
# 5,373
#
# 0.003
#
# (As of December 31, 2023)
#
# Employee
#
# 72,813 (35,111 in  Korea, 37,702 in overseas)
#
# Sales (Consolidated)
#
# Global Sales
#
# (consolt dated)
#
# USD 6455 billion
#
# (Concolidated)
#
# USD 27 billion
#
# (Consolidate 4)
#
# USD 461 billion
#
# (Consolidated)
#
# USD 281 billion
#
# Total Equity
# (Consolidated)
#
# USD 18.0 billion
#
# * Exchange rate: USD 1 = KRW 1,306
#
# Sales by Business Company
#
# Classification
#
# Ratio (%)
#
# Home Appliance & Air Solution
#
# Home Entertainment
#
# Vehicle component Solutions
#
# Business Solutions
#
# 36
#
# 17
#
# 12
#
# Classification
#
# Sales (KRW 100 million)
#
# Sales (USD billion)
#
# USD 645 billion
#
# Operating Income (Consolidated)
#
# Korea
#
# North America
#
# Europe
#
# Asia
#
# Latin America
#
# Middle East & Africa
#
# China
#
# Russia (CIS)
#
# Total
#
# USD 2 | billion
#
# ol
#
# Exchange rate: USD 1 = KRW 1,306
# (Average exchange rate in 2023)
#
# 342,720
#
# 203,475
#
# 121,293
#
# 74,880
#
# 31124
#
# 32,873
#
# 25,418
#
# 10,495
#
# 26.24
#
# 15.58
#
# 9.29
#
# 5.73
#
# 2.38
#
# 2.52
#
# 1.95
#
# 0.80
#
# 842,278
#
# 64.49
#
# (As of December 31, 2023)
#
# 6
#
# 2023-2024 LG Electronics Sustainability Report
#
# Environmental
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# oO  eG  <  >)
#
# Company Overview
#
# Global Business Sites"
#
# Russia (CIS)
#
# .
#
# Sales & Production
#
# Production
#
# Sales
#
# Europe
#
# Sales & Production
#
# Production
#
# Sales
#
# Other
#
# 1
#
# 1
#
# 2
#
# 3
#
# 2
#
# 13
#
# 14
#
# Middle East and Africa
#
# Sales & Production
#
# ;
#
# Production
# Sales
#
# over
#
# 2
#
# 3
# aq
#
# 4
#
# Sales &
# Production
#
# its
#
# Production
#
# Sales
#
# 33
#
# 46
#
# * Number of business sites according to internal management standards
#
# (As  of end
# As
# of
#
# )
# Mare
# end  of  March 2024
#
# of
#
# P
#
# \
#
# ¢
#
# ¥  q
#
# 5
#
# g  Asi
# sia
#
# ‘
#
# p  %.
#
# NN  4
#
# a ¢<  Sr
#
# Sales & Production
#
# Production
# Sales
#
# Other
#
# 10
#
# 3
# g
#
# ;
# China
#
# Sales & Production
#
# Production
#
# Sales
# orth
#
# ther
#
# Korea
#
# Sales & Production
#
# ;
#
# Production
#
# 3
#
# 8
#
# 1
# 3
#
# 1
#
# 5
#
# North America
#
# Sales & Production
#
# Production
#
# Sales
# Ch
# Other
#
# 2
#
# 4
#
# 14
#
# Central and South
#
# merica
#
# Sales & Production
#
# 2
#
# Production
#
# Sales
# Other
#
# a
#
# 3
# 3
#
# 7
#
# 2023-2024 LG Electronics Sustainability Report
#
# Environmental
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# OD  Bl <  >)
#
# Our Business
#
# Consisting of the Home Appliance & Air Solution (H&A), Home Entertainment (HE), Vehicle component Solutions (VS), and Business Solutions (BS) Business Companies, LG Electronics is a global leader in technological innovation in a
#
# range of fields that includes home appliances, IT,  automotive components, and signage, with operations at approximately 140 sites around the world.
#
# Home Appliance & Air Solution
#
# Home Entertainment
#
# Vehicle component Solutions
#
# Business Solutions
#
# The H&A (Home Appliance & Air Solution)
#
# The HE (Home Entertainment) company strives
#
# Under the vision of ‘Innovation Partner for
#
# Our BS (Business Solutions) company aims to be
#
# company is  leading the global home appliance
#
# to provide customers with a better life from
#
# Future Mobility, the VS (Vehicle component
#
# a true business partner that supports customer
#
# market with market-leading products that
#
# the perspectives of wellness, beauty, and
#
# Solutions) company is transforming itself into a
#
# value enhancement and grows together with the
#
# combine innovative technologies with premium
#
# entertainment. Through a wide range of devices,
#
# true innovation partner that achieves customer
#
# customers by proposing innovative products and
#
# designs developed through extensive research
#
# including TV and audio devices, as well as webOS-
#
# value by making proposals for future mobility
#
# solutions based on customer experience, from a
#
# of our customers around the world, including
#
# based platform businesses and content services,
#
# solutions, rather than staying as a traditional
#
# ‘Trust First’ perspective that prioritizes customer
#
# their cultural characteristics and lifestyle, and
#
# we bring inspiring experiences to our customers’
#
# automotive component supplier. Based on its
#
# trust. We combine advanced digital technologies
#
# is positioning itself as a leading brand not only
#
# daily lives. We constantly deliver innovative
#
# advanced technology in the fields of electricity and
#
# with deep insights into vertical areas to provide
#
# in existing home appliances but also in future
#
# solutions that make our customers lives more
#
# electronics and its user experience know-how in
#
# the best products and solutions based on an
#
# industries such as smart homes.
#
# comfortable, beautiful, and enjoyable, such as
#
# home appliances, we are providing differentiated
#
# innovative experience that exceeds customer
#
# LG OLED TVs with the highest picture quality
#
# value for the future of autonomous driving and
#
# expectations.
#
# available, ease of use and a design that fits
#
# next-generation electric vehicles.
#
# customers’ lifestyles, LG StandbyME, a personal
#
# screen, and LG TONE Free earbuds that achieve
#
# high fidelity audio.
#
# 8
#
# 2023-2024 LG Electronics Sustainability Report
#
# Environmental
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# oO  eG  <  >)
#
# ESG Strategy - For the Planet
#
# 3C Strategies for the Planet
#
# 01
#
# Carbon Neutrality
#
# Performance in 2023
#
# Achieving Carbon Neutrality -  Renewable Energy Transition
#
# By 2030, LG Electronics plans to achieve carbon neutrality through process improvement, the introduction of
#
# YOY carbon emissions reduction
#
# energy-saving technologies, the use of renewable energy to reduce greenhouse gas emissions and the purchase
#
# of UN carbon credits. As an RE100 participant, we have also set a goal of achieving 100% renewable energy at all
#
# of our Korean and overseas business sites by 2050.
#
# Global renewable energy transition
#
# 53,000 sons
#
# 101%
#
# 02
# Circularity
#
# Waste Recycling -  E-waste Collection and Recycling
#
# LG Electronics recycles waste generated at all  of our Korean and overseas business sites and will expand the
#
# Zero Waste To Landfill Certificate for all  of its global business sites. We achieved our goal of reaching a 95%
#
# waste recycling  rate by 2030 ahead of schedule, and will  maintain 95% or higher. We are also proactively
#
# complying with regulations in countries where we operate, establishing relevant policies and collecting e-waste.
#
# Waste recycling rates of business sites
#
# 95.5%
#
# We use environmentally conscious materials for product manufacturing as well as packaging materials, and carry
#
# Cumulative collection of e-waste (Since 2006)
#
# A . 51 million tons
#
# out campaigns to collect waste appliances and batteries.
#
# 03
# Clean Technology
#
# Developing Highly Efficient Products -  Using Environmentally Conscious Materials
#
# LG Electronics is  reducing GHG emission intensity at the product use stage through high-efficiency energy
#
# products. GHG emission intensity refers to the amount of greenhouse gases emitted per unit of product during
#
# the average lifetime of the product. For example, a refrigerator emits per liter of content, while a washing machine
#
# emits per kilogram of washing capacity. We became the first  Korean home appliance company to receive SBTi
#
# (Science Based Targets initiative) verification of our product use stage carbon emission reduction targets.
#
# Reduction of GHG emission intensity of
# seven major products at the product use stage
#
# 11.8%
#
# Cumulative use of recycled plastic (Since 2021)
#
# 114,000 io
#
# 9
#
# 2023-2024 LG Electronics Sustainability Report
#
# Environmental
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# oO  eG  <  >)
#
# ESG Strategy - For People
#
# 3D Strategies for People
#
# 01
# Decent Workplace
#
# Performance in 2023
#
# Safety, Health, Labor, and Human Rights in Supply Chain
#
# LG Electronics takes its social responsibility to protect the safety and health of the working environment and human
#
# rights through the RBA” management program at its production sites. By 2030, we aim to achieve zero critical non-
#
# conformances at 100% of production sites based on audit requirements, and we conduct selfassessments and on-
#
# site audits of suppliers to identify and improve potential and actual risks. We also evaluate the suitability of the ESG
#
# Ratio of ISO 45001 (Health and Safety Management System)
# certified production sites
# (Excluding new subsidiaries (2 in the US, 7  in Mexico) that have not started mass production.)
#
# 100%
#
# Percentage of production sites with zero critical non-conformances
# (Based on RBA audit requirements)
#
# 8 Ox
#
# 0
#
# management of our suppliers and provide related training and consulting.
#
# 1) RBA: Responsible Business Alliance, The world's largest industry alliance for pursuing responsible business activities in global supply chains
#
# Percentage of high-risk suppliers
# (Based on self-assessments)
#
# 02
# Diversity & Inclusion
#
# Recruiting and Developing Female Talents and Expanding Hiring for People with Disabilities
#
# We strive to reflect diversity,  equity, and inclusion (DEI)  in  our organizational culture so that all  employees feel
#
# recognized, have a sense of belonging, and realize their potential. To this end, we have set a target of having 3.5%
#
# Percentage of female employees (Global)
#
# of employees with disabilities in  Korea and 25.5% of female employees (on a global basis) by 2030.
#
# Employment rate of people with disabilities (Korea)
#
# 0.9%
#
# 22.0%
#
# 2.0%
#
# 03
# Design for All
#
# Improving Product and Service Accessibility
#
# LG Electronics is  developing technologies to improve the accessibility of its  products, and is  working to improve
#
# service accessibility by providing sign language counseling services and Braille sticker attachment service to home
#
# appliances. Notably, we operate an accessibility advisory group to promote product development that considers
#
# the practical ease of use for users. We will  apply accessibility technologies and universal design to all  products
#
# released to provide ease of use for all users, including people with disabilities, seniors, and children.
#
# y
#
# a
# al
#
# iN
#
# Home Appliances
# 9 products with voice
# guidance, 5 products
# with voice recognition
#
# TV
# Listening to TV together, Learning
# remote control, Shortcuts to
# accessibility features
#
# ey
#
# Common Braille sticker, product sign
# language video and voice manual,
# sign language counseling centers,
# digital human sign language guidance
# services
#
#
# 10
#
# 2023-2024 LG Electronics Sustainability Report
#
# Environmental
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# oO  eG  <  >)
#
# Sustainable Business
#
# Energy
#
# Vehicles
#
# Heating and Cooling Technologies Leading the Global HVAC Market
#
# LG Electronics leads the global heating, ventilation, and air conditioning (HVAC) market through the manufacturing
#
# Space-Customized EV Charging Solutions
# In  March 2024, LG Electronics introduced three electric vehicle charging solutions (7kW slow charger, 1OOkW fast
#
# commercial and residential heating and cooling solutions. We offer a wide range of high-quality products for
#
# charger, and 200kW fast charger) optimized for various spaces, such as residential and commercial spaces and
#
# heating, cooling, and ventilation, from personal devices to industrial and specialized HVAC systems.
#
# charging stations. The 7kW slow charger for residential use features a touchscreen for enhanced convenience
#
# eae
#
# and is  available  in  both wall-mounted and free-standing models to fit  a variety of installation  environments.
#
# The 100kW fast charger allows for simultaneous charging (up to two vehicles), making it  ideal for public parking
#
# lots at places such as shopping malls,  hospitals, and restaurants, while the 200kW fast charger offers faster
#
# charging speeds and can be used at EV charging stations. LGE’s charging solutions also support stable charging in
#
# temperatures as low as minus 25 degrees Celsius and as high as 40 degrees Celsius, and are certified up to IP65
#
# for water and dust resistance and IK10 for shock resistance.
#
# Centralized Control Solution:
# AC Manager 5
#
# External linkage solution:
# (BMS linkage system) ACP 5
#
# Individual Control Solution:
# Al Wireless Remote Controller
#
# Efficient ESS with a High Level of Competence
#
# LG Electronics provides energy storage system (ESS) solutions with high-quality products and site-specific design
#
# and construction. By building the largest integrated test facility  in  Korea and introducing the ISO 9001 quality
#
# certification system for large-scale products, LG Electronics’  ESS has improved the efficiency of PCS (Power
#
# Conversion System) and minimized electricity  losses.  In  addition, the high-quality batteries and sophisticated
#
# PMS (Power Management System) ensure both reliability and efficiency, and we were able to maximize the space
#
# efficiency in  electrical rooms by reducing the product size by 70% compared to competitors. In  recognition of this
#
# excellence, we have successfully completed the first ESS installation integrated with solar power in  Korea. (Sejong
# Galaxy Solar Power Plant)
#
# EV Charging Solution
#
# 1
#
# 2023-2024 LG Electronics Sustainability Report
#
# Environmental
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# oO  eG  <  >)
#
# Accessibility
#
# Water, Waste and Ecosystem Restoration
#
# LG Comfort Kit to Help Make Appliances Easier to Use for Everyone
#
# Using an advisory group of people with physical disabilities,  hearing impairments, visual  impairments, and brain
#
# Water-Soluble Glass
# Changes in  the marine environment are causing the ocean desertification,  resulting  in  the disappearance of
#
# lesions,  LG Electronics identified their challenges in  using home appliances, analyzed them by user type and
#
# seaweeds such as wakame and kelp in  coastal rocky areas, which is  damaging the marine ecosystem. As part of
#
# product, and developed the LG Comfort Kit,  a practical modification that can be attached to existing products,
#
# its biodiversity conservation efforts, LG Electronics is  developing a water-soluble glass that can contribute to the
#
# and detached just as easily. The LG Comfort Kit incorporates universal design to make LG home appliances easy
#
# restoration of marine ecosystems. The water-soluble glass changes to a mineral ions when dissolved  in  water,
#
# to use for all customers, regardless of gender, age, or disability.
#
# which can be utilized to help algae grow in the ocean, restoring marine ecosystems.
#
# LG Comfort Kit
#
# The water-soluble glass utilizes technology that consistently dissolves mineral ions, which are nutrients for algae,
#
# in  water to promote the growth of algae in  the ocean, much like  fertilizer for crops on land,  helping to restore
#
# marine forests. The increased amount of algae become an essential food source and habitat for other organisms
#
# in the marine ecosystem, creating the environment they need to thrive and grow. Algae also enhances the marine
#
# environment by absorbing carbon dioxide and releasing oxygen. Since 2023, we have been working with Ulsan
#
# National Institute of Science and Technology (UNIST), Research Institute of Industrial Science and Technology
#
# (RIST), and other specialized  research institutes to demonstrate the safety of water-soluble glass and its
#
# effectiveness in  promoting the growth of algae. We also signed an MOU with the Korea Polar Research Institute
#
# (KOPRI), a government-funded organization, to demonstrate its  applicability and effectiveness in  the Antarctic
#
# Voice-Recognition Water Purifier that Leaves No One Behind
#
# marine environment.
#
# In  a Korean first,  LG Electronics launched the 'PuriCare Objet Collection Water Purifier’ with a voice recognition
#
# feature, which not only allows users to dispense water in  10ml increments without pressing the button, but also
#
# Microplastics Care Course
#
# monitors the amount of water they have consumed in  the past week. This allows anyone to use the product
#
# Washing clothes is  essential to keep them clean and smelling good. However, washing clothes made of synthetic
#
# conveniently, from people with visual impairments to the elderly who had difficulty using the product because the
#
# fibers releases microscopic plastic fibers into the water. This water is  either discharged into the ocean, or treated
#
# water purifier button was hard to see, to children who are too short to reach the dispensing button.
#
# and returned to water resources, LG Electronics has introduced an advanced microplastics care course to prevent
#
# the formation of microplastics by household laundry. The course utilizes  LG's 6-Motion (Tumble, Swing, Rolling,
#
# Stepping, Scrubbing and Filtration) technology to reduce fiber friction,  prevent microplastics from forming, and
#
# minimize energy consumption” ThinQ UP washing machine users can download the microplastics care course
#
# from the Upgrade Center in the ThinQ app.
#
# 1) Washing a 3-kilogram training jacket made of 100% polyester using the microplastics care course resulted in a 70% reduction in  microplastics over
# 20um compared to the standard wash course. The microplastics care course also reduced water temperature by 75% compared to the standard
# course, leading to a 30% reduction in energy use.
#
# PuriCare Objet Collection Water Purifier
#
# 12
#
# 2023-2024 LG Electronics Sustainability Report
#
# GROEN  ue Environmental
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix  oe <  >)
#
# Environmental
#
# Environmental Management Policy
#
# 13 |  Addressing Climate Change
#
# 15 | Resource Circulation
#
# 18  | Product Stewardship
#
# 23 | Business Sites Operation  26
#
# 13
#
# 2023-2024 LG Electronics Sustainability Report
#
# Gene Environmental
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# OD  Bl <  >)
#
# Environmental Management Policy
#
# Environmental Management Policy
#
# 1. Purpose
#
# As a responsible corporate citizen,  LG Electronics is  committed to environmental protection throughout all  its
#
# business activities. We adhere to the highest environmental standards and international agreements, and we
#
# continuously strive to minimize our environmental impact through ongoing improvements. Aligned with the UN
#
# @ Hazardous Substance
#
# -  Identify and record all  chemicals (including hazardous waste) that are hazardous to human health or have the
#
# potential to cause environmental pollution when released from our workplaces, and safely store, transport,
#
# use, recycle/reuse, and dispose of these substances. Establish emergency response plans and conduct regular
#
# training to prevent environmental pollution and accidents caused by leaks or spills during handling.
#
# Sustainable Development Goals (SDGs), we have established ambitious goals for reducing our environmental
#
# -  LG Electronics products are managed Guidelines for hazardous substance management in  products to ensure
#
# footprint and have enacted this Environmental Policy to guide our efforts.
#
# that they do not contain substances prohibited by global conventions or pose a risk to human health.
#
# 2. Coverage
#
# LG Electronics applies the most stringent standards when environmental laws and regulations in  different
#
# countries conflict.
#
# @ Production operations and business facilities
#
# @ Products and services
#
# @ Distribution and logistics
#
# @ Management of waste
#
# © Suppliers, Service Providers, Contractors, and Other Key Business Partners
#
# © Mergers, Acquisitions, and New Businesses
#
# 3. Principles
#
# To promote environmental management, LG Electronics defines the following fundamental principles for each
#
# environmental topic.
#
# @ Air Pollutants
#
# ‘Identify the types, characteristics, and emissions volume of air pollutants generated our operations and treat
#
# them according to regulations before discharge. Effective manage ozone-depleting substances in  accordance
#
# with the Montreal Protocol and relevant regulations, and continuously monitor the treatment efficiency of
#
# pollution control facilities.
#
# @ Water Pollutants
#
# :  Treat all wastewater according to regulations before discharge, and continuously monitor treatment results to
#
# ensure that the emission of water pollutants is always within the standard limits.
#
# @ Waste
#
# ‘Identify the types, characteristics, and emission quantities of waste generated at our facilities  and treat
#
# and dispose of it  in  compliance with regulations. Strive to reduce waste generation. Select waste disposal
#
# contractors (including transporters) that are legally qualified to transport and dispose of waste after evaluating
#
# their suitability (including on-site inspections). Minimize the proportion of waste landfilled or incinerated and
#
# Strive to improve the recycling rate of waste.
#
# -  Consider the enhancement of reusability and recyclability from the product development stage and strive for
#
# the lawful collection and treatment of end-of life products to minimize environmental impact.
#
# © Energy
#
# ‘Monitor energy consumption and greenhouse gas emissions to improve energy efficiency at our facilities and
#
# continuously review ways to enhance efficiency.  Promote energy-saving activities.  Strive to use sustainable
#
# energy by implementing renewable energy solutions tailored to our facilities’  conditions, such as installing
#
# renewable energy generation facilities,  purchasing renewable energy certificates,  and entering into power
#
# supply contracts.
#
# © Greenhouse Gas
#
# -  Actively respond to climate change by developing and implementing effective greenhouse gas reduction
#
# measures and setting targets. Publicly disclose performance and reduction efforts for energy consumption and
#
# significant categories of Scope 1,2, and 3 emissions.
#
# 14
#
# 2023-2024 LG Electronics Sustainability Report
#
# Gene Environmental
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# oO  eG  <  >)
#
# @ Water Resource
#
# 6. Information Disclosure and Communication
#
# -  Explore ways to reduce and reuse water consumption. Implement activities to identify and mitigate water
#
# LG Electronics transparently disclose environmental information related to products and business sites, as well
#
# scarcity risks.
#
# Biodiversity Conservation
#
# -  Strive to conserve and restore biodiversity within LG Electronics’ sphere of influence.
#
# @© Preventing Deforestation
#
# as environmental policies and implementation plans, through its website, sustainability reports, and other means.
#
# The company also communicate with employees and stakeholders on environmental management performance
#
# and environmental policies, and reflect their opinions to continuously improve policies.
#
# “Recognize the potential for deforestation issues that may arise within LG Electronics’ sphere of influence and
#
# 7. Performance Evaluation and Improvement
#
# strive to minimize negative impacts.
#
# 4. Management System
#
# @ Role of the Board of Directors and Top Management
#
# LG Electronics ensures the oversight of all  environmental management and performance improvement
#
# activities through the ESG Committee within the Board of Directors and management meetings involving top
#
# management. The ESG Committee within the Board of Directors reviews and deliberate on environmental
#
# management policy  revisions,  responses to environmental laws and regulations,  and environmental
#
# management performance, including climate response, at least once a year. The main roles of the management
#
# meeting involving top management include reviewing and deciding on environmental management risk reviews
#
# and response measures, as well as other matters deemed necessary for the dissemination/propagation of
#
# environmental management.
#
# @ Roles of the Dedicated Organization
#
# LG Electronics designates an environmental management implementation organization to carry out related
#
# tasks. The environmental management implementation organization reviews environmental laws and
#
# regulations, stakeholder requirements, and prepare response measures, establish and operate environmental
#
# management goals and indicators;  build  and operate environmental management systems; and conduct
#
# education and awareness improvement for major stakeholders and information disclosure.
#
# 5. Education and Awareness Improvement
#
# LG Electronics operates education programs for employees and key stakeholders to comply with this policy, share
#
# LG Electronics sets and implement medium- to long-term performance goals for its environmental factors based
#
# on environmental policies. The company regularly evaluates the progress of goal implementation and check goal
#
# achievement, analyze the evaluation results to identify areas for policy improvement, and adjust goals according
#
# to the situation.
#
# Environmental Management System (ISO 14001) Certification
#
# To efficiently manage environmental risks by systematically identifying, evaluating, managing, and improving the
#
# elements necessary for environmental management, LG Electronics has acquired ISO 14001 certification for all  its
#
# Korean and overseas production sites, which it has kept up-to-date.
#
# Number of ISO 14001 Certified Production Sites
#
# (As of 2023)
#
# Classification
#
# Acquisition  /  Renewal
#
# Total
#
# Korea
#
# Overseas
#
# 5
#
# 25
#
# 5
#
# 25*
#
# Certification
# Acquisition Rate
#
# 1 OO (¢)
#
# %
#
# information on environmental policies,  goals, and performance. Through this,  the company raise awareness of
#
# * Excluding new subsidiaries (2 in the US and 1  in  Mexico) that have not started mass production.
#
# environmental management and encourage employees to prioritize the environment in their work processes.
#
# 15
#
# 2023-2024 LG Electronics Sustainability Report
#
# Gene Environmental
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# OD  Bl <  >)
#
# Addressing Climate Change
#
# Reducing GHG and Carbon Emissions
#
# Creating and Implementing a GHG Reduction Plan
#
# To address climate change, LG Electronics has set GHG reduction targets for the entire lifecycle of its products, from
#
# the production to use stage. We aim to reduce the total amount of direct GHG emissions (Scope 1) and indirect GHG
#
# emissions (Scope 2) in the product production stage by 54.6% by 2030 compared to 2017 levels in accordance with the
#
# SBTi's criteria, and reduce GHG emissions intensity in the product use stage by 20% by 2030 compared to 2020 levels.
#
# Promoting External GHG Reduction Projects
#
# LG Electronics is  promoting a CDM project in  India that converts the electricity savings from the usage of high-
#
# efficiency refrigerators into carbon credits.  Since receiving approval for the project from the United Nations
#
# Framework Convention on Climate Change (UNFCCC) in  2013, we have secured 560,000 tons of carbon credits
#
# by 2020, and plan to secure additional credits by 2025. This equates to a reduction in  electricity usage of 125
#
# GWh through the use of our high-efficiency refrigerators. Cumulatively, the project is expected to secure 2 million
#
# To objectively ensure the achievement of these GHG reduction goals are being achieved, in  2021 LG Electronics
#
# tons of carbon credits.
#
# became the first  Korean company in  the home appliance industry to declare its  GHG reduction targets to
#
# the Science Based Targets Initiative  (SBTi) and have them verified  by a third party. Since then, we have been
#
# Global GHG Emissions
#
# systematically managing the progress towards the targets submitted to SBT), and are continuously implementing
#
# Year
#
# Unit
#
# Direct GHG Emission (Scope 1)  Indirect GHG Emission (Scope 2)
#
# Scope 1+2
#
# various strategies and activities in this area.
#
# LG Electronics GHG Reduction Plan
#
# Reducing GHG
# emissions from
# production stage
#
# Implementing
# external GHG
# reduction project
#
# Reducing GHGs in
# the product use
# stage
#
# -  Aim to reduce GHG emissions
#
# by 54.6% by 2030 compared to
#
# 2017, in  accordance with the SBTi's
#
# criteria
#
# 1) CDM: Clean Development Mechanism
#
# .
#
# 1)
# Promote carbon credit CDM
#
# preface ‘churowgn elles oy nigh
# efficiency products
# -  Cumulative 560,000 tons of carbon
#
# credits issued as of 2020, with
#
# more to be secured by 2025
#
# -  Reduce GHG emission intensity of
#
# seven major product categories by
# 20% by 2030 compared to 2020
#
# Reducing GHG Emissions in the Product Production Stage
#
# To reduce greenhouse gas emissions during the product production stage,  LG Electronics has implemented
#
# energy-efficient equipment and carbon emission reduction devices to our manufacturing process. We have
#
# implemented a system to recover and recycle refrigerant that escapes during the injection  of HFC-based
#
# refrigerants, and reuse the recovered refrigerant, thereby reducing refrigerant leakage.
#
# 2019
#
# 2020
#
# 2021
#
# 2022"
#
# 2023
#
# 1,000
#
# tCO,eq
#
# 604
#
# A429
#
# 333
#
# 265
#
# 209
#
# 869
#
# 865
#
# 819
#
# 662
#
# 665
#
# 1,473
#
# 1,294
#
# 1152
#
# 928
#
# 874
#
# 2030 Goal
#
# 923 (54.6% reduction compared to 2017, in accordance with SBTi criteria)
#
# * Data corrected due to changes in  processing of significant figures
#
# 16
#
# 2023-2024 LG Electronics Sustainability Report
#
# Gene Environmental
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# oO  eG  <  >)
#
# Reducing GHG Emissions at the Product Use Stage
#
# Annual GHG Emissions during the Product Use Stage
#
# LG Electronics is  undertaking various efforts to reduce GHG emissions at each stage of the product life  cycle.
#
# Year
#
# 2021
#
# 2022
#
# 2023
#
# These efforts include reducing product weight, conserving resources, and improving energy efficiency. Notably, we
#
# Reduction ratio compared to 2020
#
# 6.6%
#
# 131%
#
# 11.8%
#
# are developing and selling energy-efficient products to reduce GHG emissions during the product use stage, and
#
# are expanding the launch of products that incorporate highly energy-efficient technologies. We also calculate and
#
# disclose GHG emissions generated during the product use stage for our flagship products.
#
# We have developed a Technology Road Map (TRM) that serves as the foundation for setting and implementing
#
# specific targets to improve the energy efficiency of each product category. Additionally, we are committed to
#
# enhancing energy efficiency by establishing our own energy efficiency targets and detailed strategies, while
#
# complying with global energy regulations such as the EU’s Ecodesign Regulation.”
#
# We have set a goal to reduce carbon emissions intensity during the product use stage by 20% by 2030, compared
#
# to 2020 levels, for all  global sales models in  our seven major product categories (TVs,  refrigerators, washing
#
# machines, dryers, residential air conditioners, system air conditioners, and monitors). Given that as of 2021, these
#
# seven major product categories accounted for approximately 90% of the carbon emissions generated by all  our
#
# products in the product use stage, we are actively promoting substantial carbon emission reductions through our
#
# various initiatives to reduce carbon emissions and improve energy efficiency.
#
# Reducing GHG Emissions during the Product Distribution Stage
#
# To reduce carbon emissions during the the product distribution stage, we are collaborating with distribution
#
# company LX Pantos to reduce their GHG emissions.
#
# Measurement, Reporting and Verification of GHG Emissions
#
# As a company regulated under Article 27 of the Framework Act on Carbon Neutrality and Green Growth for
#
# Coping with the Climate Crisis,  LG Electronics submits emission statements to the government and discloses
#
# related information after third-party verification of GHG emissions and energy consumption in  accordance with
#
# Article 27 (3)  of the Act. We have established a greenhouse gas inventory for our global production sites and
#
# disclose our GHG emissions annually.
#
# 1) EU Ecodesign Regulation: Environmental and energy efficiency requlations that manufacturers, distributors, and sellers must comply with from the
#
# Introducing Carbon Accounting and Carbon Pricing
#
# design stage of their products
#
# Key Reduction Achievements
#
# LG Electronics analyzes its  carbon credit allocations and actual emissions on a quarterly basis,  and records
#
# emission liabilities  in  the consolidated statement of financial position when our emissions exceed the allocated
#
# amounts. We also set an internal carbon price to identify business opportunities and assess risks related to
#
# -  In  2023, we developed an optimal wash volume control algorithm utilizing TurboWash 360 technology achieving a
#
# energy savings and GHG reduction activities. This metric, which quantifies the value of carbon for internal trading,
#
# power consumption reduction of approximately 40% for new washing machines sold in the European market
# (from 50 kWh to 30 kWh per 100 cycles).
#
# -  We achieved a 3.7% reduction in  monthly power consumption” by switching the refrigerant used (R401a ® R32) and
#
# optimizing the cooling cycle of the 2023 stand air conditioner in the Korean market.
#
# ‘We developed a DD motor dryer with 6 Motion drying technology achieving a 35.8% reduction in  power consumption
#
# compared to our previous dryer in the Korean market as of the 2023 model.
#
# 1) Monthly power consumption comparison for 2022 and 2023 models (sales-weighted average)
#
# Washing
# machine
# (FAWRS009S2W,
# 2023 model)
#
# Power  ;
# consumption  |
#
# Air
# conditioner
# ditioni
# (Allai
#
# Dryer
# consumption  :  —  (RD21ES,
#
# Power  '
#
# Power
# consumption
#
# 2023
#
# model)
#
# 40% NY  :
#
# models,  2023  mode)  3.7% NV
#
# “  35.8% NY
#
# measures the financial  impact of the environmental burden incurred by LG Electronics, and is  used to make
#
# rational investment decisions for reducing GHG emissions.
#
# 17
#
# 2023-2024 LG Electronics Sustainability Report
#
# Social
#
# Governance
#
# ESG Data
#
# Appendix
#
# 0 [el  <>)
#
# Energy Management
#
# 100% Conversion into Renewable Energy (2050)
#
# New PPA Contract for Overseas Production Sites in 2023
#
# Classification
#
# Production Sites
#
# Generation Capacity (MW)  Annual Power Generation (MWh)
#
# LG Electronics joined RE100 (Renewable Energy 100) in  June 2023 with commitment to a gradual transition to
#
# 100% renewable energy by 2050. In  accordance with our mid- to long-term plan to convert to 100% renewable
#
# China
#
# Tianjin
#
# Nanjing PN
#
# energy, we will gradually increase our use of renewable energy, considering the current status of our Korean and
#
# Solar
#
# Taizhou
#
# overseas operations and the relevant laws and regulations. Aiming to achieve 60% renewable energy by 2030,
#
# 90% by 2040, and 100% by 2050, we are exploring various options for purchasing renewable power, including a
#
# green pricing, EACs (Energy Attribute Certificates) purchasing, and third-party PPAs.?
#
# In  2023, we secured a 55 MW solar power generation capacity through self-generation and PPA” contracts,
#
# capable of generating 58,900 MWh of electricity annually.
#
# Wind
#
# Total
#
# Thailand
#
# Vietnam
#
# China
#
# Qinhuangdao
#
# 6.8
#
# 10.0
#
# 7.0
#
# 3.2
#
# 75
#
# -
#
# 445
#
# 5,200
#
# 12,000
#
# 6,539
#
# 4,365
#
# 17568
#
# 10,000
#
# 55,672
#
# -  Changwon Smart Park: utilized 2.3 MW of renewable power through Korea's first off-grid PPA
#
# Energy Consumption Management System at Global Production Sites
#
# -  Pyeongtaek Digital Park: introduced 1.4MW of solar power
#
# Additionally, we are introducing approximately 44,000 MWh of renewable energy annually through wind and
#
# hydropower. In  2024, we have promoted solar power generation of 11  MW (16,500 MWh/year) through an equity
#
# investment in our Indian production subsidiary.
#
# 1) PPA: Power Purchase Agreement, a contract between a power producer and a power consumer to purchase electricity for a fixed period of time.
#
# LG Electronics operates a global energy consumption management system to monitor and manage the amount
#
# and cost of each type of energy used in  its  Korean and overseas business sites on a monthly basis. This data is
#
# utilized to calculate Scope 1  and 2 GHG emissions, and serves as a foundation for establishing and operating
#
# energy-efficient production facilities within our subsidiaries.
#
# ...
#
# Electronics only and in accordance with terms of reference agreed with them. DNV expressly disclaims any liability
#
# or responsibility for any decisions, whether investment or otherwise, based upon this assurance statement.
#
# Scope of Assurance
#
# The GHG emissions data covered by our examination comprise Direct emissions (Scope 1  emissions) and Energy
#
# indirect emissions (Scope 2 emissions) from LG Electronics’ boundary of the report ;
#
# -  Organizational boundary for reporting:  Korean business sites of LG Electronics (Fugitive emissions form refrigerant are
# included”)
#
# 1} Limited level of assurance is  only covered for Fugitive emission by purchasing of refrigerant in  Direct emissions.
#
# Verification Approach
#
# The verification has been conducted by DNV on February to March 2024 and performed in  accordance with the
#
# verification principles and tasks outlined in the guidelines on the operation of GHG ETS (Notification No, 2023-221,
#
# Korean Ministry of Environment) and the verification  guideline for GHG ETS (Notification  No. 2021-112, Korean
#
# Ministry of Environment). We planned and performed our work to obtain all  the information and explanations
#
# deemed necessary to provide us with sufficient evidence to provide a reasonable verification opinion concerning
#
# the completeness of the emission inventory as well as the reported emission figures in  ton CO2 equivalent. As
#
# part of the verification process;
#
# -  We have reviewed and verified the GHG emissions report for the calendar year 2023
#
# -  We have reviewed and verified the process to generate, aggregate and report the emissions
#
# Greenhouse Gas Emissions of LG Electronics Korean business site for Yr 2023
#
# (Unit: ton CO, equivalent)
#
# LG Electronics
# (Domestic, in Korea)
# i
#
# ic,
#
# Excl. Refrigerant
#
# Incl.  Refrigerant
#
# Direct Emissions (Scope 1)  —_ Indirect Emissions (Scope 2)
#
# otal
# Total
#
# Emissions
# Emission
#
# 30,693
#
# 74,787*
#
# 217159
#
# 247.852
#
# 291,946
#
# * Fugitive emission (44,094 tCO,eq) by purchasing of refrigerant is included in  Direct emissions.
#
# DNV
#
# May 2024
#
# Seoul, Korea
#
# Jang-Sub Lee
#
# Country Representative
#
# DNV Business Assurance Korea Ltd.
#
# 147  2023-2024 LG Electronics Sustainability Report
#
# C  Overview
#
# Environmental
#
# Social
#
# Governance
#
# Introduction
#
# Conclusions
#
# DNV Business Assurance Korea Ltd. (“DNV”) was commissioned by LG Electronics Inc.  (“Company”) to perform
#
# Based on the process and procedures conducted, there is  no evidence that the GHG statement is  not materially
#
# third  party verification for the Company's Greenhouse Gas Inventory Report (“the report”) in  the calendar year
#
# correct and is not a fair representation of GHG data and information;
#
# 2023. The Company is  responsible for the preparation of the GHG emissions data on the basis set out within the
#
# ‘DNV presents an ‘Unmodified’ opinion on Greenhouse Gas Emissions
#
# ‘ISO 14064-1:2018, The GHG Protocol: A corporate reporting and accounting standard and 2006 IPCC Guidelines
#
# for National Greenhouse Gas Inventories’. Our responsibility in  performing this work is to the management of the
#
# Company only and in  accordance with terms of reference agreed with them. DNV expressly disclaims any liability
#
# or responsibility for any decisions, whether investment or otherwise, based upon this assurance opinion.
#
# Objectives and scope of verification
#
# The purpose of this verification  is  to present an independent verification opinion on the company's greenhouse
#
# gas emissions, and the scope of verification is as follows;
#
# -  Organizational Boundary: 26 overseas business sites of the company
# -  Operational Boundary: Scope 1  (Direct emissions) & Scope 2 (Indirect emissions)
#
# -  Reporting period: 2023.01.01 ~2023.12.31
#
# Verification Approach
#
# The verification has been conducted in  accordance with the verification principles and tasks outlined in  the ‘ISO
#
# 14064-3:2019" based upon a  limited level of assurance. We planned and performed our work so as to obtain all
#
# the information and explanations deemed necessary to provide us with sufficient evidence to provide a verification
#
# opinion with 5% materiality level, concerning the completeness of the emission inventory as well as the reported
#
# emission figures in ton CO, equivalent. As part of the verification process, we have reviewed as follows,
#
# -  Process to generate, aggregate and report the emissions data
#
# -  The data and information supporting the report were based on historical in nature. These may include partially hypothetical
#
# and projected data and information (refer to the report for details)
#
# Greenhouse Gas Emissions of LG Electronics overseas business sites for Yr 2023
#
# (Unit: ton CO, equivalent)
#
# LG Electronics
#
# Direct Emissions (Scope 1)
#
# Indirect Emissions (Scope 2)
#
# Total Emissions
#
# Overseas business
#
# sites
#
# 126,733"
#
# 448125
#
# 574,863
#
# * Fugitive emission (68,437 tCO,eq) by purchasing of refrigerant is included in  Direct emissions.
# * In order to report the GHG emissions as an integer, the rounded number on the opinion might be different from the number on the system with
#
# +1tCO,eq
#
# DNV
#
# 13th May 2024
#
# Seoul, Korea
#
# Jang-Sub Lee
#
# Country Representative
#
# DNV Business Assurance Korea
#
# ibe
#
# 148  2023-2024 LG Electronics Sustainability Report
#
# C  Overview
#
# Environmental
#
# Social
#
# Governance
#
# Introduction
#
# Conclusions
#
# DNV Business Assurance Korea Ltd.  ("DNV") was commissioned by LG Electronics Inc.  (“Company”) to
#
# Based on the process and procedures conducted, there is  no evidence that the inventory is  not materially correct
#
# perform third party verification for the Company's Greenhouse Gas Inventory (“the inventory”). The Company
#
# and is not a fair representation of GHG data and information;
#
# is  responsible for the preparation of the GHG emissions data on the basis set out within the “WRI/WBCSD
# GHG Protocol: A Corporate Accounting and Reporting Standard (2004)’, The Corporate Value Chain (Scope 3)
#
# Accounting and Reporting Standard’ and ‘2006 IPCC Guidelines for National Greenhouse Gas Inventories’. Our
#
# responsibility in  performing this work is  to the management of the Company only and in  accordance with terms
#
# of reference agreed with them. DNV expressly disclaims any liability  or responsibility for any decisions, whether
#
# investment or otherwise, based upon this verification opinion.
#
# Objectives and scope of verification
#
# The purpose of this verification  is  to present an independent verification opinion on the company's greenhouse
#
# gas emissions, and the scope of verification is as follows;
#
# -  Organizational Boundary: LG Electronics Inc.
#
# -  Operational Boundary: Scope 3 (Other indirect emissions)
#
# -  Upstream: 8 Categories -  1,  2,3,4,5, 6,78
#
# -  Downstream: 5 Categories -  10, 11, 12, 13, 15
#
# -  Reporting period: 2023.01.01 ~202312.31
#
# Verification Approach
#
# -  DNV presents an ‘Unmodified’ opinion on Greenhouse Gas Emissions
#
# Other indirect emissions (Scope 3: Category 11) of LG electronics
#
# (Unit: ton CO,eq)
#
# Year
#
# Upstream
#
# Downstream
#
# Total Emissions
#
# 2023
#
# 5,340,780
#
# 64,884,353
#
# 70,225133
#
# * In  order to report the GHG emissions as an integer, the rounded number on the opinion might be different from the number on the system with
#
# +1tCO,eq
#
# * Refer to Annex for greenhouse gas emissions by categories.
#
# DNV
#
# 28th June 2024
#
# Jang-Sub Lee
#
# Country Representative
#
# DNV Business Assurance Korea
#
# ar 4
#
# Annex to ‘PRJN-704268-2024-AST-ENG’
#
# Other indirect emissions (Scope 3) of LG Electronics in 2023
#
# (Unit: ton CO,eq)
#
# Categories
#
# Upstream
#
# Downstream
#
# Emissions
#
# The verification has been conducted in  accordance with the verification principles and tasks outlined in  the ‘ISO
#
# 1  Purchased goods and services
# 2 Capital goods
#
# 14064-3:2019" based upon a  limited  level of assurance. We planned and performed our work so as to obtain
#
# 3 Fuel- and eneray- related activities (not included in
#
# all  the information and explanations deemed necessary to provide us with sufficient evidence to provide a
#
# Scope 1  or Scope 2)
#
# verification opinion with 5% materiality level, concerning the completeness of the emission inventory. As part of
#
# the verification process, we have reviewed as follows;
#
# -  Process to generate, aggregate and report the emissions data
#
# -The data and information supporting the report were based on historical  in  nature.  May include partially
#
# hypothetical and projected data and information (refer to the inventory for details)
#
# 4 Upstream transportation and distribution
# 5 Waste generated in operation
# 6 Business travel
# 7 Employee commuting
# 8 Upstream leased assets
# 10 Processing of sold products
# 11 Use of sold products
# 12 End-of-life treatment of sold products
#
# 13 Downstream leased assets
# 15 Investments
# Total emissions
#
# 2,807,879
# 400,997
#
# 135,070
#
# 1,794,560
# 12,769
# 46,073
# 78,055
# 65,377
#
# 5,340,780
#
# 37,810
# 61,207,842
# 153,377
#
# 3,005
# 2,482,319
# 64,884,353
#
# 2,807,879
# 400,997
#
# 135,070
#
# 1,794,560
# 12,769
# 46,073
# 78,055
# 65,377
# 37,810
# 61,207,842
# 153,377
#
# 3,005
# 2,482,319
# 70,225,133
#
# * In order to report the GHG emissions as an integer, the rounded number on the statement might be different with + 1  tCO,eq.
#
# 149  2023-2024 LG Electronics Sustainability Report
#
# C  Overview
#
# Environmental
#
# Social
#
# Governance
#
# Independent Assurance Statement
#
# To readers of LG Electronics Sustainability Report 2023-2024
#
# Introduction
#
# Korea Management Registrar (KMR) was commissioned by LG Electronics to conduct an independent assurance
#
# of its  Sustainability Report 2023-2024 (the “Report”). The data and its  presentation in  the Report is  the sole
#
# responsibility of the management of LG Electronics. KMR’s responsibility is to perform an assurance engagement
#
# as agreed upon in our agreement with LG Electronics and issue an assurance statement.
#
# Scope and Standards
#
# LG Electronics described its sustainability performance and activities in  the Report. Our Assurance Team carried
#
# out an assurance engagement in accordance with the AAIOOOAS v3 and KMR’s assurance standard SRV1000. We
#
# are providing a Type 2, moderate level assurance. We evaluated the adherence to the AAIOOOAP (2018) principles
#
# of inclusivity, materiality, responsiveness and impact, and the reliability of the information and data provided using
#
# the Global Reporting Initiative (GRI) Index provided below. The opinion expressed in the Assurance Statement has
#
# been formed at the materiality of the professional judgment of our Assurance Team.
#
# -  GRI 414: Supplier Social Assessment
#
# -  GRI 416: Customer Privacy
#
# *  Etc, Material Issue
#
# -  Material Topic Issue
#
# - The Data of Supply Chain Management
#
# - Voice of Customer
# -  Health and Safety (Dead rate, LTIFR)
#
# As for the reporting boundary, the engagement excludes the data and information of LG Electronics's partners,
#
# suppliers and any third parties.
#
# KMR's Approach
#
# To perform an assurance engagement within an agreed scope of assessment using the standards outlined above,
#
# our Assurance Team undertook the following activities as part of the engagement:
#
# *  reviewed the overall Report:
#
# *  reviewed materiality assessment methodology and the assessment report;
#
# *  evaluated sustainability strategies, performance data management system, and processes,
#
# Confirmation that the Report was prepared in  accordance with GRI standards 2021 was included in  the scope
#
# *  interviewed people in charge of preparing the Report:
#
# of the assurance. We have reviewed the topic-specific disclosures of standards which were identified  in  the
#
# *  reviewed the reliability of the Report's performance data and conducted data sampling;
#
# materiality assessment process
#
# *  GRI Sustainability Reporting Standards 2021
#
# *  Universal standards
#
# *  Topic specific standards
#
# -  GRI 205: Anti-corruption
#
# -  GRI 302: Energy
#
# -  GRI 303: Water and Effluents
#
# -  GRI 305: Emissions
#
# -  GRI 306: Waste
#
# -  GRI 401: Employment
#
# -  GRI 403: Occupational Health and Safety
#
# -  GRI 404: Training and Education
#
# -  GRI 405: Diversity and Equal Opportunity
#
# -  GRI 406: Non-discrimination
#
# -  GRI 408: Child Labor
#
# -  GRI 409: Forced or Compulsory Labor
#
# *  assessed the reliability of information using independent external sources such as Financial Supervisory Service’s DART and
#
# public databases,
#
# Limitations and Recommendations
#
# KMR's assurance engagement is  based on the assumption that the data and information provided by LG
#
# Electronics to us as part of our review are provided in  good faith.  Limited depth of evidence gathering including
#
# inquiry and analytical procedures and limited sampling at lower levels in the organization were applied. To address
#
# this,  we referred to independent external sources such as DART and National Greenhouse Gas Management
#
# System (NGMS) and public databases to challenge the quality and reliability of the information provided.
#
# 150  2023-2024 LG Electronics Sustainability Report
#
# C  Overview
#
# Environmental
#
# Social
#
# Governance
#
# Conclusion and Opinion
#
# Reliability of Specific Sustainability Performance Information
#
# Based on the document reviews and interviews, we had several discussions with LG Electronics on the revision
#
# In  addition to the adherence to AAIOOOAP (2018) principles,  we have assessed the reliability  of economic,
#
# of the Report. We reviewed the Report's final version  in  order to make sure that our recommendations for
#
# environmental, and social performance data related to sustainability performance. We interviewed the in-charge
#
# improvement and revision have been reflected.  Based on the work performed, it  is  our opinion that the Report
#
# persons and reviewed information on a sampling basis and supporting documents as well as external sources and
#
# applied the GRI Standards. Nothing comes to our attention to suggest that the Report was not prepared in
# accordance with the AAIOOOAP (2018) principles.
#
# Inclusivity
#
# public databases to confirm that the disclosed data is  reliable. Any intentional error or misstatement is  not noted
#
# from the data and information disclosed in the Report.
#
# Competence and Independence
#
# LG Electronics has developed and maintained different stakeholder communication channels at all  levels to
#
# KMR maintains a comprehensive system of quality control including documented policies and procedures in
#
# announce and fulfill  its responsibilities to the stakeholders. Nothing comes to our attention to suggest that there
#
# accordance with ISO/IEC 170212015 -  Requirements for bodies providing audit and certification of management
#
# is
#
# akey stakeholder group left out in the process. The organization makes efforts to properly reflect opinions and
#
# systems. This engagement was carried out by an independent team of sustainability assurance professionals.
#
# expectations into its strategies.
#
# Materiality
#
# LG Electronics has a unique materiality assessment process to decide the impact of issues identified on its
#
# sustainability performance. We have not found any material topics left out in the process.
#
# Responsiveness
#
# LG Electronics prioritized material issues to provide a comprehensive, balanced report of performance, responses,
#
# and future plans regarding them. We did not find anything to suggest that data and information disclosed in the
#
# Report do not give a fair representation of LG Electronics's actions.
#
# Impact
#
# LG Electronics identifies and monitors the direct and indirect impacts of material topics found through the
#
# materiality assessment, and quantifies such impacts as much as possible.
#
# KMR has no other contract with LG Electronics and did  not provide any services to LG Electronics that could
#
# compromise the independence of our work.
#
# KIN) R) GR/ SRVIOOO
#
# Sustainability Committee Assurance
#
# SR Y
#
# June 2024 Seoul, Korea
#
# AA1000
# Licensed Assurance Provider
# 000-129
#
# ceo  . ST  Hoag

# %% [markdown]
# ### Pros and Cons:
#
# Pros:
# - It preserves the document structure, processing PDFs at a granular level.
# - It provides access to text positioning, fonts, and layout details.
# - It works entirely in Python, don't need any third-party OCR or GUI-based tools.
#
# Cons:
# - PDFMiner is not an OCR reader, hence it cannot capture texts on scanned images of text

# %% [markdown]
# ## Using PyPDF2.PdfReader

# %%
from PyPDF2 import PdfReader

pdf_path = r"/Users/jeremiahtay/DSA3101/2023-2024_Sustainability_Report_(ENG)_.pdf"

# Open the PDF file
with open(pdf_path, 'rb') as f:
    pdf = PdfReader(f)  # Updated from PdfFileReader to PdfReader
    information = pdf.metadata  # Updated from getDocumentInfo()
    number_of_pages = len(pdf.pages)  # Updated from getNumPages()
    print(information)

# Extract text from the PDF
text = ''
pdfReader = PdfReader(pdf_path)  # Open PDF using PdfReader
for i in range(len(pdfReader.pages)):  # Iterate through pages
    pageObj = pdfReader.pages[i]  # Access page
    text += pageObj.extract_text()  # Use extract_text() instead of extractText()

print(text)
# Out:
# {'/CreationDate': "D:20240808102920+09'00'", '/Creator': 'Adobe InDesign 15.1 (Macintosh)', '/ModDate': "D:20240808103106+09'00'", '/Producer': 'Adobe PDF Library 15.0', '/Trapped': '/False'}
# 2023 2024 LG Electronics Sustainability Report 2 Overview Environmental Social Governance ESG Data Appendix 2023-2024 LG Electronics Sustainability Report
# Report Overview
# LG Electronics has expressed its commitment to making changes that will help it to achieve sustainable growth and
# a better life for all, and has established and implemented goals and action plans to realize them. In the Sustainability
# Report, LG Electronics includes its management approach (MA), goals, activities, progress, and performance on tasks and
# objectives in the areas of environment, society, and governance. These are linked to the material issues derived from the
# materiality assessment with LG Electronics' six ESG strategic tasks. LG Electronics will continue to transparently disclose
# its sustainability management activities and performance through the publication of this report each year.
# Reporting Principles and Standards
# LG Electronics’ 2023-2024 Sustainability Report adheres to GRI Standards 2021, an international standard guideline,
# and reflects the reporting standards and frameworks set forth by the Sustainability Accounting Standards Board (SASB)
# and the Task Force on Climate-related Financial Disclosures (TCFD). We also reported out progress in implementing The
# Ten Principles of the United Nations Global Compact (UNGC) in four areas: human rights, labor, environment, and anti-
# corruption. In addition, we meet the four principles of inclusivity, materiality, responsiveness, and impact as outlined in
# the AA1000AP (AccountAbility Principles Standard), which also outlines the obligation of companies to disclose their
# approaches to sustainability management.Reporting Period
# This report covers our activities from January 2023 through December 2023, and for some key activities extends to our efforts
# through the first half of 2024. For quantitative performance, we provide three years of data from 2021 through 2023 to observe
# performance trends.
# Scope of Report
# The scope of this report covers the headquarters, production sites in Korea and overseas, and sales subsidiaries operated
# by LG Electronics. Financial information is presented on a consolidated financial statement basis in accordance with Korean
# International Financial Reporting Standards (K-IFRS), and some financial information prepared on a separate financial
# statement basis is presented in the footnotes. All financial information in USD has been calculated using the yearly average
# exchange rate. Where there are limitations in data collection or changes to the calculation criteria, we have noted the
# reporting scope and the reason for the change in the footnotes.
# Third Party Assurance
# To ensure the accuracy, objectivity and reliability of the report preparation process and all presented information, LG
# Electronics commissioned an independent assurance organization (Korea Management Registrar) to complete the
# assurance in accordance with international assurance standards. The results of the third-party assurance are presented
# in detail on page 149 of this report. The financial information in this report has been audited, and the verification
# of greenhouse gas emissions and energy usage was conducted in accordance with the assurance principles of the
# Administrative Guideline for the Greenhouse Gas Target Management System.Table of Contents
# Overview
# Message from the CEO
# Company Overview
# ESG Strategy
# Sustainable Business3
# 4
# 8
# 10Environmental
# Environmental Management Policy
# Addressing Climate Change
# Resource Circulation
# Product Stewardship
# Business Sites Operation12
# 13
# 15
# 18
# 23
# 26Governance
# Corporate Governance
# Jeong-Do Management
# Compliance Management
# Risk Management
# Information Security80
# 81
# 86
# 88
# 92
# 9529
# 30
# 44
# 56
# 66
# 75Social
# Human Rights
# Employee
# Supply Chain
# Customer
# Local Community100
# 101
# 124
# 125
# 126
# 129ESG Data
# Sustainability Management Data
# Membership·Awards & Recognition
# SHEE·Quality Certification Status
# Materiality Assessment
# Stakeholder Communication130
# 131
# 134
# 135
# 137
# 146
# 149Appendix
# GRI Index
# SASB Index
# UN SDGs Index
# TCFD Report
# Greenhouse Gas Verification
# Statement
# Independent Assurance Statement3
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# CEO 메시지Message from the CEO
# Honorable LG Electronics Stakeholders,
# In recent years, recession has plagued the global market with prolonged
# inflation and high interest rates, leading to a slowdown in consumption.
# Concurrently, demands for decarbonization and digital transformation
# are intensifying in the market, and customers are pursuing engagement-
# centered consumption such as experience consumption. To proactively
# respond to these changes in the market and with customers,
# LG Electronics declared its vision last year to transform from a ‘Global
# Leading Home Appliance Brand' to a ‘Smart Life Solution Company' that
# connects and expands the diverse experiences of customers.
# Transformation from home appliances to a Smart Life Solution
# Company
# For the mid-to-long term future, LG Electronics is focusing on the
# inflection points of servitization, digitalization and electrification.  During
# this transition, we will seek new touch points and pursue changes to
# create customer value in the '3C 2S' (Connectivity, Care, Customization,
# Servitization, Sustainability) experience area. In particular, we will focus on
# innovating non-HW business models, growing B2B business, and securing
# new growth engines as the three pillars to expand customer touchpoints
# and experiences. On the financial front, we will leap forward to become a
# USD 76.6 billion company by 2030, achieving the ‘Triple 7’ goal (CAGR and
# operating profit margin exceeding 7%, and enterprise value greater than 7x).
# 'Better Life for All’
# To maintain sustainable growth, LG Electronics conducts ESG
# management under the vision of a 'Better Life for All.’  We have chosen
# the 3Cs (Carbon Neutrality, Circularity, Clean Technology) for the planet As a Smart Life Solution Company, LG Electronics will promote sustainable management to ensure a 'Better Life for All'
# and the 3Ds (Decent Workplace, Diversity & Inclusion, Design for All) for
# people as our ESG strategic tasks. LG Electronics is implementing these
# tasks to achieve mid-to-long term goals.
# For the Planet
# LG Electronics is pursuing a broad range of activities to protect our
# planet. To achieve carbon neutrality at the product production stage by
# 2030, we are reducing carbon emissions through energy-efficient facilities
# at our production sites and expanding the use of renewable energy. LG
# Electronics is leveraging the
# development of energy-efficient products and electrification to reduce
# carbon emissions by 20% during the product use stage by 2030.
# Additionally, we are actively increasing the use of recycled plastic in our
# products, having used a cumulative total of 114,000 tons of recycled
# plastic over the past three years. Plastic cushioning materials used in our
# packaging are being replaced with paper alternatives as well. Last year,
# LGE developed the industry's first pulp mold (paper cushioning material)
# that can cushion over 20kg.  Starting with air purifiers, use of pulp mold
# will be expanded to larger products.
# For People
# LG Electronics is committed to providing convenient products and
# services for everyone. Last year, we enhanced the accessibility of our
# products by launching the LG Comfort Kit, which greatly increases user
# convenience for our home appliances. In addition, we are operating a
# Sign Language Consultation Center at our service touch points, and are
# offering the Best Companion Care Service, which provides one-on-one
# assistance from the vehicle to the store by a dedicated manager.Chief Executive Officer of LG Electronics
# William (Joowan) ChoMeanwhile, as the importance of supply chain due diligence continues to
# grow, LG Electronics is constantly checking and improving risk factors
# at its production sites and suppliers. As a member of the Responsible
# Business Alliance (RBA), LG Electronics will comply with Codes of Conduct
# for labor rights, safety and health, environment, business ethics, and
# management systems in its global supply chain and strive to minimize
# supply chain risks.
# As we work towards achieving our business vision of becoming a Smart
# Life Solution Company, we are fully dedicated to pursuing  sustainable
# management in pursuit of a better life for all. Thank you.4
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# Company Overview
# LG Way
# The LG Way is LG's unique management philosophy, and guides the thoughts and actions of all LG associates.
# The LG Way aims to achieve LG's vision of "No. 1 LG" by practicing 'People-oriented Management', and 'Creating
# Values for Customers' through “Jeong-Do Management.”LG Electronics Mission and Vision
# Based on the brand philosophy of "Life's Good," LG Electronics always strives to provide customers with the First,
# Unique, and New (F-U-N) experiences to make their lives better. We will become a 'Smart Life Solution' company
# that connects to and extends customers' experiences in every space of their lives, beyond home appliances,
# to include their homes, commercial spaces, mobile spaces including vehicles, and even the virtual space, the
# Metaverse.
# Behavioral Mode
# Ethical management and
# code of conduct to enable
# capability development
# and fair competition Vision
# The ultimate goal of LG is to be
# recognized as the market leader in
# business performance as well as in
# management practice.
# Management
# Principles
# The fundamental
# organizational principle
# guiding LG from its
# beginning as a firmMission
# Innovation for a Better Life
# Our reason for existing, and our promise to the customers.
# Vision
# Smart Life Solution Company
# By 2030, we are committed to becoming a company with USD 76.6 billion in revenue,
# achieving the 'Triple 7': a 7% CAGR, a 7% operating margin, and an EBITDA multiple of 7x.
# Core Value
# Always put the
# customer  firstWe always put our customers first and make our judgments
# based on them.
# More exciting
# challengesWe are courageous and positive, constantly finding
# and executing better ideas .
# The best that exceeds
# expectationsWe aim to be the best and most recognized by exceeding
# everyone's expectations.
# Warm
# respectWe genuinely respect each other's personality and diversity .
# Confidence in taking
# the right wayWe take pride in competing and winning fairly .No.1 LG
# Jeong-Do Management
# Customer-Value Creation |
# People-Oriented Management5
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# Introduction to the Corporation
# Name LG Electronics Inc
# Location of
# Headquarters LG Twin Towers, 128 Yeoui-daero, Yeongdeungpo-gu,
# Seoul, Korea
# Industry Manufacturing
# Major Products Refrigerators, Washing Machines, Air Conditioners,
# Vacuum Cleaners, TVs, Audio Sound Systems, Automotive
# Components, Monitors, PCs, Signage, etc.
# CEO William (Joowan) Cho
# Foundation October 1, 1958
# Credit Rating
# (Global Bond) S&P: BBB(Stable) / Moody’s: Baa2(Stable)
# Employee 72,813 (35,111 in Korea, 37,702 in overseas)
# Sales
# (Consolidated)USD 64.5 billion
# Operating Income
# (Consolidated)USD 2.7 billion
# Total Assets
# (Consolidated)USD 46.1 billion
# Total Liabilities
# (Consolidated)USD 28.1 billion
# Total Equity
# (Consolidated)USD 18.0 billion
# Classification Ratio (%)
# Home Appliance & Air Solution 36
# Home Entertainment 17
# Vehicle component Solutions 12
# Business Solutions 6Classification Sales (KRW 100 million) Sales  (USD billion)
# Korea 342,720 26.24
# North America 203,475 15.58
# Europe 121,293 9.29
# Asia 74,880 5.73
# Latin America 31,124 2.38
# Middle East & Africa 32,873 2.52
# China 25,418 1.95
# Russia (CIS) 10,495 0.80
# Total 842,278 64.49 Shareholder RelationshipOwnership
# (Shares)Shareholding Ratio
# (%)
# LG Corp Holding company 55,094,582 33.67
# Bong Seok KwonAffiliated company
# executive 9,876 0.01
# William
# (Joowan) ChoAffiliated company
# executive 5,373 0.003ShareholderNumber of Shares
# (Shares)Shareholding Ratio
# (%)
# LG Corp 55,094,582 33.67
# National Pension
# Service11,191,518 6.84Shareholder Status
# Status of Shareholders Holding 5% or more Largest Shareholders and Affiliated Persons
# Global Sales Sales (Consolidated)
# Operating Income (Consolidated)
# (As of December 31, 2023) Exchange rate: USD 1 = KRW 1,306
# (Average exchange rate in 2023)Sales by Business Company(As of December 31, 2023)(Voting share, as of December 31, 2023)
# USD 6 4 . 5  billion
# USD 2 . 7  billionCompany Overview
# * Exchange rate: USD 1 = KRW 1,3066
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# Global Business Sites*
# Sales &
# Production
# 18Sales
# 46Production
# 33Other
# 48(As of end of March 2024)
# * Number of business sites according to internal management standardsEurope
# Sales & Production 3
# Production 2
# Sales 13
# Other 14Russia (CIS)
# Sales & Production 1
# Production 1
# Sales 2
# Middle East and Africa
# Sales & Production 2
# Production 3
# Sales 11
# Other 4Korea
# Sales & Production 1
# Production 5
# Asia
# Sales & Production 4
# Production 6
# Sales 9
# Other 10China
# Sales & Production 3
# Production 8
# Sales 1
# Other 3
# Central and South
# America
# Sales & Production 2
# Production 4
# Sales 8
# Other 3North America
# Sales & Production 2
# Production 4
# Sales 2
# Other 14Company Overview7
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# Our Business
# Consisting of the Home Appliance & Air Solution (H&A), Home Entertainment (HE), Vehicle component Solutions (VS), and Business Solutions (BS) Business Companies, LG Electronics is a global leader in technological innovation in a
# range of fields that includes home appliances, IT, automotive components, and signage, with operations at approximately 140 sites around the world.
# Home Appliance & Air Solution
# The H&A (Home Appliance & Air Solution)
# company is leading the global home appliance
# market with market-leading products that
# combine innovative technologies with premium
# designs developed through extensive research
# of our customers around the world, including
# their cultural characteristics and lifestyle, and
# is positioning itself as a leading brand not only
# in existing home appliances but also in future
# industries such as smart homes.
# Vehicle component Solutions
# Under the vision of 'Innovation Partner for
# Future Mobility,’ the VS (Vehicle component
# Solutions) company is transforming itself into a
# true innovation partner that achieves customer
# value by making proposals for future mobility
# solutions, rather than staying as a traditional
# automotive component supplier. Based on its
# advanced technology in the fields of electricity and
# electronics and its user experience know-how in
# home appliances, we are providing differentiated
# value for the future of autonomous driving and
# next-generation electric vehicles.
# Home Entertainment
# The HE (Home Entertainment) company strives
# to provide customers with a better life from
# the perspectives of wellness, beauty, and
# entertainment. Through a wide range of devices,
# including TV and audio devices, as well as webOS-
# based platform businesses and content services,
# we bring inspiring experiences to our customers'
# daily lives. We constantly deliver innovative
# solutions that make our customers' lives more
# comfortable, beautiful, and enjoyable, such as
# LG OLED TVs with the highest picture quality
# available, ease of use and a design that fits
# customers’ lifestyles, LG StandbyME, a personal
# screen, and LG TONE Free earbuds that achieve
# high fidelity audio.
# Business Solutions
# Our BS (Business Solutions) company aims to be
# a true business partner that supports customer
# value enhancement and grows together with the
# customers by proposing innovative products and
# solutions based on customer experience, from a
# 'Trust First' perspective that prioritizes customer
# trust. We combine advanced digital technologies
# with deep insights into vertical areas to provide
# the best products and solutions based on an
# innovative experience that exceeds customer
# expectations.
# Company Overview8
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# 01
# Carbon Neutrality
# Achieving Carbon Neutrality · Renewable Energy Transition
# By 2030, LG Electronics plans to achieve carbon neutrality through process improvement, the introduction of
# energy-saving technologies, the use of renewable energy to reduce greenhouse gas emissions and the purchase
# of UN carbon credits. As an RE100 participant, we have also set a goal of achieving 100% renewable energy at all
# of our Korean and overseas business sites by 2050.
# 02
# Circularity
# Waste Recycling · E-waste Collection and Recycling
# LG Electronics recycles waste generated at all of our Korean and overseas business sites and will expand the
# Zero Waste To Landfill Certificate for all of its global business sites. We achieved our goal of reaching a 95%
# waste recycling rate by 2030 ahead of schedule, and will maintain 95% or higher. We are also proactively
# complying with regulations in countries where we operate, establishing relevant policies and collecting e-waste.
# We use environmentally conscious materials for product manufacturing as well as packaging materials, and carry
# out campaigns to collect waste appliances and batteries.
# 03
# Clean Technology
# Developing Highly Efficient Products · Using Environmentally Conscious Materials
# LG Electronics is reducing GHG emission intensity at the product use stage through high-efficiency energy
# products. GHG emission intensity refers to the amount of greenhouse gases emitted per unit of product during
# the average lifetime of the product. For example, a refrigerator emits per liter of content, while a washing machine
# emits per kilogram of washing capacity. We became the first Korean home appliance company to receive SBTi
# (Science Based Targets initiative) verification of our product use stage carbon emission reduction targets.3C Strategies for the Planet
# Global renewable energy transition 10.1%   53,000 tons     YOY carbon emissions reduction
# Waste recycling rates of business  sites 95.5 %
# Cumulative collection of e-waste (Since 2006) 4.51 million tons
# Reduction of GHG emission intensity of
# seven major products at the product use stage 11.8 %
# Cumulative use of recycled plastic (Since 2021) 114,000 tons  ESG Strategy - For the Planet
# Performance in 20239
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# 01
# Decent Workplace
# Safety, Health, Labor, and Human Rights in Supply Chain
# LG Electronics takes its social responsibility to protect the safety and health of the working environment and human
# rights through the RBA1) management program at its production sites. By 2030, we aim to achieve zero critical non-
# conformances at 100% of production sites based on audit requirements, and we conduct self-assessments and on-
# site audits of suppliers to identify and improve potential and actual risks. We also evaluate the suitability of the ESG
# management of our suppliers and provide related training and consulting.
# 1) RBA: Responsible Business Alliance, The world's largest industry alliance for pursuing responsible business activities in global supply chains3D Strategies for People
# TV
# Listening to TV together, Learning
# remote control, Shortcuts to
# accessibility featuresCommon Braille sticker, product sign
# language video and voice manual,
# sign language counseling centers,
# digital human sign language guidance
# servicesHome Appliances
# 9 products with voice
# guidance, 5 products
# with voice recognitionPerformance in 2023
# 02
# Diversity & Inclusion
# Recruiting and Developing Female Talents and Expanding Hiring for People with Disabilities
# We strive to reflect diversity, equity, and inclusion (DEI) in our organizational culture so that all employees feel
# recognized, have a sense of belonging, and realize their potential. To this end, we have set a target of having 3.5%
# of employees with disabilities in Korea and 25.5% of female employees (on a global basis) by 2030.
# 03
# Design for All
# Improving Product and Service Accessibility
# LG Electronics is developing technologies to improve the accessibility of its products, and is working to improve
# service accessibility by providing sign language counseling services and Braille sticker attachment service to home
# appliances. Notably, we operate an accessibility advisory group to promote product development that considers
# the practical ease of use for users. We will apply accessibility technologies and universal design to all products
# released to provide ease of use for all users, including people with disabilities, seniors, and children.Percentage of female employees (Global) 22.0 %
# Employment rate of people with disabilities (Korea) 2.5%   Percentage of production sites with zero critical non-conformances
# (Based on RBA audit requirements) 80%    100 %    Ratio of ISO 45001 (Health and Safety Management System)
# certified production sites
# (Excluding new subsidiaries (2 in the US, 1 in Mexico) that have not started mass production.)
# 0.9%    Percentage of high-risk suppliers
# (Based on self-assessments)ESG Strategy - For People10
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# Energy
# Heating and Cooling Technologies Leading the Global HVAC Market
# LG Electronics leads the global heating, ventilation, and air conditioning (HVAC) market through the manufacturing
# commercial and residential heating and cooling solutions. We offer a wide range of high-quality products for
# heating, cooling, and ventilation, from personal devices to industrial and specialized HVAC systems.
# Efficient ESS with a High Level of Competence
# LG Electronics provides energy storage system (ESS) solutions with high-quality products and site-specific design
# and construction. By building the largest integrated test facility in Korea and introducing the ISO 9001 quality
# certification system for large-scale products, LG Electronics’ ESS has improved the efficiency of PCS (Power
# Conversion System) and minimized electricity losses. In addition, the high-quality batteries and sophisticated
# PMS (Power Management System) ensure both reliability and efficiency, and we were able to maximize the space
# efficiency in electrical rooms by reducing the product size by 70% compared to competitors. In recognition of this
# excellence, we have successfully completed the first ESS installation integrated with solar power in Korea. (Sejong
# Galaxy Solar Power Plant)Sustainable Business
# Vehicles
# Space-Customized EV Charging Solutions
# In March 2024, LG Electronics introduced three electric vehicle charging solutions (7kW slow charger, 100kW fast
# charger, and 200kW fast charger) optimized for various spaces, such as residential and commercial spaces and
# charging stations. The 7kW slow charger for residential use features a touchscreen for enhanced convenience
# and is available in both wall-mounted and free-standing models to fit a variety of installation environments.
# The 100kW fast charger allows for simultaneous charging (up to two vehicles), making it ideal for public parking
# lots at places such as shopping malls, hospitals, and restaurants, while the 200kW fast charger offers faster
# charging speeds and can be used at EV charging stations. LGE’s charging solutions also support stable charging in
# temperatures as low as minus 25 degrees Celsius and as high as 40 degrees Celsius, and are certified up to IP65
# for water and dust resistance and IK10 for shock resistance.
# Centralized Control Solution:
# AC Manager 5 External linkage solution:
# (BMS linkage system) ACP 5Individual Control Solution:
# AI Wireless Remote Controller
# EV Charging Solution11
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# Accessibility
# LG Comfort Kit to Help Make Appliances Easier to Use for Everyone
# Using an advisory group of people with physical disabilities, hearing impairments, visual impairments, and brain
# lesions, LG Electronics identified their challenges in using home appliances, analyzed them by user type and
# product, and developed the LG Comfort Kit, a practical modification that can be attached to existing products,
# and detached just as easily. The LG Comfort Kit incorporates universal design to make LG home appliances easy
# to use for all customers, regardless of gender, age, or disability.
# Voice-Recognition Water Purifier that Leaves No One Behind
# In a Korean first, LG Electronics launched the 'PuriCare Objet Collection Water Purifier' with a voice recognition
# feature, which not only allows users to dispense water in 10ml increments without pressing the button, but also
# monitors the amount of water they have consumed in the past week. This allows anyone to use the product
# conveniently, from people with visual impairments to the elderly who had difficulty using the product because the
# water purifier button was hard to see, to children who are too short to reach the dispensing button.Water, Waste and Ecosystem Restoration
# Water-Soluble Glass
# Changes in the marine environment are causing the ocean desertification, resulting in the disappearance of
# seaweeds such as wakame and kelp in coastal rocky areas, which is damaging the marine ecosystem. As part of
# its biodiversity conservation efforts, LG Electronics is developing a water-soluble glass that can contribute to the
# restoration of marine ecosystems. The water-soluble glass changes to a mineral ions when dissolved in water,
# which can be utilized to help algae grow in the ocean, restoring marine ecosystems.
# The water-soluble glass utilizes technology that consistently dissolves mineral ions, which are nutrients for algae,
# in water to promote the growth of algae in the ocean, much like fertilizer for crops on land, helping to restore
# marine forests. The increased amount of algae become an essential food source and habitat for other organisms
# in the marine ecosystem, creating the environment they need to thrive and grow. Algae also enhances the marine
# environment by absorbing carbon dioxide and releasing oxygen. Since 2023, we have been working with Ulsan
# National Institute of Science and Technology (UNIST), Research Institute of Industrial Science and Technology
# (RIST), and other specialized research institutes to demonstrate the safety of water-soluble glass and its
# effectiveness in promoting the growth of algae. We also signed an MOU with the Korea Polar Research Institute
# (KOPRI), a government-funded organization, to demonstrate its applicability and effectiveness in the Antarctic
# marine environment.
# Microplastics Care Course
# Washing clothes is essential to keep them clean and smelling good. However, washing clothes made of synthetic
# fibers releases microscopic plastic fibers into the water. This water is either discharged into the ocean, or treated
# and returned to water resources. LG Electronics has introduced an advanced microplastics care course to prevent
# the formation of microplastics by household laundry. The course utilizes LG’s 6-Motion (Tumble, Swing, Rolling,
# Stepping, Scrubbing and Filtration) technology to reduce fiber friction, prevent microplastics from forming, and
# minimize energy consumption.1) ThinQ UP washing machine users can download the microplastics care course
# from the Upgrade Center in the ThinQ app.
# 1)  Washing a 3-kilogram training jacket made of 100% polyester using the microplastics care course resulted in a 70% reduction in microplastics over
# 20㎛ compared to the standard wash course. The microplastics care course also reduced water temperature by 75% compared to the standard
# course, leading to a 30% reduction in energy use.
# LG Comfort Kit
# PuriCare Objet Collection Water PurifierSustainable Business Environmental
# Environmental Management Policy 13
#  Addressing Climate Change 15 Resource Circulation 18 Product Stewardship 23 Business Sites Operation 2612
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix13
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# Environmental Management Policy
# 1. Purpose
# As a responsible corporate citizen, LG Electronics is committed to environmental protection throughout all its
# business activities. We adhere to the highest environmental standards and international agreements, and we
# continuously strive to minimize our environmental impact through ongoing improvements. Aligned with the UN
# Sustainable Development Goals (SDGs), we have established ambitious goals for reducing our environmental
# footprint and have enacted this Environmental Policy to guide our efforts.
# 2. Coverage
# LG Electronics applies the most stringent standards when environmental laws and regulations in different
# countries conflict.
# ① Production operations and business facilities
# ② Products and services
# ③ Distribution and logistics
# ④ Management of waste
# ⑤ Suppliers, Service Providers, Contractors, and Other Key Business Partners
# ⑥ Mergers, Acquisitions, and New Businesses
# 3. Principles
# To promote environmental management, LG Electronics defines the following fundamental principles for each
# environmental topic.
# ① Air Pollutants
# ·  Identify the types, characteristics, and emissions volume of air pollutants generated our operations and treat
# them according to regulations before discharge. Effective manage ozone-depleting substances in accordance
# with the Montreal Protocol and relevant regulations, and continuously monitor the treatment efficiency of
# pollution control facilities.
# ② Water Pollutants
# ·  Treat all wastewater according to regulations before discharge, and continuously monitor treatment results to
# ensure that the emission of water pollutants is always within the standard limits.Environmental Management Policy
# ③ Hazardous Substance
# ·  Identify and record all chemicals (including hazardous waste) that are hazardous to human health or have the
# potential to cause environmental pollution when released from our workplaces, and safely store, transport,
# use, recycle/reuse, and dispose of these substances. Establish emergency response plans and conduct regular
# training to prevent environmental pollution and accidents caused by leaks or spills during handling.
# ·  LG Electronics products are managed Guidelines for hazardous substance management in products to ensure
# that they do not contain substances prohibited by global conventions or pose a risk to human health.
# ④ Waste
# ·  Identify the types, characteristics, and emission quantities of waste generated at our facilities and treat
# and dispose of it in compliance with regulations. Strive to reduce waste generation. Select waste disposal
# contractors (including transporters) that are legally qualified to transport and dispose of waste after evaluating
# their suitability (including on-site inspections). Minimize the proportion of waste landfilled or incinerated and
# strive to improve the recycling rate of waste.
# ·  Consider the enhancement of reusability and recyclability from the product development stage and strive for
# the lawful collection and treatment of end-of-life products to minimize environmental impact.
# ⑤ Energy
# ·  Monitor energy consumption and greenhouse gas emissions to improve energy efficiency at our facilities and
# continuously review ways to enhance efficiency. Promote energy-saving activities. Strive to use sustainable
# energy by implementing renewable energy solutions tailored to our facilities’ conditions, such as installing
# renewable energy generation facilities, purchasing renewable energy certificates, and entering into power
# supply contracts.
# ⑥ Greenhouse Gas
# ·  Actively respond to climate change by developing and implementing effective greenhouse gas reduction
# measures and setting targets. Publicly disclose performance and reduction efforts for energy consumption and
# significant categories of Scope 1,2, and 3 emissions.14
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# ⑦ Water Resource
# ·  Explore ways to reduce and reuse water consumption. Implement activities to identify and mitigate water
# scarcity risks.
# ⑧ Biodiversity Conservation
# ·  Strive to conserve and restore biodiversity within LG Electronics' sphere of influence.
# ⑨ Preventing Deforestation
# ·  Recognize the potential for deforestation issues that may arise within LG Electronics' sphere of influence and
# strive to minimize negative impacts.
# 4. Management System
# ① Role of the Board of Directors and Top Management
# LG Electronics ensures the oversight of all environmental management and performance improvement
# activities through the ESG Committee within the Board of Directors and management meetings involving top
# management. The ESG Committee within the Board of Directors reviews and deliberate on environmental
# management policy revisions, responses to environmental laws and regulations, and environmental
# management performance, including climate response, at least once a year. The main roles of the management
# meeting involving top management include reviewing and deciding on environmental management risk reviews
# and response measures, as well as other matters deemed necessary for the dissemination/propagation of
# environmental management.
# ② Roles of the Dedicated Organization
# LG Electronics designates an environmental management implementation organization to carry out related
# tasks. The environmental management implementation organization reviews environmental laws and
# regulations, stakeholder requirements, and prepare response measures; establish and operate environmental
# management goals and indicators; build and operate environmental management systems; and conduct
# education and awareness improvement for major stakeholders and information disclosure.
# 5. Education and Awareness Improvement
# LG Electronics operates education programs for employees and key stakeholders to comply with this policy, share
# information on environmental policies, goals, and performance. Through this, the company raise awareness of
# environmental management and encourage employees to prioritize the environment in their work processes.6. Information Disclosure and Communication
# LG Electronics transparently disclose environmental information related to products and business sites, as well
# as environmental policies and implementation plans, through its website, sustainability reports, and other means.
# The company also communicate with employees and stakeholders on environmental management performance
# and environmental policies, and reflect their opinions to continuously improve policies.
# 7. Performance Evaluation and Improvement
# LG Electronics sets and implement medium- to long-term performance goals for its environmental factors based
# on environmental policies. The company regularly evaluates the progress of goal implementation and check goal
# achievement, analyze the evaluation results to identify areas for policy improvement, and adjust goals according
# to the situation.
# Number of ISO 14001 Certified Production Sites
# (As of 2023)
# 100%Certification
# Acquisition RateClassification Acquisition / Renewal Total
# Korea 5 5
# Overseas 25 25*
# * Excluding new subsidiaries (2 in the US and 1 in Mexico) that have not started mass production.Environmental Management System (ISO 14001) Certification
# To efficiently manage environmental risks by systematically identifying, evaluating, managing, and improving the
# elements necessary for environmental management, LG Electronics has acquired ISO 14001 certification for all its
# Korean and overseas production sites, which it has kept up-to-date.Environmental Management Policy15
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# Reducing GHG and Carbon Emissions
# Creating and Implementing a GHG Reduction Plan
# To address climate change, LG Electronics has set GHG reduction targets for the entire lifecycle of its products, from
# the production to use stage. We aim to reduce the total amount of direct GHG emissions (Scope 1) and indirect GHG
# emissions (Scope 2) in the product production stage by 54.6% by 2030 compared to 2017 levels in accordance with the
# SBTi's criteria, and reduce GHG emissions intensity in the product use stage by 20% by 2030 compared to 2020 levels.
# To objectively ensure the achievement of these GHG reduction goals are being achieved, in 2021 LG Electronics
# became the first Korean company in the home appliance industry to declare its GHG reduction targets to
# the Science Based Targets Initiative (SBTi) and have them verified by a third party. Since then, we have been
# systematically managing the progress towards the targets submitted to SBTi, and are continuously implementing
# various strategies and activities in this area.
# Reducing GHG Emissions in the Product Production Stage
# To reduce greenhouse gas emissions during the product production stage, LG Electronics has implemented
# energy-efficient equipment and carbon emission reduction devices to our manufacturing process. We have
# implemented a system to recover and recycle refrigerant that escapes during the injection of HFC-based
# refrigerants, and reuse the recovered refrigerant, thereby reducing refrigerant leakage.LG Electronics GHG Reduction PlanAddressing Climate Change
# ·  Aim to reduce GHG emissions
# by 54.6% by 2030 compared to
# 2017, in accordance with the SBTi's
# criteria·  Promote carbon credit CDM1)
# project through sales of high-
# efficiency products
# ·  Cumulative 560,000 tons of carbon
# credits issued as of 2020, with
# more to be secured by 2025·  Reduce GHG emission intensity of
# seven major product categories by
# 20% by 2030 compared to 2020Reducing GHG
# emissions from
# production stageReducing GHGs in
# the product use
# stageImplementing
# external GHG
# reduction project
# 1) CDM: Clean Development MechanismPromoting External GHG Reduction Projects
# LG Electronics is promoting a CDM project in India that converts the electricity savings from the usage of high-
# efficiency refrigerators into carbon credits. Since receiving approval for the project from the United Nations
# Framework Convention on Climate Change (UNFCCC) in 2013, we have secured 560,000 tons of carbon credits
# by 2020, and plan to secure additional credits by 2025. This equates to a reduction in electricity usage of 125
# GWh through the use of our high-efficiency refrigerators. Cumulatively, the project is expected to secure 2 million
# tons of carbon credits.
# Year Unit Direct GHG Emission (Scope 1) Indirect GHG Emission (Scope 2) Scope 1+2
# 2019
# 1,000
# tCO2eq604 869 1,473
# 2020 429 865 1,294
# 2021 333 819 1,152
# 2022*265 662 928
# 2023 209 665 874
# 2030 Goal 923 (54.6% reduction compared to 2017, in accordance with SBTi criteria)Global GHG Emissions
# * Data corrected due to changes in processing of significant figures16
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# Reducing GHG Emissions at the Product Use Stage
# LG Electronics is undertaking various efforts to reduce GHG emissions at each stage of the product life cycle.
# These efforts include reducing product weight, conserving resources, and improving energy efficiency. Notably, we
# are developing and selling energy-efficient products to reduce GHG emissions during the product use stage, and
# are expanding the launch of products that incorporate highly energy-efficient technologies. We also calculate and
# disclose GHG emissions generated during the product use stage for our flagship products.
# We have developed a Technology Road Map (TRM) that serves as the foundation for setting and implementing
# specific targets to improve the energy efficiency of each product category. Additionally, we are committed to
# enhancing energy efficiency by establishing our own energy efficiency targets and detailed strategies, while
# complying with global energy regulations such as the EU’s Ecodesign Regulation.1)
# We have set a goal to reduce carbon emissions intensity during the product use stage by 20% by 2030, compared
# to 2020 levels, for all global sales models in our seven major product categories (TVs, refrigerators, washing
# machines, dryers, residential air conditioners, system air conditioners, and monitors). Given that as of 2021, these
# seven major product categories accounted for approximately 90% of the carbon emissions generated by all our
# products in the product use stage, we are actively promoting substantial carbon emission reductions through our
# various initiatives to reduce carbon emissions and improve energy efficiency.
# 1)  EU Ecodesign Regulation: Environmental and energy efficiency regulations that manufacturers, distributors, and sellers must comply with from the
# design stage of their productsAnnual GHG Emissions during the Product Use Stage
# Key Reduction AchievementsYear 2021 2022 2023
# Reduction ratio compared to 2020 6.6% 13.1% 11.8%
# Reducing GHG Emissions during the Product Distribution Stage
# To reduce carbon emissions during the the product distribution stage, we are collaborating with distribution
# company LX Pantos to reduce their GHG emissions.
# Measurement, Reporting and Verification of GHG Emissions
# As a company regulated under Article 27 of the Framework Act on Carbon Neutrality and Green Growth for
# Coping with the Climate Crisis, LG Electronics submits emission statements to the government and discloses
# related information after third-party verification of GHG emissions and energy consumption in accordance with
# Article 27 (3) of the Act. We have established a greenhouse gas inventory for our global production sites and
# disclose our GHG emissions annually.
# Introducing Carbon Accounting and Carbon Pricing
# LG Electronics analyzes its carbon credit allocations and actual emissions on a quarterly basis, and records
# emission liabilities in the consolidated statement of financial position when our emissions exceed the allocated
# amounts. We also set an internal carbon price to identify business opportunities and assess risks related to
# energy savings and GHG reduction activities. This metric, which quantifies the value of carbon for internal trading,
# measures the financial impact of the environmental burden incurred by LG Electronics, and is used to make
# rational investment decisions for reducing GHG emissions.LX Pantos Climate Change Response
# Power
# consumption
# 40%  Washing
# machine
# (F4WR9009S2W,
# 2023 model)Power
# consumption
# 35.8%  Dryer
# (RD21ES,
# 2023 model)Power
# consumption
# 3.7%  Air
# conditioner
# (All air conditioning
# models, 2023 model)·  In 2023, we developed an optimal wash volume control algorithm utilizing TurboWash 360 technology achieving a
# power consumption reduction of approximately 40% for new washing machines sold in the European market
# (from 50 kWh to 30 kWh per 100 cycles).
# ·  We achieved a 3.7% reduction in monthly power consumption1) by switching the refrigerant used (R401a ▶ R32) and
# optimizing the cooling cycle of the 2023 stand air conditioner in the Korean market.
# ·  We developed a DD motor dryer with 6 Motion drying technology achieving a 35.8% reduction in power consumption
# compared to our previous dryer in the Korean market as of the 2023 model.
# 1) Monthly power consumption comparison for 2022 and 2023 models (sales-weighted average)Addressing Climate Change17
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# Energy Management
# 100% Conversion into Renewable Energy (2050)
# LG Electronics joined RE100 (Renewable Energy 100) in June 2023 with commitment to a gradual transition to
# 100% renewable energy by 2050. In accordance with our mid- to long-term plan to convert to 100% renewable
# energy, we will gradually increase our use of renewable energy, considering the current status of our Korean and
# overseas operations and the relevant laws and regulations. Aiming to achieve 60% renewable energy by 2030,
# 90% by 2040, and 100% by 2050, we are exploring various options for purchasing renewable power, including a
# green pricing, EACs (Energy Attribute Certificates) purchasing, and third-party PPAs.1)
# In 2023, we secured a 55 MW solar power generation capacity through self-generation and PPA1) contracts,
# capable of generating 58,900 MWh of electricity annually.
# Additionally, we are introducing approximately 44,000 MWh of renewable energy annually through wind and
# hydropower. In 2024, we have promoted solar power generation of 11 MW (16,500 MWh/year) through an equity
# investment in our Indian production subsidiary.
# 1) PPA: Power Purchase Agreement, a contract between a power producer and a power consumer to purchase electricity for a fixed period of time.
# Global Renewable Energy Status
# In 2023, LG Electronics’ global business sites purchased and generated 126,410 MWh of renewable energy
# through PPAs (solar, wind, hydropower), EACs purchasing (wind, hydropower, biomass), and self-generation, which
# accounted for 10.1% of our global electricity consumption.
# Renewable Energy Transition of Global Business SitesNew PPA Contract for Overseas Production Sites in 2023
# Classification Unit 2021 2022 2023
# PPA
# MWh- 36,786 56,110
# EACs 64,588 58,961 65,159
# Self-generation 5,113 4,336 5,141
# Total 69,701 100,083 126,410
# Transition Rate % 4.6 8.2 10.1Classification Production Sites Generation Capacity (MW) Annual Power Generation (MWh)
# SolarChinaNanjing PN 6.8 5,200
# Tianjin 10.0 12,000
# Taizhou             7.0          6,539
# Thailand 3.2 4,365
# Vietnam 17.5 17,568
# Wind China Qinhuangdao - 10,000
# Total 44.5 55,672
# Energy Consumption Management System at Global Production Sites
# LG Electronics operates a global energy consumption management system to monitor and manage the amount
# and cost of each type of energy used in its Korean and overseas business sites on a monthly basis. This data is
# utilized to calculate Scope 1 and 2 GHG emissions, and serves as a foundation for establishing and operating
# energy-efficient production facilities within our subsidiaries.
# Energy Management System (ISO 50001) Certification
# LG Electronics is continuously expanding its acquisition of ISO 50001 certification to reduce energy consumption,
# improve efficiency, and systematize management at both Korean and overseas business sites. To ensure
# continuous and standardized management, we have established the 'Energy and Greenhouse Gas Management
# Standards and Rules' and will enhance our energy management by regularly inspecting and auditing the energy
# management systems at our business sites.
# Number of ISO 50001 Certified Production Sites
# (As of 2023)
# 63%Certification
# Acquisition RateClassification Acquisition / Renewal Total
# Korea 5 5
# Overseas 14 25*· Changwon Smart Park: utilized 2.3 MW of renewable power through Korea’s first off-grid PPA
#  · Pyeongtaek Digital Park: introduced 1.4MW of solar power
# * Excluding new subsidiaries (2 in the US, 1 in Mexico) that have not started mass production.Addressing Climate Change18
# 2023-2024 LG Electronics Sustainability Report Overview Environmental Social Governance ESG Data Appendix
# K-EV100 Declaration and Implementation
# LG Electronics is participating in the ‘K-EV1001)’ campaign led by the Ministry of Environment since April 2021.
# Following the K-EV100 declaration, we plan to gradually increase the proportion environment-friendly motor vehicles2)
# ...
# the basis set out within the guidelines on the operation of GHG emission trading scheme (“ETS) (Notification No.
# 2023-221 of Ministry of Environment)’. Our responsibility in performing this work is to the management of LG
# Electronics only and in accordance with terms of reference agreed with them. DNV expressly disclaims any liability
# or responsibility for any decisions, whether investment or otherwise, based upon this assurance statement.
# Scope of Assurance
# The GHG emissions data covered by our examination comprise Direct emissions (Scope 1 emissions) and Energy
# indirect emissions (Scope 2 emissions) from LG Electronics’ boundary of the report ;
# ·  Organizational boundary for reporting: Korean business sites of LG Electronics (Fugitive emissions form refrigerant are
# included1))
# 1) Limited level of assurance is only covered for Fugitive emission by purchasing of refrigerant in Direct emissions.
# Verification Approach
# The verification has been conducted by DNV on February to March 2024 and performed in accordance with the
# verification principles and tasks outlined in the guidelines on the operation of GHG ETS (Notification No. 2023-221,
# Korean Ministry of Environment) and the verification guideline for GHG ETS (Notification No. 2021-112, Korean
# Ministry of Environment). We planned and performed our work to obtain all the information and explanations
# deemed necessary to provide us with sufficient evidence to provide a reasonable verification opinion concerning
# the completeness of the emission inventory as well as the reported emission figures in ton CO2 equivalent. As
# part of the verification process;
# · We have reviewed and verified the GHG emissions report for the calendar year 2023
# ·  We have reviewed and verified the process to generate, aggregate and report the emissionsGreenhouse Gas Emissions of LG Electronics Korean business site for Yr 2023
# LG Electronics
# (Domestic, in Korea)Direct Emissions (Scope 1) Indirect Emissions (Scope 2) Total Emissions
# Excl. Refrigerant 30,693
# 217,159247,852
# Incl. Refrigerant 74,787* 291,946(Unit: ton CO2 equivalent)
# May 2024
# Seoul, Korea
# Jang-Sub Lee
# Country Representative
# DNV Business Assurance Korea Ltd.
# * Fugitive emission (44,094 tCO2eq) by purchasing of refrigerant is included in Direct emissions.Conclusions
# As a result of the work described above, in our opinion nothing has come to our attention that would cause us to
# believe that the GHG emissions set out in LG Electronics’ report are not fairly stated. The GHG emissions of LG
# Electronics for the year 2023 were confirmed as below;147
# Overview Environmental Social Governance ESG Data Appendix 2023-2024 LG Electronics Sustainability Report
# Introduction
# DNV Business Assurance Korea Ltd. (“DNV”) was commissioned by LG Electronics Inc. (“Company”) to perform
# third party verification for the Company’s Greenhouse Gas Inventory Report (“the report”) in the calendar year
# 2023. The Company is responsible for the preparation of the GHG emissions data on the basis set out within the
# ‘ISO 14064-1:2018, The GHG Protocol: A corporate reporting and accounting standard and 2006 IPCC Guidelines
# for National Greenhouse Gas Inventories’. Our responsibility in performing this work is to the management of the
# Company only and in accordance with terms of reference agreed with them. DNV expressly disclaims any liability
# or responsibility for any decisions, whether investment or otherwise, based upon this assurance opinion.
# Objectives and scope of verification
# The purpose of this verification is to present an independent verification opinion on the company's greenhouse
# gas emissions, and the scope of verification is as follows;
# · Organizational Boundary: 26 overseas business sites of the company
# · Operational Boundary: Scope 1 (Direct emissions) & Scope 2 (Indirect emissions)
# · Reporting period: 2023.01.01 ~2023.12.31
# Verification Approach
# The verification has been conducted in accordance with the verification principles and tasks outlined in the ‘ISO
# 14064-3:2019’, based upon a limited level of assurance. We planned and performed our work so as to obtain all
# the information and explanations deemed necessary to provide us with sufficient evidence to provide a verification
# opinion with 5% materiality level, concerning the completeness of the emission inventory as well as the reported
# emission figures in ton CO2 equivalent. As part of the verification process, we have reviewed as follows;
# · Process to generate, aggregate and report the emissions data
# ·  The data and information supporting the report were based on historical in nature. These may include partially hypothetical
# and projected data and information (refer to the report for details)Greenhouse Gas Emissions of LG Electronics overseas business sites for Yr 2023
# LG Electronics Direct Emissions (Scope 1) Indirect Emissions (Scope 2) Total Emissions
# Overseas business
# sites126,738*448,125 574,863(Unit: ton CO2 equivalent)
# 13th May 2024
# Seoul, Korea
# Jang-Sub Lee
# Country Representative
# DNV Business Assurance Korea
# * Fugitive emission (68,437 tCO2eq) by purchasing of refrigerant is included in Direct emissions.
# ※  In order to report the GHG emissions as an integer, the rounded number on the opinion might be different from the number on the system with
# ± 1 tCO2eqConclusions
# Based on the process and procedures conducted, there is no evidence that the GHG statement is not materially
# correct and is not a fair representation of GHG data and information;
# · DNV presents an ‘Unmodified’ opinion on Greenhouse Gas EmissionsGreenhouse Gas Verification Statement148
# Overview Environmental Social Governance ESG Data Appendix 2023-2024 LG Electronics Sustainability Report
# Introduction
# DNV Business Assurance Korea Ltd. (“DNV”) was commissioned by LG Electronics Inc. (“Company”) to
# perform third party verification for the Company’s Greenhouse Gas Inventory (“the inventory”). The Company
# is responsible for the preparation of the GHG emissions data on the basis set out within the ‘WRI/WBCSD
# GHG Protocol: A Corporate Accounting and Reporting Standard (2004)’, The Corporate Value Chain (Scope 3)
# Accounting and Reporting Standard’ and ‘2006 IPCC Guidelines for National Greenhouse Gas Inventories’. Our
# responsibility in performing this work is to the management of the Company only and in accordance with terms
# of reference agreed with them. DNV expressly disclaims any liability or responsibility for any decisions, whether
# investment or otherwise, based upon this verification opinion.
# Objectives and scope of verification
# The purpose of this verification is to present an independent verification opinion on the company's greenhouse
# gas emissions, and the scope of verification is as follows;
# · Organizational Boundary: LG Electronics Inc.
# · Operational Boundary: Scope 3 (Other indirect emissions)
# - Upstream: 8 Categories - 1, 2, 3, 4, 5, 6, 7, 8
# - Downstream: 5 Categories - 10, 11, 12, 13, 15
# · Reporting period: 2023.01.01 ~2023.12.31
# Verification Approach
# The verification has been conducted in accordance with the verification principles and tasks outlined in the ‘ISO
# 14064-3:2019’, based upon a limited level of assurance. We planned and performed our work so as to obtain
# all the information and explanations deemed necessary to provide us with sufficient evidence to provide a
# verification opinion with 5% materiality level, concerning the completeness of the emission inventory. As part of
# the verification process, we have reviewed as follows;
# · Process to generate, aggregate and report the emissions data
# ·  The data and information supporting the report were based on historical in nature. May include partially
# hypothetical and projected data and information (refer to the inventory for details)Other indirect emissions (Scope 3: Category 11) of LG electronics
# Other indirect emissions (Scope 3) of LG Electronics in 2023Annex to ‘PRJN-704268-2024-AST-ENG’Year Upstream Downstream Total Emissions
# 2023 5,340,780 64,884,353 70,225,133
# Categories Upstream Downstream Emissions
# 1 Purchased goods and services 2,807,879 2,807,879
# 2 Capital goods 400,997 400,997
# 3  Fuel- and energy- related activities (not included in
# Scope 1 or Scope 2)135,070 135,070
# 4 Upstream transportation and distribution 1,794,560 1,794,560
# 5 Waste generated in operation 12,769 12,769
# 6 Business travel 46,073 46,073
# 7 Employee commuting 78,055 78,055
# 8 Upstream leased assets 65,377 65,377
# 10 Processing of sold products 37,810 37,810
# 11 Use of sold products 61,207,842 61,207,842
# 12 End-of-life treatment of sold products 1,153,377 1,153,377
# 13 Downstream leased assets 3,005 3,005
# 15 Investments 2,482,319 2,482,319
# Total emissions 5,340,780 64,884,353 70,225,133(Unit: ton CO2eq)
# (Unit: ton CO2eq)※  In order to report the GHG emissions as an integer, the rounded number on the opinion might be different from the number on the system with
# ± 1 tCO2eq
# ※ Refer to Annex for greenhouse gas emissions by categories.
# 28th June 2024
# Jang-Sub Lee
# Country Representative
# DNV Business Assurance Korea
# ※ In order to report the GHG emissions as an integer, the rounded number on the statement might be different with ± 1 tCO2eq.
# Conclusions
# Based on the process and procedures conducted, there is no evidence that the inventory is not materially correct
# and is not a fair representation of GHG data and information;
# · DNV presents an ‘Unmodified’ opinion on Greenhouse Gas EmissionsGreenhouse Gas Verification Statement149
# Overview Environmental Social Governance ESG Data Appendix 2023-2024 LG Electronics Sustainability Report
# Independent Assurance Statement
# To readers of LG Electronics Sustainability Report 2023-2024
# Introduction
# Korea Management Registrar (KMR) was commissioned by LG Electronics to conduct an independent assurance
# of its Sustainability Report 2023-2024 (the “Report”). The data and its presentation in the Report is the sole
# responsibility of the management of LG Electronics. KMR’s responsibility is to perform an assurance engagement
# as agreed upon in our agreement with LG Electronics and issue an assurance statement.
# Scope and Standards
# LG Electronics described its sustainability performance and activities in the Report. Our Assurance Team carried
# out an assurance engagement in accordance with the AA1000AS v3 and KMR’s assurance standard SRV1000. We
# are providing a Type 2, moderate level assurance. We evaluated the adherence to the AA1000AP (2018) principles
# of inclusivity, materiality, responsiveness and impact, and the reliability of the information and data provided using
# the Global Reporting Initiative (GRI) Index provided below. The opinion expressed in the Assurance Statement has
# been formed at the materiality of the professional judgment of our Assurance Team.
# Confirmation that the Report was prepared in accordance with GRI standards 2021 was included in the scope
# of the assurance. We have reviewed the topic-specific disclosures of standards which were identified in the
# materiality assessment process
# • GRI Sustainability Reporting Standards 2021
# • Universal standards
# • Topic specific standards
# - GRI 205: Anti-corruption
# - GRI 302: Energy
# - GRI 303: Water and Effluents
# - GRI 305: Emissions
# - GRI 306: Waste
# - GRI 401: Employment
# - GRI 403: Occupational Health and Safety
# - GRI 404: Training and Education
# - GRI 405: Diversity and Equal Opportunity
# - GRI 406: Non-discrimination
# - GRI 408: Child Labor
# - GRI 409: Forced or Compulsory Labor- GRI 414: Supplier Social Assessment
# - GRI 416: Customer Privacy
# • Etc. Material Issue
# - Material Topic Issue
# - The Data of Supply Chain Management
# - Voice of Customer
# - Health and Safety (Dead rate, LTIFR)
# As for the reporting boundary, the engagement excludes the data and information of LG Electronics’s partners,
# suppliers and any third parties.
# KMR's Approach
# To perform an assurance engagement within an agreed scope of assessment using the standards outlined above,
# our Assurance Team undertook the following activities as part of the engagement:
# • reviewed the overall Report;
# • reviewed materiality assessment methodology and the assessment report;
# • evaluated sustainability strategies, performance data management system, and processes;
# • interviewed people in charge of preparing the Report;
# • reviewed the reliability of the Report's performance data and conducted data sampling;
# •  assessed the reliability of information using independent external sources such as Financial Supervisory Service’s DART and
# public databases.
# Limitations and Recommendations
# KMR’s assurance engagement is based on the assumption that the data and information provided by LG
# Electronics to us as part of our review are provided in good faith. Limited depth of evidence gathering including
# inquiry and analytical procedures and limited sampling at lower levels in the organization were applied. To address
# this, we referred to independent external sources such as DART and National Greenhouse Gas Management
# System (NGMS) and public databases to challenge the quality and reliability of the information provided.150
# Overview Environmental Social Governance ESG Data Appendix 2023-2024 LG Electronics Sustainability Report
# Conclusion and Opinion
# Based on the document reviews and interviews, we had several discussions with LG Electronics on the revision
# of the Report. We reviewed the Report’s final version in order to make sure that our recommendations for
# improvement and revision have been reflected. Based on the work performed, it is our opinion that the Report
# applied the GRI Standards. Nothing comes to our attention to suggest that the Report was not prepared in
# accordance with the AA1000AP (2018) principles.
# Inclusivity
# LG Electronics has developed and maintained different stakeholder communication channels at all levels to
# announce and fulfill its responsibilities to the stakeholders. Nothing comes to our attention to suggest that there
# is a key stakeholder group left out in the process. The organization makes efforts to properly reflect opinions and
# expectations into its strategies.
# Materiality
# LG Electronics has a unique materiality assessment process to decide the impact of issues identified on its
# sustainability performance. We have not found any material topics left out in the process.
# Responsiveness
# LG Electronics prioritized material issues to provide a comprehensive, balanced report of performance, responses,
# and future plans regarding them. We did not find anything to suggest that data and information disclosed in the
# Report do not give a fair representation of LG Electronics’s actions.
# Impact
# LG Electronics identifies and monitors the direct and indirect impacts of material topics found through the
# materiality assessment, and quantifies such impacts as much as possible. Reliability of Specific Sustainability Performance Information
# In addition to the adherence to AA1000AP (2018) principles, we have assessed the reliability of economic,
# environmental, and social performance data related to sustainability performance. We interviewed the in-charge
# persons and reviewed information on a sampling basis and supporting documents as well as external sources and
# public databases to confirm that the disclosed data is reliable. Any intentional error or misstatement is not noted
# from the data and information disclosed in the Report.
# Competence and Independence
# KMR maintains a comprehensive system of quality control including documented policies and procedures in
# accordance with ISO/IEC 17021·2015 - Requirements for bodies providing audit and certification of management
# systems. This engagement was carried out by an independent team of sustainability assurance professionals.
# KMR has no other contract with LG Electronics and did not provide any services to LG Electronics that could
# compromise the independence of our work.
# June 2024 Seoul, Korea
# Independent Assurance Statement

# %% [markdown]
# ### Pros and Cons (PyPDF2):
#
# Pros:
# - It works well if the document is single-column, no table (fast and effective). But often times this is not the case.
# - You can rotate pages, split PDF into multiple pages, merge multiple PDFs.
#
# Cons:
# - PDFMiner is not an OCR reader, hence it cannot capture texts on scanned images of text
# - Slower than pdfminer
# - Inconsistent Extraction Accuracy

# %% [markdown]
# ## Pytersseract

# %%
from pdf2image import convert_from_path
import cv2
import numpy as np
import pytesseract


# Replace 'input_file.pdf' with the path to your PDF file
input_pdf_path = "/Users/jeremiahtay/DSA3101/2023-2024_Sustainability_Report_(ENG)_.pdf"
pages = convert_from_path(input_pdf_path)

def deskew(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.bitwise_not(gray)
    coords = np.column_stack(np.where(gray > 0))
    angle = cv2.minAreaRect(coords)[-1]
    
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle

    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated


def extract_text_from_image(image):
    text = pytesseract.image_to_string(image)
    return text

# Create a list to store extracted text from all pages
extracted_text = []

for page in pages:
    # Step 2: Preprocess the image (deskew)
    preprocessed_image = deskew(np.array(page))

    # Step 3: Extract text using OCR
    text = extract_text_from_image(preprocessed_image)
    extracted_text.append(text)


def process_page(page):
    try:
        # Transfer image of pdf_file into array
        page_arr = np.array(page)
        # Transfer into grayscale
        page_arr_gray = cv2.cvtColor(page_arr, cv2.COLOR_BGR2GRAY)
        # Deskew the page
        page_deskew = deskew(page_arr_gray)
        # Cal confidence value
        page_conf = get_conf(page_deskew)
        # Extract string
        d = pytesseract.image_to_data(page_deskew, output_type=pytesseract.Output.DICT)
        d_df = pd.DataFrame.from_dict(d)
        # Get block number
        block_num = int(d_df.loc[d_df['level'] == 2, 'block_num'].max())
        # Drop header and footer by index
        header_index = d_df[d_df['block_num'] == 1].index.values
        footer_index = d_df[d_df['block_num'] == block_num].index.values
        # Combine text in dataframe, excluding header and footer regions
        text = ' '.join(d_df.loc[(d_df['level'] == 5) & (~d_df.index.isin(header_index) & ~d_df.index.isin(footer_index)), 'text'].values)
        return page_conf, text
    except Exception as e:
        # If can't extract then give some notes into df
        if hasattr(e, 'message'):
            return -1, e.message
        else:
            return -1, str(e)


combined_text = " ".join(extracted_text)
output_file_path = "/Users/jeremiahtay/DSA3101/LG_Sustainability Report.txt"

# Open the file in write mode and save the text
with open(output_file_path, "w") as file:
    file.write(combined_text)

print(combined_text)
# Out:
# LG Electronics Sustainability Report
#
# BETTER
#
# LIFE
#
# FOR ALL
#
# Life’s
# Good.
#  cs Sustainability Report [overview Environmental Social Governance ESG Data AY
# ts
#
# Environmental 12 ~~ Social 29 Governance 80 ESG Data 100 = Appendi:
#
# 3 Environmental Management Policy 13 Human Rights 30 Corporate Governance 81 Sustainability Management Data 101 GRI Inde»
#
# 4 Addressing Climate Change 15 Employee 44 — Jeong-Do Management 86 = Membership-Awards & Recognition 124 — SASB Ind
#
# 8 Resource Circulation 18 Supply Chain 56 Compliance Management 88  SHEE-Quality Certification Status 125 UN SDGs
#
# 10 Product Stewardship 23. Customer 66 — Risk Management 92 Materiality Assessment 126 ~—TCFD Ref
#
# Business Sites Operation 26 ~~ Local Community 75 Information Security 95 Stakeholder Communication 129 Greenhot
#
# Statemer
#
# Independ
#
# its commitment to making changes that will help it to achieve sustainable growth and
# tablished and implemented goals and action plans to realize them. In the Sustainability
# its management approach (MA), goals, activities, progress, and performance on tasks and
# onment, society, and governance. These are linked to the material issues derived from the
# Electronics’ six ESG strategic tasks. LG Electronics will continue to transparently disclose
# ctivities and performance through the publication of this report each year.
#
# indards
#
# stainability Report adheres to GRI Standards 2021, an international standard guideline,
# dards and frameworks set forth by the Sustainability Accounting Standards Board (SASB)
# related Financial Disclosures (TCFD). We also reported out progress in implementing The
# ations Global Compact (UNGC) in four areas: human rights, labor, environment, and anti-
# st the four principles of inclusivity, materiality, responsiveness, and impact as outlined in
# y Principles Standard), which also outlines the obligation of companies to disclose their
# nagement.
#
# Reporting Period
# This report covers our activities from January 2023 through December 2023, and for some key
# through the first half of 2024. For quantitative performance, we provide three years of data fror
# performance trends,
#
# Scope of Report
#
# The scope of this report covers the headquarters, production sites in Korea and overseas,
# by LG Electronics. Financial information is presented on a consolidated financial statement t
# International Financial Reporting Standards (K-IFRS), and some financial information pr
# statement basis is presented in the footnotes. All financial information in USD has been calc
# exchange rate. Where there are limitations in data collection or changes to the calculati
# reporting scope and the reason for the change in the footnotes.
#
# Third Party Assurance
#
# To ensure the accuracy, objectivity and reliability of the report preparation process and
# Electronics commissioned an independent assurance organization (Korea Managemer
# assurance in accordance with international assurance standards. The results of the third-
# in detail on page 149 of this report. The financial information in this report has beer
#
# of greenhouse gas emissions and energy usage was conducted in accordance with tt
#
# Administrative Guideline for the Greenhouse Gas Target Management System,
#  cs Sustainability Report
#
# e CEO
#
# Social Governance
#
# ESG Data A
#
# mpany, LG Electronics will promote sustainable management to ensure a ‘Better Life for All’
#
# akeholders,
#
# plagued the global market with prolonged
# 2S, leading to a slowdown in consumption.
# scarbonization and digital transformation
# and customers are pursuing engagement-
# S experience consumption. To proactively
# ; in the market and with customers,
# sion last year to transform from a ‘Global
# d' to a ‘Smart Life Solution Company’ that
#
# se experiences of customers.
# 2 appliances to a Smart Life Solution
#
# iture, LG Electronics is focusing on the
# n, digitalization and electrification. During
# vew touch points and pursue changes to
# 3C 2S' (Connectivity, Care, Customization,
# erience area. In particular, we will focus on
# 1odels, growing B2B business, and securing
# ree pillars to expand customer touchpoints
# ial front, we wi
#
# )30, achieving the ‘Triple 7’ goal (CAGR and
#
# 1g 7%, and enterprise value greater than 7x).
#
# leap forward to become a
#
# rowth, LG Electronics conducts ESG
#
# of a ‘Better Life for All’ We have chosen
#
# rcularity, Clean Technology) for the planet
#
# and the 3Ds (Decent Workplace, Diversity & Inclusion, Design for All) for
# people as our ESG strategic tasks. LG Electronics is implementing these
# tasks to achieve mid-to-long term goals.
#
# For the Planet
#
# LG Electronics is pursuing a broad range of activities to protect our
# planet. To achieve carbon neutrality at the product production stage by
# 2030, we are reducing carbon emissions through energy-efficient facilities
# at our production sites and expanding the use of renewable energy. LG
# Electronics is leveraging the
#
# development of energy-efficient products and electrification to reduce
# carbon emissions by 20% during the product use stage by 2030.
# Additionally, we are actively increasing the use of recycled plastic in our
# products, having used a cumulative total of 114,000 tons of recycled
# plastic over the past three years. Plastic cushioning materials used in our
# packaging are being replaced with paper alternatives as well. Last year,
# LGE developed the industry's first pulp mold (paper cushioning material)
# that can cushion over 20kg. Starting with air purifiers, use of pulp mold
#
# will be expanded to larger products.
#
# For People
# LG Electronics is committed to providing convenient products and
# services for everyone. Last year, we enhanced the accessibility of our
# products by launching the LG Comfort Kit, which greatly increases user
# convenience for our home appliances. In addition, we are operating a
# Sign Language Consultation Center at our service touch points, and are
# offering the Best Companion Care Service, which provides one-on-one
#
# assistance from the vehicle to the store by a dedicated manager.
#
# Meanwhile, as the importance of supply ch
#
# grow, LG Electronics is constantly checki
# at its production sites and suppliers. As }
# Business Alliance (RBA), LG Electronics will.
# for labor rights, safety and health, envirc
# management systems in its global supply
#
# supply chain risks.
#
# As we work towards achieving our busines
# Life Solution Company, we are fully dedic
#
# management in pursuit of a better life for a
#
# Chief Exe
#  cs Sustainability Report
#
# lew
#
# anagement philosophy, and guides the thoughts and actions of all LG associates.
# G's vision of "No. 1 LG" by practicing 'People-oriented Management’, and ‘Creating
# "Jeong-Do Management.”
#
# * Vision
# The ultimate goal of LG is to be
# recognized as the market leader in
# business performance as well as in
# management practice.
#
# Jeong-Do Management
#
# ° Management
# Principles
# The fundamental
#
# Customer-Value Creation |
# People-Oriented Management
# organizational principle
# guiding LG from its
# beginning as a firm
#
# Environmental Social Governance
#
# Overview
#
# ESG Data A
#
# LG Electronics Mission and Vision
# Based on the brand philosophy of "Life's Good," LG Electronics always strives to pre
# Unique, and New (F-U-N) experiences to make their lives better. We will become a
#
# that connects to and extends customers' experiences in every space of their li
# to include their homes, commercial spaces, mobile spaces including vehicles, an
#
# Metaverse.
#
# Mission
#
# Innovation for a Better Life
#
# Our reason for existing, and our promise to the customers
#
# jon
#
# Smart Life Solution Company
#
# By 2030, we are committed to becoming a company with USD 76.6 bi
# achieving the ‘Triple 7": a 7% CAGR, a 7% operating margin, and an EBITD/
#
# Core Value
#
# ays put the
# customer first
#
# We always put our customers first and make our jud
# based on them.
#
# More exciting
# challenges
#
# We are courageous and positive, constantly finding
# and executing better ideas.
#
# The best that exceeds
# expectations
#
# We aim to be the best and most recognized by exce
# everyone's expecta
#
# Warm
#
# respect We genuinely respect each other's personality and d
#
# Confidence in taking
# the right way
#
# We take pride in competing and winning fairly.
#
#  cs Sustainability Report
#
# Corporation
#
# ctronics Inc
#
# Social Governance ESG Data At
#
# Shareholder Status
#
# Status of Shareholders Holding 5% or more
#
# Largest Shareholders and Affiliated Perso!
#
# in Towers, 128 Yeoui-daero, Yeongdeungpo-gu, Shareholder Number of Shares Shareholding Rati Shareholder Relationship Owne
# Korea (Shares) (%) (s
# facturing LG Corp 55,094,582 33.67 LG Corp Holding company 55,092
# erators, Washing Machines, Air Conditioners, National Pension Affiliated company
#
# m Cleaners, TVs, Audio Sound Systems, Automotive Ser 11191518 6.84 Ging Sacer executive
# onents, Monitors, PCs, Signage, etc. William Affiliated company |
#
# n oowan) Cho
#
# er 1, 1958
#
# 3BB(Stable) / Moody's: Baa2(Stable)
#
# 3 (35111 in Korea, 37,702 in overseas)
#
# ompany
#
# Ratio (%)
#
# 7
#
# 12
#
# (Voting share, as of December 31, 2023)
#
# Sales (Consolidated)
#
# (oowan) Cho executive
#
# Global Sales
#
# Classification Sales (KRW 100 n
#
# ion)
#
# usD 64.5 billion
#
# Operating Income (Consolidated)
#
# Korea 342,720
# ® North America 203,475
# Europe 121,293
# Asia 74,880
# Latin America 31124
# Middle East & Africa 32,873
# China 25,418
# Russia (CIS) 10,495
# Total 842,278
#
# “4
#
# USD 2 / billion
#
# Exchange rate: USD 1 = KRW 1,306
# (Average exchange rate in 2023)
#  6 2023-2024 LG Electronics Sustainability Report Environmental Social Governance ESG Data Appendix oO eg < >)
#
# Compan
#
# Global Business Sites”
#
# Russia (CIS) (As of end of March 2024)
# Sales & Production 1
# Production 1
# Sales 2
# sd
# ie China North America
#
# Sales & Production 3
#
# Sales & Production Sales & Production 2
#
# Producti 2
# — Production 8 Production 4
# Sales 13
# Oth 4 Sales Sales
# ie
# ° Other 3 Other 14
# Korea
# Middle East and Africa Sales & Production 1 Central and South
# i Production 5 America
# Sales & Production 2 ————
# Production 5 a
# Sales & Production Production 4
# Sales ai) ‘ sles 5
# Production 3
# Other 4 other ;
#
# Sales 9 Z
#
# Other 10
#
# Production
#
# 33
#
# * Number of business sites according to internal management standards
#
#  cs Sustainability Report
#
# Overview Environmental Social
#
# Governance
#
# ESG Data Ay
#
# nce & Air Solution (H&A), Home Entertainment (HE), Vehicle component Solutions (VS), and Business Solutions (BS) Business Companies, LG Electronics is a global leader in te
#
# me appliances, IT, automotive components, and signage, with operations at approximately 140
#
# r Solution
#
# % Air Solution)
#
# al home appliance
# products that
# gies with premium
# =xtensive research
# 2 world, including
# and lifestyle, and
# ing brand not only
# but also in future
#
# nes.
#
# Home Entertainment
#
# The HE (Home Entertainment) company strives
# to provide customers with a better life from
#
# the perspectives of wellness, beauty, and
# entertainment. Through a wide range of devices,
# including TV and audio devices, as well as webOS-
# based platform businesses and content services,
# we bring inspiring experiences to our customers’
#
# daily lives. We constantly deliver innovative
#
# solutions that make our customers’ lives more
# comfortable, beautiful, and enjoyable, such as
# LG OLED TVs with the highest picture quality
# available, ease of use and a design that fits
# customers’ lifestyles, LG StandbyME, a personal
# screen, and LG TONE Free earbuds that achieve
#
# high fidelity audio.
#
# es around the world.
#
# Vehicle component Solutions
#
# Under the vision of ‘Innovation Partner for
#
# Future Mobility’ the VS (Vehicle component
# Solutions) company is transforming itself into a
# true innovation partner that achieves customer
# value by making proposals for future mobility
# solutions, rather than staying as a traditional
# automotive component supplier. Based on its
# advanced technology in the fields of electricity and
# electronics and its user experience know-how in
# home appliances, we are providing differentiated
#
# value for the future of autonomous driving and
#
# next-generation electric vehicles.
#
# Business Solutior
# Our BS (Business Solut
#
# a true business partne
# value enhancement an
# customers by proposin
# solutions based on cus
# "Trust First’ perspectiv
# trust. We combine adv
# with deep insights into
# the best products and
#
# innovative experience 1
#
# expectations.
#
#  cs Sustainability Report
#
# or the Planet
#
# [Overview] Environmental Social Governance
#
# A
#
# the Planet
#
# - Renewable Energy Transition
#
# 5 to achieve carbon neutrality through process improvement, the introduction of
#
# le use of renewable energy to reduce greenhouse gas emissions and the purchase
# “100 participant, we have also set a goal of achieving 100% renewable energy at all
#
# siness sites by 2050.
#
# ollection and Recycling
#
# generated at all of our Korean and overseas business sites and will expand the
# cate for all of its global business sites. We achieved our goal of reaching a 95%
# ) ahead of schedule, and will maintain 95% or higher. We are also proactively
# countries where we operate, establishing relevant policies and collecting e-waste.
#
# ious materials for product manufacturing as well as packaging materials, and carry
# e appliances and batteries.
#
# roducts - Using Environmentally Conscious Materials
#
# 1G emission intensity at the product use stage through high-efficiency energy
# sity refers to the amount of greenhouse gases emitted per unit of product during
# duct. For example, a refrigerator emits per liter of content, while a washing machine
# ] capacity. We became the first Korean home appliance company to receive SBTi
#
# e) verification of our product use stage carbon emission reduction targets.
#
# Performance in 2023
#
# YOY carbon emissions reduction
#
# Global renewable energy transition
#
# Waste recycling rates of business sites
#
# Cumulative collection of e-waste (Since 2006)
#
# Reduction of GHG emission intensity of
# seven major products at the product use stage
#
# Cumulative use of recycled plastic (Since 2021)
#
# 114
#  cs Sustainability Report
#
# or People
#
# [Overview] Environmental Social Governance ESG Data A
#
# People
#
# man Rights in Supply Chain
#
# esponsibility to protect the safety and health of the working environment and human
# Jement program at its production sites. By 2030, we aim to achieve zero critical non-
# uction sites based on audit requirements, and we conduct self-assessments and on-
# ify and improve potential and actual risks. We also evaluate the suitability of the ESG
#
# ad provide related training and consulting.
#
# ce for pursu
#
# \g responsi ies in global supply
#
# male Talents and Expanding Hiring for People with Disabilities
# equity, and inclusion (DEI) in our organizational culture so that all employees feel
# longing, and realize their potential. To this end, we have set a target of having 3.5%
# 1 Korea and 25.5% of female employees (on a global basis) by 2030.
#
# ce Accessibility
#
# echnologies to improve the accessibility of its products, and is working to improve
# g sign language counseling services and Braille sticker attachment service to home
# e an accessibility advisory group to promote product development that considers
#
# isers. We will apply accessibility technologies and universal design to all products
#
# : for all users, including people with disabilities, seniors, and children.
#
# Performance in 2023
#
# Ratio of ISO 45001 (Health and Safety Management System)
#
# certified production sites
# (Exclu
#
# new subsidiaries (2 in the US, 1 in Mexico) that have not started mass production.)
#
# Percentage of production sites with zero critical non-conformances
# (Based on RBA audit requirements)
#
# Percentage of high-risk suppliers
#
# (Based on self-assessments)
#
# Percentage of female employees (Global)
#
# Employment rate of people with disabilities (Korea)
#
# SS
# Home Appliances TV Commo
# 9 products with voice Listening to TV together, Learning languag
# guidance, 5 products remote control, Shortcuts to sign lan
# with voice recognition accessibility features digital h
#
# services
#  cs Sustainability Report
#
# 1ologies Leading the Global HVAC Market
# heating, ventilation, and air conditioning (HVAC) market through the manufacturing
# ating and cooling solutions. We offer a wide range of high-quality products for
#
# 1, from personal devices to industrial and specialized HVAC systems.
#
# Individual Control Solution:
# Al Wireless Remote Controller
#
# External linkage solution:
# (BMS linkage system) ACP 5
#
# evel of Competence
#
# / storage system (ESS) solutions with high-quality products and site-specific design
# the largest integrated test facility in Korea and introducing the ISO 9001 quality
# -scale products, LG Electronics’ ESS has improved the efficiency of PCS (Power
# mized electricity losses. In addition, the high-quality batteries and sophisticated
#
# tem) ensure both reliabi ity and efficiency, and we were able to maxi
#
# ize the space
# y reducing the product size by 70% compared to competitors. In recognition of this
#
# ly completed the first ESS installation integrated with solar power in Korea. (Sejong
#
# [overview Environmental Social
#
# Governance ESG Data At
#
# Vehicles
#
# Space-Customized EV Charging Solutions
# In March 2024, LG Electronics introduced three electric vehicle charging solutions (
#
# charger, and 200kW fast charger) optimized for various spaces, such as residenti
# charging stations. The 7kW slow charger for residential use features a touchscre
# and is available in both wall-mounted and free-standing models to fit a variety
# The 100kW fast charger allows for simultaneous charging (up to two vehicles), ma
# lots at places such as shopping malls, hospitals, and restaurants, while the 200!
# charging speeds and can be used at EV charging stations. LGE’s charging solutions «
# temperatures as low as minus 25 degrees Celsius and as high as 40 degrees Celsit
#
# for water and dust resistance and IK10 for shock resistance.
#
# EV Charging Solution
#  cs Sustainability Report
#
# ake Appliances Easier to Use for Everyone
# ople with physical disal
#
# ‘ied their challenges in using home appliances, analyzed them by user type and
#
# ies, hearing impairments, visual impairments, and brain
#
# 3 Comfort Kit, a practical modification that can be attached to existing products,
# 1e LG Comfort Kit incorporates universal design to make LG home appliances easy
# jless of gender, age, or disability.
#
# ee
#
# LG Comfort Kit
#
# Purifier that Leaves No One Behind
#
# ‘s launched the 'PuriCare Objet Collection Water Purifier’ with a voice recognition
# users to dispense water in 10ml increments without pressing the button, but also
# sr they have consumed in the past week. This allows anyone to use the product
# visual impairments to the elderly who had difficulty using the product because the
# to see, to children who are too short to reach the dispensing button.
#
# er Purifier
#
# [overview Environmental Social
#
# Governance ESG Data At
#
# Water, Waste and Ecosystem Restoration
#
# Water-Soluble Glass
#
# Changes in the marine environment are causing the ocean desertification, resu
# seaweeds such as wakame and kelp in coastal rocky areas, which is damaging the
# its biodiversity conservation efforts, LG Electronics is developing a water-soluble gl
# restoration of marine ecosystems. The water-soluble glass changes to a mineral
# which can be utilized to help algae grow in the ocean, restoring marine ecosystems.
# The water-soluble glass utilizes technology that consistently dissolves mineral ions,
# in water to promote the growth of algae in the ocean, much like fertilizer for cro
# marine forests. The increased amount of algae become an essential food source ar
# in the marine ecosystem, creating the environment they need to thrive and grow. A
# environment by absorbing carbon dioxide and releasing oxygen. Since 2023, we t
# National Institute of Science and Technology (UNIST), Research Institute of Indu
# (RIST), and other specialized research institutes to demonstrate the safety o
# effectiveness in promoting the growth of algae. We also signed an MOU with the |
# (KOPRI), a government-funded organization, to demonstrate its applicability and.
#
# marine environment.
#
# Microplastics Care Course
#
# Washing clothes is essential to keep them clean and smelling good. However, wast
# fibers releases microscopic plastic fibers into the water. This water is either dischar
# and returned to water resources. LG Electronics has introduced an advanced microy
# the formation of microplastics by household laundry. The course utilizes LG's 6-N
# Stepping, Scrubbing and Filtration) technology to reduce fiber friction, prevent m
# minimize energy consumption.” ThinQ UP washing machine users can download
# from the Upgrade Center in the ThinQ app.
#
# 1) Washing a 3-kilogram training jacket made of 100% polyester using the microplastics care course resulted
# 20un compared to the standard wash course, The microplastics care course also reduced water tempera
# course, leading to a 30% reduction in energy use.
#  12 2023-2024 LG Electronics Sustainability Report ¢ Overview Social Governance ESG Data Appendix oOo fe < >)
#
# Environmental
#
# Environmental Management Policy 13 | Addressing Climate Change 15 | Resource Circulation 18 | Product Stewardship 23 | Business Sites Operation 26
#  13 2023-2024 LG Electronics Sustainability Report
#
# Environmental Management Po
#
# Environmental Management Policy
#
# 1. Purpose
#
# As a responsible corporate citizen, LG Electronics is committed to environmental protection throughout all its
# business activities. We adhere to the highest environmental standards and international agreements, and we
# continuously strive to minimize our environmental impact through ongoing improvements. Aligned with the UN
# Sustainable Development Goals (SDGs), we have established ambitious goals for reducing our environmental
#
# footprint and have enacted this Environmental Policy to guide our efforts.
#
# 2. Coverage
# LG Electronics applies the most stringent standards when environmental laws and regulations in different
#
# countries conflict.
#
# @ Production operations and business facilities
#
# @ Products and services
#
# @ Distribution and logistics
#
# @ Management of waste
#
# © Suppliers, Service Providers, Contractors, and Other Key Business Partners
#
# © Mergers, Acquisitions, and New Businesses
#
# 3. Principles
# To promote environmental management, LG Electronics defines the following fundamental principles for each
# environmental topic.
# © Air Pollutants
# - Identify the types, characteristics, and emissions volume of air pollutants generated our operations and treat
# them according to regulations before discharge. Effective manage ozone-depleting substances in accordance
# with the Montreal Protocol and relevant regulations, and continuously monitor the treatment efficiency of
# pollution control facilities.
# @ Water Pollutants
# + Treat all wastewater according to regulations before discharge, and continuously monitor treatment results to
#
# ensure that the emission of water pollutants is always within the standard limits.
#
# Overview Social Governance ESG Data Appendix Oo tf < >)
#
# @ Hazardous Substance
#
# + Identify and record all chemicals (including hazardous waste) that are hazardous to human health or have the
# potential to cause environmental pollution when released from our workplaces, and safely store, transport,
# use, recycle/reuse, and dispose of these substances. Establish emergency response plans and conduct regular
#
# training to prevent environmental pollution and accidents caused by leaks or spills during handling
#
# + LG Electronics products are managed Guidelines for hazardous substance management in products to ensure
#
# that they do not contain substances prohibited by global conventions or pose a risk to human health
#
# @ Waste
#
# + Identify the types, characteristics, and emission quantities of waste generated at our facilities and treat
# and dispose of it in compliance with regulations. Strive to reduce waste generation. Select waste disposal
# contractors (including transporters) that are legally qualified to transport and dispose of waste after evaluating
# their suitability (including on-site inspections). Minimize the proportion of waste landfilled or incinerated and
#
# strive to improve the recycling rate of waste.
#
# - Consider the enhancement of reusability and recyclability from the product development stage and strive for
#
# the lawful collection and treatment of end-of-life products to minimize environmental impact.
#
# © Energy
#
# - Monitor energy consumption and greenhouse gas emissions to improve energy efficiency at our facilities and
# continuously review ways to enhance efficiency. Promote energy-saving activities. Strive to use sustainable
# energy by implementing renewable energy solutions tailored to our facilities’ conditions, such as installing
# renewable energy generation facilities, purchasing renewable energy certificates, and entering into power
#
# supply contracts.
#
# © Greenhouse Gas
# - Actively respond to climate change by developing and implementing effective greenhouse gas reduction
# measures and setting targets. Publicly disclose performance and reduction efforts for energy consumption and
#
# significant categories of Scope 1,2, and 3 emissions.
#  14 2023-2024 LG Electronics Sustainability Report
#
# @ Water Resource
# - Explore ways to reduce and reuse water consumption. Implement activities to identify and mitigate water
# scarcity risks.
#
# ® Biodiversity Conservation
#
# - Strive to conserve and restore biodiversity within LG Electronics’ sphere of influence.
#
# © Preventing Deforestation
# - Recognize the potential for deforestation issues that may arise within LG Electronics’ sphere of influence and
# strive to minimize negative impacts.
#
# 4. Management System
#
# @ Role of the Board of Directors and Top Management
#
# LG Electronics ensures the oversight of all environmental management and performance improvement
# activities through the ESG Committee within the Board of Directors and management meetings involving top
# management. The ESG Committee within the Board of Directors reviews and deliberate on environmental
# management policy revisions, responses to environmental laws and regulations, and environmental
# management performance, including climate response, at least once a year. The main roles of the management
# meeting involving top management include reviewing and deciding on environmental management risk reviews
# and response measures, as well as other matters deemed necessary for the dissemination/propagation of
# environmental management.
#
# @ Roles of the Dedicated Organization
#
# LG Electronics designates an environmental management implementation organization to carry out related
# tasks. The environmental management implementation organization reviews environmental laws and
# regulations, stakeholder requirements, and prepare response measures; establish and operate environmental
# management goals and indicators; build and operate environmental management systems, and conduct
# education and awareness improvement for major stakeholders and information disclosure.
#
# 5. Education and Awareness Improvement
# LG Electronics operates education programs for employees and key stakeholders to comply with this policy, share
# information on environmental policies, goals, and performance. Through this, the company raise awareness of
# environmental management and encourage employees to prioritize the environment in their work processes.
#
# \
#
# DG < >)
#
# Governance ESG Data Appendix
#
# 6. Information Disclosure and Communication
#
# LG Electronics transparently disclose environmental information related to products and business sites, as well
# as environmental policies and implementation plans, through its website, sustainability reports, and other means.
# The company also communicate with employees and stakeholders on environmental management performance
# and environmental policies, and reflect their opinions to continuously improve policies.
#
# 7. Performance Evaluation and Improvement
#
# LG Electronics sets and implement medium- to long-term performance goals for its environmental factors based
# on environmental policies. The company regularly evaluates the progress of goal implementation and check goal
# achievement, analyze the evaluation results to identify areas for policy improvement, and adjust goals according
# to the situation.
#
# Environmental Management System (ISO 14001) Certification
# To efficiently manage environmental risks by systematically identifying, evaluating, managing, and improving the
# elements necessary for environmental management, LG Electronics has acquired ISO 14001 certification for all its
#
# Korean and overseas production sites, which it has kept up-to-date.
#
# Number of ISO 14001 Certified Production Sites
#
# (As of 2023)
# Classification Acquisition / Renewal Total Certification
# Acquisition Rate
# Korea 5 5
# Overseas 25 25* 1 00%
#
# * Excluding new subsidiaries (2 in the US and 1 in Mexico) that have not started mass production.
#  cs Sustainability Report
#
# ate Change
#
# bon Emissions
# 1g a GHG Reduction Plan
#
# lectronics has set GHG reduction targets for the entire lifecycle of its products, from
# e aim to reduce the total amount of direct GHG emissions (Scope 1) and indirect GHG
# ict production stage by 54.6% by 2030 compared to 2017 levels in accordance with the
# »missions intensity in the product use stage by 20% by 2030 compared to 2020 levels.
# 2vement of these GHG reduction goals are being achieved, in 2021 LG Electronics
# ipany in the home appliance industry to declare its GHG reduction targets to
# itiative (SBTi) and have them verified by a third party. Since then, we have been
# rogress towards the targets submitted to SBTi, and are continuously implementing
#
# s in this area.
#
# n Plan
#
# Implementing
# external GHG
#
# Reducing GHGs in
# the product use
# reduction projec’
#
# stage
#
# : D
# Promote carbon credit CDM Reduce GHG emission intensity of
#
# project through sales of high- seven major product categories by
#
# BTi's efficiency products 20% by 2030 compared to 2020
#
# - Cumulative 560,000 tons of carbon
# credits issued as of 2020, with
# more to be secured by 2025
#
# in the Product Production Stage
#
# nissions during the product production stage, LG Electronics has implemented
# nd carbon emission reduction devices to our manufacturing process. We have
# cover and recycle refrigerant that escapes during the injection of HFC-based
#
# overed refrigerant, thereby reducing refrigerant leakage.
#
# Environmental Social Governance ESG Data At
#
# Promoting External GHG Reduction Projects
#
# LG Electronics is promoting a CDM project in India that converts the electricity sa
# efficiency refrigerators into carbon credits. Since receiving approval for the pro
# Framework Convention on Climate Change (UNFCCC) in 2013, we have secured 5!
# by 2020, and plan to secure additional credits by 2025. This equates to a reduct
# GWh through the use of our high-efficiency refrigerators. Cumulatively, the project
#
# tons of carbon credits.
#
# Global GHG Emissions
#
# Year Unit Direct GHG Emission (Scope 1) Indirect GHG Emission (Scope 2)
# 2019 604 869
# 2020 429 865
# 2021 1,000 333 819
# 2022° tCO.eq 265 662
# 2023 209 665
# 2030 Goal 923 (54.6% reduction compared to 2017, in accordant
#
# * Data corrected due to changes in processing of significant figures
#  cs Sustainability Report
#
# at the Product Use Stage
#
# various efforts to reduce GHG emissions at each stage of the product life cycle.
# product weight, conserving resources, and improving energy efficiency. Notably, we
# rgy-efficient products to reduce GHG emissions during the product use stage, and
# oducts that incorporate highly energy-efficient technologies. We also calculate and
# ated during the product use stage for our flagship products.
#
# ogy Road Map (TRM) that serves as the foundation for setting and implementing
# le energy efficiency of each product category. Additionally, we are committed to
# by establishing our own energy efficiency targets and detailed strategies, while
# egulations such as the EU's Ecodesign Regulation.”
#
# arbon emissions intensity during the product use stage by 20% by 2030, compared
# sales models in our seven major product categories (TVs, refrigerators, washing
# r conditioners, system air conditioners, and monitors). Given that as of 2021, these
# »s accounted for approximately 90% of the carbon emissions generated by all our
# age, we are actively promoting substantial carbon emission reductions through our
#
# rbon emissions and improve energy efficiency.
#
# tal and energy effi
#
# icy regulations that manufacturers, distributors, and sellers must comply with from the
#
# nal wash volume control algorithm utilizing TurboWash 360 technology achieving a
#
# of approximately 40% for new washing machines sold in the European market
#
# 100 cycles).
#
# in monthly power consumption” by switching the refrigerant used (R401a ® R32) and
# the 2023 stand air conditioner in the Korean market.
#
# er with 6 Motion drying technology achieving a 35.8% reduction in power consumption
# r in the Korean market as of the 2023 model.
#
# arison for 2022 and 2023 models (sales-weighted average)
#
# Power Air Power Dryer Power
# iption conditioner consumption (RD2IES, consumption
#
# (All air conditioning 3.7% V Eh) 35.8%)
#
# y
# CNY models, 2023 model)
#
# Social Governance ESG Data AY
# Annual GHG Emissions during the Product Use Stage
# Year 2021 2022
# Reduction ratio compared to 2020 6.6% 13.1%
#
# Reducing GHG Emissions during the Product Distribution Stage
# To reduce carbon emissions during the the product distribution stage, we are c
#
# company LX Pantos to reduce their GHG emissions.
#
# Measurement, Reporting and Verification of GHG Emissions
#
# As a company regulated under Article 27 of the Framework Act on Carbon Neu
# Coping with the Climate Crisis, LG Electronics submits emission statements to t
# related information after third-party verification of GHG emissions and energy co
# Article 27 (8) of the Act. We have established a greenhouse gas inventory for ot
#
# disclose our GHG emissions annually.
#
# Introducing Carbon Accounting and Carbon Pricing
#
# LG Electronics analyzes its carbon credit allocations and actual emissions on a
#
# emission liabilities in the consolidated statement of financial position when our e!
#
# amounts. We also set an internal carbon price to identify business opportu
# energy savings and GHG reduction activities. This metric, which quantifies the value
#
# measures the financial impact of the environmental burden incurred by LG Elec
#
# rational investment decisions for reducing GHG emissions.
#  cs Sustainability Report
#
# newable Energy (2050)
#
# Renewable Energy 100) in June 2023 with commitment to a gradual transition to
# 50. In accordance with our mid- to long-term plan to convert to 100% renewable
# ase our use of renewable energy, considering the current status of our Korean and
# elevant laws and regulations. Aiming to achieve 60% renewable energy by 2030,
# 050, we are exploring various options for purchasing renewable power, including a
# tribute Certificates) purchasing, and third-party PPAs.”
#
# N solar power generation capacity through self-generation and PPA” contracts,
#
# MWh of electricity annually.
#
# ed 2.3 MW of renewable power through Korea's first off-grid PPA
# roduced 1.4MW of solar power
#
# Ig approximately 44,000 MWh of renewable energy annually through wind and
# promoted solar power generation of 11 MW (16,500 MWh/year) through an equity
# ction subsidiary.
#
# yntract between a power producer and a power consumer to purchase electricity for a fixed period of time.
#
# Status
# al business sites purchased and generated 126,410 MWh of renewable energy
# ropower), EACs purchasing (wind, hydropower, biomass), and self-generation, which
#
# nal electricity consumption.
#
# of Global Business Sites
#
# Environmental Social Governance ESG Data At
#
# New PPA Contract for Overseas Production Sites in 2023
#
# Classification Production Sites Generation Capacity(MW) A
# Nanjing PN 68
#
# China Tianjin 10.0
#
# Solar Taizhou 70 -
# Thailand 3.2 -
#
# Vietnam 75 -
#
# Wind China Qinhuangdao _
# Total 445 -
#
# Energy Consumption Management System at Global Production Site:
# LG Electronics operates a global energy consumption management system to moi
# and cost of each type of energy used in its Korean and overseas business sites or
# utilized to calculate Scope 1 and 2 GHG emissions, and serves as a foundation f
#
# energy-efficient production facilities within our subsidiaries.
#
# Energy Management System (ISO 50001) Certification
#
# LG Electronics is continuously expanding its acquisition of ISO 50001 certification t
# improve efficiency, and systematize management at both Korean and overse
# continuous and standardized management, we have established the 'Energy and (
# Standards and Rules’ and will enhance our energy management by regularly inspe
#
# management systems at our business sites.
#
# vit 2021 2022 2023 Number of ISO 50001 Certified Production
# - 36,786 56,110 (Ascii)
# 64,588 58,961 65,159 Classification Acquisition / Renewal Total
# vn 513 4,336 5141 Korea 5 5
# 69,701 100,083 126,410 Overseas 14 25*
# 6 46 82 101 * Excluding new subsidiaries (2 in the US, 1 in Mexico) that have not started mass production
#
#  cs Sustainability Report
#
# : Change Policy
# 1ange Organizations and Initiatives
#
# ies related to climate change, such as the Paris Agreement” and the IPCC,”
# vith Korean and international climate change-related specialized institutions,
# to introduce and implement climate change policies. We continuously review
# I
#
# jes of participating organizations to ensure they align with LG Electronics’
# nd if discrepancies are identified, we actively engage with the organizations
# egularly assess the stances and activities of participating organizations and
# ant discrepancies persist. Through this efforts, we aim to establish an effective
# dressing climate change issues to achieve shared goals.
#
# pted on December 12, 2015 by 195 countries at the 21st Conference of the Parties to the United Nations
# ange, held from November 30 through December 11, 2015 in Paris, France
# nate Change
#
# je Initiatives
#
# Implementation
# 1 the ‘K-EV100” campaign led by the Ministry of Environment since April 2021
#
# ion, we plan to gradually increase the proportion environment-friendly motor vehicles”
#
# or leased vehicles aiming for a 100% transition to environment-friendly motor vehicles
#
# an (K-EV100): A campaign organized by the Ministry of Environment that declares and phases in a
# their owned or leased vehicles to 100% zero-emission vehicles by 2030
# Vehicles that meet zero- or low-emission standards and are energy efficient
#
# Environmental Social Governance ESG Data At
#
# Resource Circulation
#
# E-Waste Collection and Disposal
# E-Waste Collection and Compliance to Recycling/Regulations
#
# LG Electronics supports the concept of Individual Producer Responsibility (IPR) whi
# of producers in taking back e-waste and is enhancing the reusability and recyclab
# reducing the environmental impact during the disposal process. Notably, proactive
# and collects e-waste in compliance with the regulations in countries where we op
# management, including global e-waste collection and disposal policies and reg
#
# systems, is publicly available on our website.
#
# Global E-Waste Local (
#
# Cumulative E-Was
# Performance
# (Since 2006, Unit: 10,00¢
#
# E-Waste Recovery/Disposal Results by Region
#
# Region Unit 2021 2022 ©2023
# Europe” 155,598 151,920 126,739
# Korea 124764 116,491 131,506
# North America” 26,576 23125 30,979 -
# 352 402
# Asia? ton 112705 148,041 134,061
# Russia (CIS) 22,602 23677 10,291
# Garttellqns Semtin 3008 3694 51,530
# America
# Africa? - 1542 7,298
#
# 1) Estimated figures are used for some European countries
#
# 2) North America: U.S,, Canada
#
# 3) Asia‘ Japan, India, Australia, Singapore
#
# 4) Central and South America: Brazil, Colombia, Mexico, Peru, Panama
# 5) Africa: Republic of South Africa
#
# * As countries in some re
# reporting recovery, if d
# of publication of the re
# the previous year's recc
# of neighboring countri
# slight adjustments whe
#  cs Sustainability Report
#
# ervice (Korea) — How It Works
#
# cipating in the Producer Responsibility Recycling System since its implementation
# ree-of-charge take-back service for discarded electronic products. We strive to
# -waste and mitigate the environmental impact of landfills and incineration in the
# recyclability assessments from the development to ensure our products are more
#
# Large Appliances
#
# E-waste collected by
# stallation specialists vi
# customer's home
#
# Disassemble and
#
# Recycle as
#
# sort out e-waste material
# Small Appliances
#
# --waste collected through a
# designated recovery box at
# LG Electronics service
# centers
#
# Recycling Center)
#
# (CRC) was established in the Gyeongnam region in 2001 to recycle e-waste and
# - recycles resources while ensuring the environmentally conscious recycling or
#
# ed in waste appliances.
#
# Social Governance ESG Data At
#
# Collection of Small and Medium-sized Electronic Products
#
# Since July 2022, LG Electronics has been collecting small and medium-sized ele
# of brand through its e-waste collection boxes at all LG Best Shop stores, base
# Environment Corporation, E-Cycle Governance, and home appliance manufacturer
# the collection rate of small and medium-sized e-waste. This has laid the foundatior
# for small and medium-sized e-waste, which typically have a low collection rate.
#
# Collection and Recycling of Small Secondary Batteries
# In May 2024, LG Electro
# for the collection and recycling of small secondary batteries, pledging to cooperate
#
# s signed an MOU with the Korea Environment Corpor:
#
# economy, including the establishment and operation of a resource circulation syste
# also encourage customers to participate in the resource circulation by collecting
# vacuum cleaner and offering discounts on new batteries through the “BatteReturn
# been held twice a year since 2022 and is currently in its Sth cycle, with a total of 6:
# collecting about 51.2 tons of waste batteries.
#
# [A7| AAPA As DRA] 274A
#
# ~ AY
#
# LG Electronics CEO participating in e-waste
# collection batteries
#
# MOU to collect and recycle small secondary Bat
#
# E-Waste Collection and Treatment Service (Overseas)
#
# LG Electronics collects waste electronic products in accordance with the WEEE (V
# Equipment) regulations and the requirements of each country, and as of the |
# electronic product collection and treatment services in 89 locations in 54 co
# recycling policies in new regions, we introduce services after conducting a regulatoi
# governments and industry organizations in the target countries.
#  cs Sustainability Report
#
# fficiency
# Structure and Material
#
# elopment stage, LG Electronics focuses on improving materials and structures to
# n addition, we have established a collaborative system with recycling companies to
# ing and sorting. In 2023, we modified the material of our TV model (S50UQ8300ENF),
# tion in product weight (approx. 2.8 kg), a 7% reduction in product volume (0.013
# ‘kaging material weight (0.11 kg) compared to the previous model (SOLF6500). We
# f our products, reducing the number of fastening parts which measures ease of
# 0 26. To reduce waste and improve resource efficiency, we will enhance our efforts
#
# scious products and improve the design of existing products.
#
# 1d material for a TV model (model name: SOUQ8300ENF)
#
# Structure Change
#
# Number of
# packaging material fastening parts
#
# 3% reduction 21% reduction
#
# (0.11kg) (from 33 to 26)
#
# Product volume Weight of
#
# 7% reduction
#
# (0.013m*)
#
# Environmental Social Governance ESG Data At
#
# Use of Recycled Plastic
#
# LG Electronics recycles plastic from collected waste electronics and uses it to mal
# the goal of using 600,000 tons of recycled plastic from 2021 to 2030; by 2023, we
#
# Classification Unit 2021 2022
# Amount of recycled plastic 26,545 32;
# A ton
# Amount of raw materials used 12533 16,
# for recycled plastic
# Cumulative amount of recycled 10,000 27
#
# plastic tons
#
# E-Cycle Certification Status
#
# LG Electronics has obtained E-Cycle Excellent Product Certification for six f
# refrigerator (45 models), two air purifiers (16 models), and one vacuum cleaner (1
# Product Certification is a certification system that is awarded to excellent products
# (sponsored by the Ministry of Environment) by evaluating 12 criteria across five
# (material reduction, ease of decomposition, percentage of recycled plastic, etc.)
#
# LG OLED TVs, which recognized as a 2023 Product of the Year, are resource-efficier
# a backlight, which means they have fewer parts and a simpler structure than cor
# OLED evo uses environmentally conscious composite fiber materials and metal inst
# use of about 40% less plastic than an LCD TV of the same size. Manufacturing |
# 16,000 tons less plastic to manufacture OLED TVs compared to the same number
# from the production and transportation of plastic are projected to be reduced b
# Additionally, we use 30% recycled plastic for the back cover of our TVs, further cont
# LG OLED TVs have been recognized for their resource efficiency by leading Korear
# were recently awarded environmental product certifications for a fourth consecutiv
#
# non-profit certification institution in the UK, and Société Générale de Surveillance (
#
# second consecutive year by Intertek, the UK's non-profit certification organization.
#  cs Sustainability Report
#
# ly Conscious Packaging
#
# 1e application of environmentally conscious design and environmentally conscious
# aging to minimize post-consumer waste, while maintaining the basic function of
# ‘Ss and maintain their stability. We will strengthen activities such as technology
#
# very by ions so that environmentally conscious packaging can be applied to more
#
# 13 2014 2023
#
# - Established and
# executed goals for each
# division regarding the
# amount of packaging Environmentally conscious
# material used, packaging printing
# volume, and the Reduced disposable plastic
#
# reduction in packaging and increased the use of paper
# space, etc, buffers
#
# ‘panded the
# plication of the
# nvironmentally
# nscious Packaging
# sign Guidebook” to
# products
#
# Developed and applied recycled
# cushioning material containing
# 50% waste Styrofoam
#
# ing and Recycling EPS Manufacturing Technology
#
# mount of plastic in its product packaging to the greatest extent possible to minimize
# to paper for our internal cushioning materials, which have been applied to laptops and
# addition, we developed the industry's first paper cushioning material for packaging
# and are planning to develop paper cushioning for packaging large products weighing
# s in products for which plastic cushioning materials are required. The plastic packaging
# ics are produced through a differentiated process with 50% waste material content,
# 2ntal impact compared to conventional plastic cushioning materials. Furthermore,
# te waste Styrofoam recycling process, from waste material collection to product
# ‘panding its scope, beginning with a pilot application in dryers in February 2024.
#
# nioning used for speaker Paper cushioning used for air purifier
#
# packaging
#
# Environmental Social Governance ESG Data At
#
# Waste Management
# Creating and Internalizing Waste Goals
#
# LG Electronics conducts record inspections, facility inspections, and waste categor
# and type of waste generated during our business operations, and identifies opp:
# waste management. Based on the identified opportunities, we establish specific w:
# quantitative targets. In addition, we not only review and invest in R&D for waste rec
#
# reduction training to employees to ensure they understand and implement our goal
#
# Waste Reduction Activities
# LG Electronics has identified and implemented various waste reduction activities at
# - Pyeongtaek Digital Park - Hanuri: Replacing approximately 1.36 million sing
# serve beverages with reusable containers
# - Changwon Smart Park 1: Setting up a plan in 2024 to reduce 30 tons of wv
# through improved packaging techniques (visible packaging)
# - Pyeongtaek Chiller: Setting up a plan in 2024 to save 10 tons of waste wood
# steel so that pallets used in the painting process can be used multiple times
# - Magok Science Park, Gasan R&D Campus, Seocho R&D Campus, Yangjae
# Digital Park, Pyeongtaek Chiller: Participating in the BiCycle Campaign” to str
# by establishing a closed loop for waste hand towels generated from restroom:
#
# 1)An environmentally conscious campaign organized by Yuhan-Kimberly to increase resource @
# circulation by separating and collecting waste and producing and consuming products with
# renewable materials
#  cs Sustainability Report
#
# ‘ecycling Rate Across All Korean and Overseas Business Sites
# ecycling, LG Electronics has strengthened waste separation and sorting procedures
# recyclable waste. In addition, most of our business sites in Korea have recycled
# ...
# 4) In 2024, we identified that the heating function of some air conditioner models sold in certain coun
# verification (DNV) of our calculations, so we recalculated and corrected the carbon emissions.
#
#  cs Sustainability Report
#
# Unit 2021 2022 2023
# rea) 632 548 496
# erseas) 948 845 615
# rea) (e) (0) (0)
# erseas) (e) (0) (0)
# (orea) 70 67 56
# )verseas) 500 450 557
# I 2150 1,910 1,724
# wer” 19 33 64
# _— vu
# wer 233 212 268
# - - 1
# - 115 122
#
# I 252 360 455
# ty (Korea) 2,508 1,736 1,686
# ty (Overseas) 2,942 2,678 2,808
# <orea) 397 335 310
# Nverseas) 3 2 2
#
# TJ/USD 100 million 12,38 10.30 10:13
# 2a under the control of LG Electronics.
# oduction sites (26 locations)
# sed in combustion facilities and externally supplied power and heat at business sites
# sed on net calorific value; steam consumption includes steam recovered from waste heat in Korea
#
# ion was completed
# voltaic energy
#
# (including self-generation) data
#
# /intensity data due to a change in data calculation methodology
#
# Environmental Social Governance ESG Data €
#
# Goals for 2030 Carbon Neutrality
#
# 1. 54.6% Reduction in GHG Emissions by 2030 Compared to 2017
#
# - Continue to invest in facilities to reduce emissions (initial investment made in 201
# each year)
#
# — Improve energy efficiency, replace older low-efficiency equipment, etc.
#
# 2. GHG Reduction by Participating in UN CDM Projects
# - Contributed to reducing emissions during the product use stage by expanding the
# high-efficiency products such as refrigerators and air conditioners in India
#
# - Acquired certification by the UN for emission reduction performance, CERs are be’
#
# 3. Expansion of Renewable Energy
#
# - Aim to achieve 100% renewable energy by 2050
#
# — 100% conversion into renewable energy for US production/sales subsidiaries, log
# subsidiary (2022)
#  cs Sustainability Report
#
# Verification Statement
#
# a Ltd. ("DNV") was commissioned by LG Electronics Inc. (“LG Electronics”) to verify
# se Gas Inventory Report for the calendar year 2023 (‘the report”) based upon a
#
# LG Electronics is responsible for the preparation of the GHG emissions data on
# lidelines on the operation of GHG emission trading scheme (“ETS) (Notification No.
# onment)’. Our responsibility in performing this work is to the management of LG
# ince with terms of reference agreed with them. DNV expressly disclaims any liability
#
# ns, whether investment or otherwise, based upon this assurance statement.
#
# red by our examination comprise Direct emissions (Scope 1 emissions) and Energy
# lissions) from LG Electronics’ boundary of the report ;
#
# orting: Korean business sites of LG Electronics (Fugitive emissions form refrigerant are
#
# Fugitive emission by purcha Direct emissi
#
# lucted by DNV on February to March 2024 and performed in accordance with the
# ; outlined in the guidelines on the operation of GHG ETS (Notification No. 2023-221,
# nt) and the verification guideline for GHG ETS (Notification No. 2021-112, Korean
#
# planned and performed our work to obtain all the information and explanations
#
# us with sufficient evidence to provide a reasonable verification opinion concerning
#
# sion inventory as well as the reported emission figures in ton CO2 equivalent. As
#
# 1e GHG emissions report for the calendar year 2023
#
# le process to generate, aggregate and report the emissions
#
# Environmental Social Governance
#
# EsGData @
#
# Conclusions
# As a result of the work described above, in our opinion nothing has come to our att
# believe that the GHG emissions set out in LG Electronics’ report are not fairly sta
#
# Electronics for the year 2023 were confirmed as below;
#
# Greenhouse Gas Emissions of LG Electronics Korean business site for Yr 2023
#
# one raced Direct Emissions (Scope 1) _ Indirect Emissions (Scope 2)
# Excl. Refrigerant 30,693
# 217159
# Incl. Refrigerant 74,787*
# * Fugitive emission (44,094 tCO,eq) by purchasing of refrigerant is included in Direct emissions.
# | Ma)
# Seo
# DNV Jan
# Cou
# DN'
#  147 2023-2024 LG Electronics Sustainability Report
#
# Introduction
#
# DNV Business Assurance Korea Ltd. ("DNV") was commissioned by LG Electronics Inc. (“Company”) to perform
# third party verification for the Company's Greenhouse Gas Inventory Report (‘the report”) in the calendar year
# 2023. The Company is responsible for the preparation of the GHG emissions data on the basis set out within the
# ‘ISO 14064-1:2018, The GHG Protocol: A corporate reporting and accounting standard and 2006 IPCC Guidelines
# for National Greenhouse Gas Inventories’. Our responsibility in performing this work is to the management of the
# Company only and in accordance with terms of reference agreed with them. DNV expressly disclaims any liability
# or responsibility for any decisions, whether investment or otherwise, based upon this assurance opinion.
#
# Objectives and scope of verification
# The purpose of this verification is to present an independent verification opinion on the company's greenhouse
# gas emissions, and the scope of verification is as follows;
# Organizational Boundary: 26 overseas business sites of the company
# - Operational Boundary: Scope 1 (Direct emissions) & Scope 2 (Indirect emissions)
# - Reporting period: 2023.01.01 ~202312.31
#
# Verification Approach
# The verification has been conducted in accordance with the verification principles and tasks outlined in the ‘ISO
# 14064-3:2019', based upon a limited level of assurance. We planned and performed our work so as to obtain all
# the information and explanations deemed necessary to provide us with sufficient evidence to provide a verification
# opinion with 5% materiality level, concerning the completeness of the emission inventory as well as the reported
# emission figures in ton CO, equivalent. As part of the verification process, we have reviewed as follows;
# * Process to generate, aggregate and report the emissions data
# The data and information supporting the report were based on historical in nature. These may include partially hypothetical
# and projected data and information (refer to the report for details)
#
# (Overview Environmental Social Governance ESG Data Appendix oO fal < >)
#
# Conclusions
# Based on the process and procedures conducted, there is no evidence that the GHG statement is not materially
# correct and is not a fair representation of GHG data and information;
#
# DNV presents an ‘Unmodified’ opinion on Greenhouse Gas Emissions
#
# Greenhouse Gas Emissions of LG Electronics overseas business sites for Yr 2023
# (Unit: ton CO, equivalent)
#
# LG Electronics Direct Emissions (Scope 1) Indirect Emissions (Scope 2) Total Emissions
#
# Overseas business
#
# R 448125
# sites
#
# 126,738" 574,863
#
# * Fugitive emission (68,437 tCO,eq) by purchasing of refrigerant is included in Direct emissions.
# 2 In order to report the GHG emissions as an integer, the rounded number on the opinion might be different from the number on the system with
# £1tCO,eq
#
# 13th May 2024
#
# Seoul, Korea
#
# Jang-Sub Lee
#
# Country Representative
#
# DNV
#
# DNV Business Assurance Korea
#
# RX
#  cs Sustainability Report
#
# yrea Ltd. ("DNV") was commissioned by LG Electronics Inc. (“Company”) to
# n for the Company's Greenhouse Gas Inventory (“the inventory”). The Company
# ation of the GHG emissions data on the basis set out within the ‘WRI/WBCSD
# ccounting and Reporting Standard (2004)’, The Corporate Value Chain (Scope 3)
# indard’ and ‘2006 IPCC Guidelines for National Greenhouse Gas Inventories’, Our
#
# is work is to the management of the Company only and in accordance with terms
# n. DNV expressly disclaims any liability or responsibility for any decisions, whether
#
# d upon this verification opinion.
#
# erification
#
# n is to present an independent verification opinion on the company's greenhouse
# f verification is as follows;
#
# electronics Inc.
#
# 3 (Other indirect emissions)
#
# 2,3,4,5,6,7,8
#
# - 10, 11, 12, 13, 15
#
# 20231231
#
# jucted in accordance with the verification principles and tasks outlined in the ‘ISO
# limited level of assurance. We planned and performed our work so as to obtain
# nations deemed necessary to provide us with sufficient evidence to provide a
# ateriality level, concerning the completeness of the emission inventory. As part of
# ve reviewed as follows;
#
# te and report the emissions data
#
# upporting the report were based on historical in nature. May include partially
#
# ta and information (refer to the inventory for detat s)
#
# Environmental Social Governance
#
# EsGData @
#
# Conclusions
#
# Based on the process and procedures conducted, there is no evidence that the inve
# and is not a fair representation of GHG data and information;
#
# - DNV presents an ‘Unmodified’ opinion on Greenhouse Gas Emissions
#
# Other indirect emissions (Scope 3: Category 11) of LG electronics
#
# Year Upstream Downstream
# 2023 5,340,780 64,884,353
# In order to report the GHG emissions as an integer, the rounded number on the opinion might be differer
# £1tCO;eq
# 3 Refer to Annex for greenhouse gas emissions by categories,
# Sa
# DNV
# Annex to ‘PRJN-704268-2024-AST-ENG’
# Other indirect emissions (Scope 3) of LG Electronics in 2023
# Categories Upstream Downs
# 1 Purchased goods and services 2,807,879
# 2 Capital goods 400,997
# 3 Fuel- and energy- related activities (not included in 135,070
# Scope 1 or Scope 2)
# 4 Upstream transportation and distribution 1,794,560
# 5 Waste generated in operation 12,769
# 6 Business travel 46,073
# 7 Employee commuting 78,055
# 8 Upstream leased assets 65,377
# 10 Processing of sold products
# 11 Use of sold products é
# 12 End-of-life treatment of sold products
# 13 Downstream leased assets
# 15 Investments
# Total emissions 5,340,780 6
#
# in order to report the GHG e1
#
# ions as an integer, the rounded number on the statement might be differe
#  149 2023-2024 LG Electronics Sustainability Report
#
# Independent Assurance Statemen
#
# To readers of LG Electronics Sustainability Report 2023-2024
#
# Introduction
#
# Korea Management Registrar (KMR) was commissioned by LG Electronics to conduct an independent assurance
# of its Sustainability Report 2023-2024 (the “Report”. The data and its presentation in the Report is the sole
# responsibility of the management of LG Electronics. KMR’s responsibility is to perform an assurance engagement
# as agreed upon in our agreement with LG Electronics and issue an assurance statement.
#
# Scope and Standards
#
# LG Electronics described its sustainability performance and activities in the Report. Our Assurance Team carried
# out an assurance engagement in accordance with the AAI000AS v3 and KMR’s assurance standard SRV1000. We
# are providing a Type 2, moderate level assurance. We evaluated the adherence to the AAIOOOAP (2018) principles
# of inclusivity, materiality, responsiveness and impact, and the reliability of the information and data provided using
# the Global Reporting Initiative (GRI) Index provided below. The opinion expressed in the Assurance Statement has
# been formed at the materiality of the professional judgment of our Assurance Team.
#
# Confirmation that the Report was prepared in accordance with GRI standards 2021 was included in the scope
# of the assurance. We have reviewed the topic-specific disclosures of standards which were identified in the
# materiality assessment process
#
# + GRI Sustainability Reporting Standards 2021
# + Universal standards
# + Topic specific standards
# - GRI 205: Anti-corruption
# - GRI 302: Energy
# - GRI 303: Water and Effluents
# - GRI 305: Emissions
# - GRI 306: Waste
# ~ GRI 401: Employment
# - GRI 403: Occupational Health and Safety
# - GRI 404: Training and Education
# - GRI 405: Diversity and Equal Opportunity
# - GRI 406: Non-discrimination
# - GRI 408: Child Labor
# - GRI 409: Forced or Compulsory Labor
#
# Overview Environmental Social Governance
#
# ESG Data Appendix om <>)
#
# - GRI 414: Supplier Social Assessment
# - GRI 416: Customer Privacy
# + Etc. Material Issue
# - Material Topic Issue
# - The Data of Supply Chain Management
# - Voice of Customer
# - Health and Safety (Dead rate, LTIFR)
#
# As for the reporting boundary, the engagement excludes the data and information of LG Electronics's partners,
# suppliers and any third parties.
#
# KMR's Approach
#
# To perform an assurance engagement within an agreed scope of assessment using the standards outlined above,
#
# our Assurance Team undertook the following activities as part of the engagement:
#
# + reviewed the overall Report;
#
# + reviewed materiality assessment methodology and the assessment report;
#
# + evaluated sustainability strategies, performance data management system, and processes;
#
# + interviewed people in charge of preparing the Report;
#
# + reviewed the reliability of the Report's performance data and conducted data sampling;
#
# * assessed the reliability of information using independent external sources such as Financial Supervisory Service’s DART and
# public databases.
#
# Limitations and Recommendations
#
# KMR's assurance engagement is based on the assumption that the data and information provided by LG
# Electronics to us as part of our review are provided in good faith. Limited depth of evidence gathering including
# inquiry and analytical procedures and limited sampling at lower levels in the organization were applied, To address
# this, we referred to independent external sources such as DART and National Greenhouse Gas Management
# System (NGMS) and public databases to challenge the quality and reliability of the information provided.
#  150 2023-2024 LG Electronics Sustainability Report
#
# Conclusion and Opinion
#
# Based on the document reviews and interviews, we had several discussions with LG Electronics on the revision
# of the Report. We reviewed the Report's final version in order to make sure that our recommendations for
# improvement and revision have been reflected. Based on the work performed, it is our opinion that the Report
# applied the GRI Standards. Nothing comes to our attention to suggest that the Report was not prepared in
# accordance with the AAIOOOAP (2018) principles.
#
# Inclusivity
#
# LG Electronics has developed and maintained different stakeholder communication channels at all levels to
# announce and fulfill its responsibilities to the stakeholders. Nothing comes to our attention to suggest that there
# is a key stakeholder group left out in the process. The organization makes efforts to properly reflect opinions and
# expectations into its strategies.
#
# Materiality
#
# LG Electronics has a unique materiality assessment process to decide the impact of issues identified on its
# sustainability performance. We have not found any material topics left out in the process.
#
# Responsiveness
#
# LG Electronics prioritized material issues to provide a comprehensive, balanced report of performance, responses,
# and future plans regarding them. We did not find anything to suggest that data and information disclosed in the
# Report do not give a fair representation of LG Electronics's actions.
#
# Impact
#
# LG Electronics identifies and monitors the direct and indirect impacts of material topics found through the
# materiality assessment, and quantifies such impacts as much as possible.
#
# C Overview Environmental Social Governance
#
# Reliability of Specific Sustainability Performance Information
#
# In addition to the adherence to AAIOO0AP (2018) principles, we have assessed the reliability of economic,
# environmental, and social performance data related to sustainability performance. We interviewed the in-charge
# persons and reviewed information on a sampling basis and supporting documents as well as external sources and
# Public databases to confirm that the disclosed data is reliable. Any intentional error or misstatement is not noted
# from the data and information disclosed in the Report.
#
# Competence and Independence
#
# KMR maintains a comprehensive system of quality control including documented policies and procedures in
# accordance with ISO/IEC 170212015 - Requirements for bodies providing audit and certification of management
# systems. This engagement was carried out by an independent team of sustainability assurance professionals.
# KMR has no other contract with LG Electronics and did not provide any services to LG Electronics that could
# compromise the independence of our work.
#
# June 2024 Seoul, Korea
#
# AA1000
#
# Km) ‘SIA SRVIOOO Kicensed Assurance Provider
# ceo S. ST Hoag

# %% [markdown]
# ### Pros and Cons (PyTesseract):
#
# Pros:
# - OCR scanner, which can extract text from scanned PDFs
# - Best choice for images, scanned documents, and non-text PDFs.
# - Can handle rotated or skewed texts
#
# Cons:
# - OCR involves image processing, hence it is slower than pure text extraction
# - It does not preserve formatting (text might be out of order)
# - Table and multi-column layouts may be extracted incorrectly.
# - Pytesseract must convert PDFs to image first using pdf2image

# %%
from pdf2image import convert_from_path
import cv2
import numpy as np
import pytesseract
import pandas as pd  # Ensure Pandas is imported

# Replace with your actual PDF path
input_pdf_path = "/Users/jeremiahtay/DSA3101/2023-2024_Sustainability_Report_(ENG)_.pdf"
output_file_path = "/Users/jeremiahtay/DSA3101/LG_Sustainability_Report.txt"

# Convert PDF pages to images
pages = convert_from_path(input_pdf_path)

def deskew(image):
    """Corrects skew in an image using OpenCV."""
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.bitwise_not(gray)
    coords = np.column_stack(np.where(gray > 0))
    angle = cv2.minAreaRect(coords)[-1]
    
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle

    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

def get_conf(image):
    """Calculates the OCR confidence level of the image."""
    ocr_data = pytesseract.image_to_data(image, output_type=pytesseract.Output.DICT)
    conf_values = [int(conf) for conf in ocr_data["conf"] if conf.isdigit()]
    return sum(conf_values) / len(conf_values) if conf_values else 0

def process_page(page):
    """Processes an image page: Deskews, extracts text, and removes headers/footers."""
    try:
        page_arr = np.array(page)
        page_arr_gray = cv2.cvtColor(page_arr, cv2.COLOR_BGR2GRAY)
        page_deskew = deskew(page_arr_gray)
        page_conf = get_conf(page_deskew)
        
        # Extract OCR data
        d = pytesseract.image_to_data(page_deskew, output_type=pytesseract.Output.DICT)
        d_df = pd.DataFrame.from_dict(d)
        
        # Get block number
        block_num = int(d_df.loc[d_df['level'] == 2, 'block_num'].max())
        
        # Drop header and footer by index
        header_index = d_df[d_df['block_num'] == 1].index.values
        footer_index = d_df[d_df['block_num'] == block_num].index.values
        
        # Combine text in dataframe, excluding header and footer regions
        text = ' '.join(d_df.loc[(d_df['level'] == 5) & (~d_df.index.isin(header_index) & ~d_df.index.isin(footer_index)), 'text'].values)
        return page_conf, text
    except Exception as e:
        return -1, str(e)

# Extract text from all pages using process_page
extracted_text = []
for page in pages:
    conf, text = process_page(page)
    extracted_text.append(text)

# Combine extracted text
combined_text = "\n".join(extracted_text)

# Save to file
with open(output_file_path, "w", encoding="utf-8") as file:
    file.write(combined_text)

print("Extraction complete. Text saved to:", output_file_path)
# Out:
# Extraction complete. Text saved to: /Users/jeremiahtay/DSA3101/LG_Sustainability_Report.txt

# %%
combined_text = " ".join(extracted_text)
output_file_path = "/Users/jeremiahtay/DSA3101/LG_Sustainability Report.txt"

# Open the file in write mode and save the text
with open(output_file_path, "w", encoding="utf-8") as file:
    file.write(combined_text)

print(combined_text)
# Out:
# LG Electronics Sustainability Report
#
# BETTER
#
# LIFE
#
# FOR ALL
#
# Life’s
# Good.
#  cs Sustainability Report [overview Environmental Social Governance ESG Data AY
# ts
#
# Environmental 12 ~~ Social 29 Governance 80 ESG Data 100 = Appendi:
#
# 3 Environmental Management Policy 13 Human Rights 30 Corporate Governance 81 Sustainability Management Data 101 GRI Inde»
#
# 4 Addressing Climate Change 15 Employee 44 — Jeong-Do Management 86 = Membership-Awards & Recognition 124 — SASB Ind
#
# 8 Resource Circulation 18 Supply Chain 56 Compliance Management 88  SHEE-Quality Certification Status 125 UN SDGs
#
# 10 Product Stewardship 23. Customer 66 — Risk Management 92 Materiality Assessment 126 ~—TCFD Ref
#
# Business Sites Operation 26 ~~ Local Community 75 Information Security 95 Stakeholder Communication 129 Greenhot
#
# Statemer
#
# Independ
#
# its commitment to making changes that will help it to achieve sustainable growth and
# tablished and implemented goals and action plans to realize them. In the Sustainability
# its management approach (MA), goals, activities, progress, and performance on tasks and
# onment, society, and governance. These are linked to the material issues derived from the
# Electronics’ six ESG strategic tasks. LG Electronics will continue to transparently disclose
# ctivities and performance through the publication of this report each year.
#
# indards
#
# stainability Report adheres to GRI Standards 2021, an international standard guideline,
# dards and frameworks set forth by the Sustainability Accounting Standards Board (SASB)
# related Financial Disclosures (TCFD). We also reported out progress in implementing The
# ations Global Compact (UNGC) in four areas: human rights, labor, environment, and anti-
# st the four principles of inclusivity, materiality, responsiveness, and impact as outlined in
# y Principles Standard), which also outlines the obligation of companies to disclose their
# nagement.
#
# Reporting Period
# This report covers our activities from January 2023 through December 2023, and for some key
# through the first half of 2024. For quantitative performance, we provide three years of data fror
# performance trends,
#
# Scope of Report
#
# The scope of this report covers the headquarters, production sites in Korea and overseas,
# by LG Electronics. Financial information is presented on a consolidated financial statement t
# International Financial Reporting Standards (K-IFRS), and some financial information pr
# statement basis is presented in the footnotes. All financial information in USD has been calc
# exchange rate. Where there are limitations in data collection or changes to the calculati
# reporting scope and the reason for the change in the footnotes.
#
# Third Party Assurance
#
# To ensure the accuracy, objectivity and reliability of the report preparation process and
# Electronics commissioned an independent assurance organization (Korea Managemer
# assurance in accordance with international assurance standards. The results of the third-
# in detail on page 149 of this report. The financial information in this report has beer
#
# of greenhouse gas emissions and energy usage was conducted in accordance with tt
#
# Administrative Guideline for the Greenhouse Gas Target Management System,
#  cs Sustainability Report
#
# e CEO
#
# Social Governance
#
# ESG Data A
#
# mpany, LG Electronics will promote sustainable management to ensure a ‘Better Life for All’
#
# akeholders,
#
# plagued the global market with prolonged
# 2S, leading to a slowdown in consumption.
# scarbonization and digital transformation
# and customers are pursuing engagement-
# S experience consumption. To proactively
# ; in the market and with customers,
# sion last year to transform from a ‘Global
# d' to a ‘Smart Life Solution Company’ that
#
# se experiences of customers.
# 2 appliances to a Smart Life Solution
#
# iture, LG Electronics is focusing on the
# n, digitalization and electrification. During
# vew touch points and pursue changes to
# 3C 2S' (Connectivity, Care, Customization,
# erience area. In particular, we will focus on
# 1odels, growing B2B business, and securing
# ree pillars to expand customer touchpoints
# ial front, we wi
#
# )30, achieving the ‘Triple 7’ goal (CAGR and
#
# 1g 7%, and enterprise value greater than 7x).
#
# leap forward to become a
#
# rowth, LG Electronics conducts ESG
#
# of a ‘Better Life for All’ We have chosen
#
# rcularity, Clean Technology) for the planet
#
# and the 3Ds (Decent Workplace, Diversity & Inclusion, Design for All) for
# people as our ESG strategic tasks. LG Electronics is implementing these
# tasks to achieve mid-to-long term goals.
#
# For the Planet
#
# LG Electronics is pursuing a broad range of activities to protect our
# planet. To achieve carbon neutrality at the product production stage by
# 2030, we are reducing carbon emissions through energy-efficient facilities
# at our production sites and expanding the use of renewable energy. LG
# Electronics is leveraging the
#
# development of energy-efficient products and electrification to reduce
# carbon emissions by 20% during the product use stage by 2030.
# Additionally, we are actively increasing the use of recycled plastic in our
# products, having used a cumulative total of 114,000 tons of recycled
# plastic over the past three years. Plastic cushioning materials used in our
# packaging are being replaced with paper alternatives as well. Last year,
# LGE developed the industry's first pulp mold (paper cushioning material)
# that can cushion over 20kg. Starting with air purifiers, use of pulp mold
#
# will be expanded to larger products.
#
# For People
# LG Electronics is committed to providing convenient products and
# services for everyone. Last year, we enhanced the accessibility of our
# products by launching the LG Comfort Kit, which greatly increases user
# convenience for our home appliances. In addition, we are operating a
# Sign Language Consultation Center at our service touch points, and are
# offering the Best Companion Care Service, which provides one-on-one
#
# assistance from the vehicle to the store by a dedicated manager.
#
# Meanwhile, as the importance of supply ch
#
# grow, LG Electronics is constantly checki
# at its production sites and suppliers. As }
# Business Alliance (RBA), LG Electronics will.
# for labor rights, safety and health, envirc
# management systems in its global supply
#
# supply chain risks.
#
# As we work towards achieving our busines
# Life Solution Company, we are fully dedic
#
# management in pursuit of a better life for a
#
# Chief Exe
#  cs Sustainability Report
#
# lew
#
# anagement philosophy, and guides the thoughts and actions of all LG associates.
# G's vision of "No. 1 LG" by practicing 'People-oriented Management’, and ‘Creating
# "Jeong-Do Management.”
#
# * Vision
# The ultimate goal of LG is to be
# recognized as the market leader in
# business performance as well as in
# management practice.
#
# Jeong-Do Management
#
# ° Management
# Principles
# The fundamental
#
# Customer-Value Creation |
# People-Oriented Management
# organizational principle
# guiding LG from its
# beginning as a firm
#
# Environmental Social Governance
#
# Overview
#
# ESG Data A
#
# LG Electronics Mission and Vision
# Based on the brand philosophy of "Life's Good," LG Electronics always strives to pre
# Unique, and New (F-U-N) experiences to make their lives better. We will become a
#
# that connects to and extends customers' experiences in every space of their li
# to include their homes, commercial spaces, mobile spaces including vehicles, an
#
# Metaverse.
#
# Mission
#
# Innovation for a Better Life
#
# Our reason for existing, and our promise to the customers
#
# jon
#
# Smart Life Solution Company
#
# By 2030, we are committed to becoming a company with USD 76.6 bi
# achieving the ‘Triple 7": a 7% CAGR, a 7% operating margin, and an EBITD/
#
# Core Value
#
# ays put the
# customer first
#
# We always put our customers first and make our jud
# based on them.
#
# More exciting
# challenges
#
# We are courageous and positive, constantly finding
# and executing better ideas.
#
# The best that exceeds
# expectations
#
# We aim to be the best and most recognized by exce
# everyone's expecta
#
# Warm
#
# respect We genuinely respect each other's personality and d
#
# Confidence in taking
# the right way
#
# We take pride in competing and winning fairly.
#
#  cs Sustainability Report
#
# Corporation
#
# ctronics Inc
#
# Social Governance ESG Data At
#
# Shareholder Status
#
# Status of Shareholders Holding 5% or more
#
# Largest Shareholders and Affiliated Perso!
#
# in Towers, 128 Yeoui-daero, Yeongdeungpo-gu, Shareholder Number of Shares Shareholding Rati Shareholder Relationship Owne
# Korea (Shares) (%) (s
# facturing LG Corp 55,094,582 33.67 LG Corp Holding company 55,092
# erators, Washing Machines, Air Conditioners, National Pension Affiliated company
#
# m Cleaners, TVs, Audio Sound Systems, Automotive Ser 11191518 6.84 Ging Sacer executive
# onents, Monitors, PCs, Signage, etc. William Affiliated company |
#
# n oowan) Cho
#
# er 1, 1958
#
# 3BB(Stable) / Moody's: Baa2(Stable)
#
# 3 (35111 in Korea, 37,702 in overseas)
#
# ompany
#
# Ratio (%)
#
# 7
#
# 12
#
# (Voting share, as of December 31, 2023)
#
# Sales (Consolidated)
#
# (oowan) Cho executive
#
# Global Sales
#
# Classification Sales (KRW 100 n
#
# ion)
#
# usD 64.5 billion
#
# Operating Income (Consolidated)
#
# Korea 342,720
# ® North America 203,475
# Europe 121,293
# Asia 74,880
# Latin America 31124
# Middle East & Africa 32,873
# China 25,418
# Russia (CIS) 10,495
# Total 842,278
#
# “4
#
# USD 2 / billion
#
# Exchange rate: USD 1 = KRW 1,306
# (Average exchange rate in 2023)
#  6 2023-2024 LG Electronics Sustainability Report Environmental Social Governance ESG Data Appendix oO eg < >)
#
# Compan
#
# Global Business Sites”
#
# Russia (CIS) (As of end of March 2024)
# Sales & Production 1
# Production 1
# Sales 2
# sd
# ie China North America
#
# Sales & Production 3
#
# Sales & Production Sales & Production 2
#
# Producti 2
# — Production 8 Production 4
# Sales 13
# Oth 4 Sales Sales
# ie
# ° Other 3 Other 14
# Korea
# Middle East and Africa Sales & Production 1 Central and South
# i Production 5 America
# Sales & Production 2 ————
# Production 5 a
# Sales & Production Production 4
# Sales ai) ‘ sles 5
# Production 3
# Other 4 other ;
#
# Sales 9 Z
#
# Other 10
#
# Production
#
# 33
#
# * Number of business sites according to internal management standards
#
#  cs Sustainability Report
#
# Overview Environmental Social
#
# Governance
#
# ESG Data Ay
#
# nce & Air Solution (H&A), Home Entertainment (HE), Vehicle component Solutions (VS), and Business Solutions (BS) Business Companies, LG Electronics is a global leader in te
#
# me appliances, IT, automotive components, and signage, with operations at approximately 140
#
# r Solution
#
# % Air Solution)
#
# al home appliance
# products that
# gies with premium
# =xtensive research
# 2 world, including
# and lifestyle, and
# ing brand not only
# but also in future
#
# nes.
#
# Home Entertainment
#
# The HE (Home Entertainment) company strives
# to provide customers with a better life from
#
# the perspectives of wellness, beauty, and
# entertainment. Through a wide range of devices,
# including TV and audio devices, as well as webOS-
# based platform businesses and content services,
# we bring inspiring experiences to our customers’
#
# daily lives. We constantly deliver innovative
#
# solutions that make our customers’ lives more
# comfortable, beautiful, and enjoyable, such as
# LG OLED TVs with the highest picture quality
# available, ease of use and a design that fits
# customers’ lifestyles, LG StandbyME, a personal
# screen, and LG TONE Free earbuds that achieve
#
# high fidelity audio.
#
# es around the world.
#
# Vehicle component Solutions
#
# Under the vision of ‘Innovation Partner for
#
# Future Mobility’ the VS (Vehicle component
# Solutions) company is transforming itself into a
# true innovation partner that achieves customer
# value by making proposals for future mobility
# solutions, rather than staying as a traditional
# automotive component supplier. Based on its
# advanced technology in the fields of electricity and
# electronics and its user experience know-how in
# home appliances, we are providing differentiated
#
# value for the future of autonomous driving and
#
# next-generation electric vehicles.
#
# Business Solutior
# Our BS (Business Solut
#
# a true business partne
# value enhancement an
# customers by proposin
# solutions based on cus
# "Trust First’ perspectiv
# trust. We combine adv
# with deep insights into
# the best products and
#
# innovative experience 1
#
# expectations.
#
#  cs Sustainability Report
#
# or the Planet
#
# [Overview] Environmental Social Governance
#
# A
#
# the Planet
#
# - Renewable Energy Transition
#
# 5 to achieve carbon neutrality through process improvement, the introduction of
#
# le use of renewable energy to reduce greenhouse gas emissions and the purchase
# “100 participant, we have also set a goal of achieving 100% renewable energy at all
#
# siness sites by 2050.
#
# ollection and Recycling
#
# generated at all of our Korean and overseas business sites and will expand the
# cate for all of its global business sites. We achieved our goal of reaching a 95%
# ) ahead of schedule, and will maintain 95% or higher. We are also proactively
# countries where we operate, establishing relevant policies and collecting e-waste.
#
# ious materials for product manufacturing as well as packaging materials, and carry
# e appliances and batteries.
#
# roducts - Using Environmentally Conscious Materials
#
# 1G emission intensity at the product use stage through high-efficiency energy
# sity refers to the amount of greenhouse gases emitted per unit of product during
# duct. For example, a refrigerator emits per liter of content, while a washing machine
# ] capacity. We became the first Korean home appliance company to receive SBTi
#
# e) verification of our product use stage carbon emission reduction targets.
#
# Performance in 2023
#
# YOY carbon emissions reduction
#
# Global renewable energy transition
#
# Waste recycling rates of business sites
#
# Cumulative collection of e-waste (Since 2006)
#
# Reduction of GHG emission intensity of
# seven major products at the product use stage
#
# Cumulative use of recycled plastic (Since 2021)
#
# 114
#  cs Sustainability Report
#
# or People
#
# [Overview] Environmental Social Governance ESG Data A
#
# People
#
# man Rights in Supply Chain
#
# esponsibility to protect the safety and health of the working environment and human
# Jement program at its production sites. By 2030, we aim to achieve zero critical non-
# uction sites based on audit requirements, and we conduct self-assessments and on-
# ify and improve potential and actual risks. We also evaluate the suitability of the ESG
#
# ad provide related training and consulting.
#
# ce for pursu
#
# \g responsi ies in global supply
#
# male Talents and Expanding Hiring for People with Disabilities
# equity, and inclusion (DEI) in our organizational culture so that all employees feel
# longing, and realize their potential. To this end, we have set a target of having 3.5%
# 1 Korea and 25.5% of female employees (on a global basis) by 2030.
#
# ce Accessibility
#
# echnologies to improve the accessibility of its products, and is working to improve
# g sign language counseling services and Braille sticker attachment service to home
# e an accessibility advisory group to promote product development that considers
#
# isers. We will apply accessibility technologies and universal design to all products
#
# : for all users, including people with disabilities, seniors, and children.
#
# Performance in 2023
#
# Ratio of ISO 45001 (Health and Safety Management System)
#
# certified production sites
# (Exclu
#
# new subsidiaries (2 in the US, 1 in Mexico) that have not started mass production.)
#
# Percentage of production sites with zero critical non-conformances
# (Based on RBA audit requirements)
#
# Percentage of high-risk suppliers
#
# (Based on self-assessments)
#
# Percentage of female employees (Global)
#
# Employment rate of people with disabilities (Korea)
#
# SS
# Home Appliances TV Commo
# 9 products with voice Listening to TV together, Learning languag
# guidance, 5 products remote control, Shortcuts to sign lan
# with voice recognition accessibility features digital h
#
# services
#  cs Sustainability Report
#
# 1ologies Leading the Global HVAC Market
# heating, ventilation, and air conditioning (HVAC) market through the manufacturing
# ating and cooling solutions. We offer a wide range of high-quality products for
#
# 1, from personal devices to industrial and specialized HVAC systems.
#
# Individual Control Solution:
# Al Wireless Remote Controller
#
# External linkage solution:
# (BMS linkage system) ACP 5
#
# evel of Competence
#
# / storage system (ESS) solutions with high-quality products and site-specific design
# the largest integrated test facility in Korea and introducing the ISO 9001 quality
# -scale products, LG Electronics’ ESS has improved the efficiency of PCS (Power
# mized electricity losses. In addition, the high-quality batteries and sophisticated
#
# tem) ensure both reliabi ity and efficiency, and we were able to maxi
#
# ize the space
# y reducing the product size by 70% compared to competitors. In recognition of this
#
# ly completed the first ESS installation integrated with solar power in Korea. (Sejong
#
# [overview Environmental Social
#
# Governance ESG Data At
#
# Vehicles
#
# Space-Customized EV Charging Solutions
# In March 2024, LG Electronics introduced three electric vehicle charging solutions (
#
# charger, and 200kW fast charger) optimized for various spaces, such as residenti
# charging stations. The 7kW slow charger for residential use features a touchscre
# and is available in both wall-mounted and free-standing models to fit a variety
# The 100kW fast charger allows for simultaneous charging (up to two vehicles), ma
# lots at places such as shopping malls, hospitals, and restaurants, while the 200!
# charging speeds and can be used at EV charging stations. LGE’s charging solutions «
# temperatures as low as minus 25 degrees Celsius and as high as 40 degrees Celsit
#
# for water and dust resistance and IK10 for shock resistance.
#
# EV Charging Solution
#  cs Sustainability Report
#
# ake Appliances Easier to Use for Everyone
# ople with physical disal
#
# ‘ied their challenges in using home appliances, analyzed them by user type and
#
# ies, hearing impairments, visual impairments, and brain
#
# 3 Comfort Kit, a practical modification that can be attached to existing products,
# 1e LG Comfort Kit incorporates universal design to make LG home appliances easy
# jless of gender, age, or disability.
#
# ee
#
# LG Comfort Kit
#
# Purifier that Leaves No One Behind
#
# ‘s launched the 'PuriCare Objet Collection Water Purifier’ with a voice recognition
# users to dispense water in 10ml increments without pressing the button, but also
# sr they have consumed in the past week. This allows anyone to use the product
# visual impairments to the elderly who had difficulty using the product because the
# to see, to children who are too short to reach the dispensing button.
#
# er Purifier
#
# [overview Environmental Social
#
# Governance ESG Data At
#
# Water, Waste and Ecosystem Restoration
#
# Water-Soluble Glass
#
# Changes in the marine environment are causing the ocean desertification, resu
# seaweeds such as wakame and kelp in coastal rocky areas, which is damaging the
# its biodiversity conservation efforts, LG Electronics is developing a water-soluble gl
# restoration of marine ecosystems. The water-soluble glass changes to a mineral
# which can be utilized to help algae grow in the ocean, restoring marine ecosystems.
# The water-soluble glass utilizes technology that consistently dissolves mineral ions,
# in water to promote the growth of algae in the ocean, much like fertilizer for cro
# marine forests. The increased amount of algae become an essential food source ar
# in the marine ecosystem, creating the environment they need to thrive and grow. A
# environment by absorbing carbon dioxide and releasing oxygen. Since 2023, we t
# National Institute of Science and Technology (UNIST), Research Institute of Indu
# (RIST), and other specialized research institutes to demonstrate the safety o
# effectiveness in promoting the growth of algae. We also signed an MOU with the |
# (KOPRI), a government-funded organization, to demonstrate its applicability and.
#
# marine environment.
#
# Microplastics Care Course
#
# Washing clothes is essential to keep them clean and smelling good. However, wast
# fibers releases microscopic plastic fibers into the water. This water is either dischar
# and returned to water resources. LG Electronics has introduced an advanced microy
# the formation of microplastics by household laundry. The course utilizes LG's 6-N
# Stepping, Scrubbing and Filtration) technology to reduce fiber friction, prevent m
# minimize energy consumption.” ThinQ UP washing machine users can download
# from the Upgrade Center in the ThinQ app.
#
# 1) Washing a 3-kilogram training jacket made of 100% polyester using the microplastics care course resulted
# 20un compared to the standard wash course, The microplastics care course also reduced water tempera
# course, leading to a 30% reduction in energy use.
#  12 2023-2024 LG Electronics Sustainability Report ¢ Overview Social Governance ESG Data Appendix oOo fe < >)
#
# Environmental
#
# Environmental Management Policy 13 | Addressing Climate Change 15 | Resource Circulation 18 | Product Stewardship 23 | Business Sites Operation 26
#  13 2023-2024 LG Electronics Sustainability Report
#
# Environmental Management Po
#
# Environmental Management Policy
#
# 1. Purpose
#
# As a responsible corporate citizen, LG Electronics is committed to environmental protection throughout all its
# business activities. We adhere to the highest environmental standards and international agreements, and we
# continuously strive to minimize our environmental impact through ongoing improvements. Aligned with the UN
# Sustainable Development Goals (SDGs), we have established ambitious goals for reducing our environmental
#
# footprint and have enacted this Environmental Policy to guide our efforts.
#
# 2. Coverage
# LG Electronics applies the most stringent standards when environmental laws and regulations in different
#
# countries conflict.
#
# @ Production operations and business facilities
#
# @ Products and services
#
# @ Distribution and logistics
#
# @ Management of waste
#
# © Suppliers, Service Providers, Contractors, and Other Key Business Partners
#
# © Mergers, Acquisitions, and New Businesses
#
# 3. Principles
# To promote environmental management, LG Electronics defines the following fundamental principles for each
# environmental topic.
# © Air Pollutants
# - Identify the types, characteristics, and emissions volume of air pollutants generated our operations and treat
# them according to regulations before discharge. Effective manage ozone-depleting substances in accordance
# with the Montreal Protocol and relevant regulations, and continuously monitor the treatment efficiency of
# pollution control facilities.
# @ Water Pollutants
# + Treat all wastewater according to regulations before discharge, and continuously monitor treatment results to
#
# ensure that the emission of water pollutants is always within the standard limits.
#
# Overview Social Governance ESG Data Appendix Oo tf < >)
#
# @ Hazardous Substance
#
# + Identify and record all chemicals (including hazardous waste) that are hazardous to human health or have the
# potential to cause environmental pollution when released from our workplaces, and safely store, transport,
# use, recycle/reuse, and dispose of these substances. Establish emergency response plans and conduct regular
#
# training to prevent environmental pollution and accidents caused by leaks or spills during handling
#
# + LG Electronics products are managed Guidelines for hazardous substance management in products to ensure
#
# that they do not contain substances prohibited by global conventions or pose a risk to human health
#
# @ Waste
#
# + Identify the types, characteristics, and emission quantities of waste generated at our facilities and treat
# and dispose of it in compliance with regulations. Strive to reduce waste generation. Select waste disposal
# contractors (including transporters) that are legally qualified to transport and dispose of waste after evaluating
# their suitability (including on-site inspections). Minimize the proportion of waste landfilled or incinerated and
#
# strive to improve the recycling rate of waste.
#
# - Consider the enhancement of reusability and recyclability from the product development stage and strive for
#
# the lawful collection and treatment of end-of-life products to minimize environmental impact.
#
# © Energy
#
# - Monitor energy consumption and greenhouse gas emissions to improve energy efficiency at our facilities and
# continuously review ways to enhance efficiency. Promote energy-saving activities. Strive to use sustainable
# energy by implementing renewable energy solutions tailored to our facilities’ conditions, such as installing
# renewable energy generation facilities, purchasing renewable energy certificates, and entering into power
#
# supply contracts.
#
# © Greenhouse Gas
# - Actively respond to climate change by developing and implementing effective greenhouse gas reduction
# measures and setting targets. Publicly disclose performance and reduction efforts for energy consumption and
#
# significant categories of Scope 1,2, and 3 emissions.
#  14 2023-2024 LG Electronics Sustainability Report
#
# @ Water Resource
# - Explore ways to reduce and reuse water consumption. Implement activities to identify and mitigate water
# scarcity risks.
#
# ® Biodiversity Conservation
#
# - Strive to conserve and restore biodiversity within LG Electronics’ sphere of influence.
#
# © Preventing Deforestation
# - Recognize the potential for deforestation issues that may arise within LG Electronics’ sphere of influence and
# strive to minimize negative impacts.
#
# 4. Management System
#
# @ Role of the Board of Directors and Top Management
#
# LG Electronics ensures the oversight of all environmental management and performance improvement
# activities through the ESG Committee within the Board of Directors and management meetings involving top
# management. The ESG Committee within the Board of Directors reviews and deliberate on environmental
# management policy revisions, responses to environmental laws and regulations, and environmental
# management performance, including climate response, at least once a year. The main roles of the management
# meeting involving top management include reviewing and deciding on environmental management risk reviews
# and response measures, as well as other matters deemed necessary for the dissemination/propagation of
# environmental management.
#
# @ Roles of the Dedicated Organization
#
# LG Electronics designates an environmental management implementation organization to carry out related
# tasks. The environmental management implementation organization reviews environmental laws and
# regulations, stakeholder requirements, and prepare response measures; establish and operate environmental
# management goals and indicators; build and operate environmental management systems, and conduct
# education and awareness improvement for major stakeholders and information disclosure.
#
# 5. Education and Awareness Improvement
# LG Electronics operates education programs for employees and key stakeholders to comply with this policy, share
# information on environmental policies, goals, and performance. Through this, the company raise awareness of
# environmental management and encourage employees to prioritize the environment in their work processes.
#
# \
#
# DG < >)
#
# Governance ESG Data Appendix
#
# 6. Information Disclosure and Communication
#
# LG Electronics transparently disclose environmental information related to products and business sites, as well
# as environmental policies and implementation plans, through its website, sustainability reports, and other means.
# The company also communicate with employees and stakeholders on environmental management performance
# and environmental policies, and reflect their opinions to continuously improve policies.
#
# 7. Performance Evaluation and Improvement
#
# LG Electronics sets and implement medium- to long-term performance goals for its environmental factors based
# on environmental policies. The company regularly evaluates the progress of goal implementation and check goal
# achievement, analyze the evaluation results to identify areas for policy improvement, and adjust goals according
# to the situation.
#
# Environmental Management System (ISO 14001) Certification
# To efficiently manage environmental risks by systematically identifying, evaluating, managing, and improving the
# elements necessary for environmental management, LG Electronics has acquired ISO 14001 certification for all its
#
# Korean and overseas production sites, which it has kept up-to-date.
#
# Number of ISO 14001 Certified Production Sites
#
# (As of 2023)
# Classification Acquisition / Renewal Total Certification
# Acquisition Rate
# Korea 5 5
# Overseas 25 25* 1 00%
#
# * Excluding new subsidiaries (2 in the US and 1 in Mexico) that have not started mass production.
#  cs Sustainability Report
#
# ate Change
#
# bon Emissions
# 1g a GHG Reduction Plan
#
# lectronics has set GHG reduction targets for the entire lifecycle of its products, from
# e aim to reduce the total amount of direct GHG emissions (Scope 1) and indirect GHG
# ict production stage by 54.6% by 2030 compared to 2017 levels in accordance with the
# »missions intensity in the product use stage by 20% by 2030 compared to 2020 levels.
# 2vement of these GHG reduction goals are being achieved, in 2021 LG Electronics
# ipany in the home appliance industry to declare its GHG reduction targets to
# itiative (SBTi) and have them verified by a third party. Since then, we have been
# rogress towards the targets submitted to SBTi, and are continuously implementing
#
# s in this area.
#
# n Plan
#
# Implementing
# external GHG
#
# Reducing GHGs in
# the product use
# reduction projec’
#
# stage
#
# : D
# Promote carbon credit CDM Reduce GHG emission intensity of
#
# project through sales of high- seven major product categories by
#
# BTi's efficiency products 20% by 2030 compared to 2020
#
# - Cumulative 560,000 tons of carbon
# credits issued as of 2020, with
# more to be secured by 2025
#
# in the Product Production Stage
#
# nissions during the product production stage, LG Electronics has implemented
# nd carbon emission reduction devices to our manufacturing process. We have
# cover and recycle refrigerant that escapes during the injection of HFC-based
#
# overed refrigerant, thereby reducing refrigerant leakage.
#
# Environmental Social Governance ESG Data At
#
# Promoting External GHG Reduction Projects
#
# LG Electronics is promoting a CDM project in India that converts the electricity sa
# efficiency refrigerators into carbon credits. Since receiving approval for the pro
# Framework Convention on Climate Change (UNFCCC) in 2013, we have secured 5!
# by 2020, and plan to secure additional credits by 2025. This equates to a reduct
# GWh through the use of our high-efficiency refrigerators. Cumulatively, the project
#
# tons of carbon credits.
#
# Global GHG Emissions
#
# Year Unit Direct GHG Emission (Scope 1) Indirect GHG Emission (Scope 2)
# 2019 604 869
# 2020 429 865
# 2021 1,000 333 819
# 2022° tCO.eq 265 662
# 2023 209 665
# 2030 Goal 923 (54.6% reduction compared to 2017, in accordant
#
# * Data corrected due to changes in processing of significant figures
#  cs Sustainability Report
#
# at the Product Use Stage
#
# various efforts to reduce GHG emissions at each stage of the product life cycle.
# product weight, conserving resources, and improving energy efficiency. Notably, we
# rgy-efficient products to reduce GHG emissions during the product use stage, and
# oducts that incorporate highly energy-efficient technologies. We also calculate and
# ated during the product use stage for our flagship products.
#
# ogy Road Map (TRM) that serves as the foundation for setting and implementing
# le energy efficiency of each product category. Additionally, we are committed to
# by establishing our own energy efficiency targets and detailed strategies, while
# egulations such as the EU's Ecodesign Regulation.”
#
# arbon emissions intensity during the product use stage by 20% by 2030, compared
# sales models in our seven major product categories (TVs, refrigerators, washing
# r conditioners, system air conditioners, and monitors). Given that as of 2021, these
# »s accounted for approximately 90% of the carbon emissions generated by all our
# age, we are actively promoting substantial carbon emission reductions through our
#
# rbon emissions and improve energy efficiency.
#
# tal and energy effi
#
# icy regulations that manufacturers, distributors, and sellers must comply with from the
#
# nal wash volume control algorithm utilizing TurboWash 360 technology achieving a
#
# of approximately 40% for new washing machines sold in the European market
#
# 100 cycles).
#
# in monthly power consumption” by switching the refrigerant used (R401a ® R32) and
# the 2023 stand air conditioner in the Korean market.
#
# er with 6 Motion drying technology achieving a 35.8% reduction in power consumption
# r in the Korean market as of the 2023 model.
#
# arison for 2022 and 2023 models (sales-weighted average)
#
# Power Air Power Dryer Power
# iption conditioner consumption (RD2IES, consumption
#
# (All air conditioning 3.7% V Eh) 35.8%)
#
# y
# CNY models, 2023 model)
#
# Social Governance ESG Data AY
# Annual GHG Emissions during the Product Use Stage
# Year 2021 2022
# Reduction ratio compared to 2020 6.6% 13.1%
#
# Reducing GHG Emissions during the Product Distribution Stage
# To reduce carbon emissions during the the product distribution stage, we are c
#
# company LX Pantos to reduce their GHG emissions.
#
# Measurement, Reporting and Verification of GHG Emissions
#
# As a company regulated under Article 27 of the Framework Act on Carbon Neu
# Coping with the Climate Crisis, LG Electronics submits emission statements to t
# related information after third-party verification of GHG emissions and energy co
# Article 27 (8) of the Act. We have established a greenhouse gas inventory for ot
#
# disclose our GHG emissions annually.
#
# Introducing Carbon Accounting and Carbon Pricing
#
# LG Electronics analyzes its carbon credit allocations and actual emissions on a
#
# emission liabilities in the consolidated statement of financial position when our e!
#
# amounts. We also set an internal carbon price to identify business opportu
# energy savings and GHG reduction activities. This metric, which quantifies the value
#
# measures the financial impact of the environmental burden incurred by LG Elec
#
# rational investment decisions for reducing GHG emissions.
#  cs Sustainability Report
#
# newable Energy (2050)
#
# Renewable Energy 100) in June 2023 with commitment to a gradual transition to
# 50. In accordance with our mid- to long-term plan to convert to 100% renewable
# ase our use of renewable energy, considering the current status of our Korean and
# elevant laws and regulations. Aiming to achieve 60% renewable energy by 2030,
# 050, we are exploring various options for purchasing renewable power, including a
# tribute Certificates) purchasing, and third-party PPAs.”
#
# N solar power generation capacity through self-generation and PPA” contracts,
#
# MWh of electricity annually.
#
# ed 2.3 MW of renewable power through Korea's first off-grid PPA
# roduced 1.4MW of solar power
#
# Ig approximately 44,000 MWh of renewable energy annually through wind and
# promoted solar power generation of 11 MW (16,500 MWh/year) through an equity
# ction subsidiary.
#
# yntract between a power producer and a power consumer to purchase electricity for a fixed period of time.
#
# Status
# al business sites purchased and generated 126,410 MWh of renewable energy
# ropower), EACs purchasing (wind, hydropower, biomass), and self-generation, which
#
# nal electricity consumption.
#
# of Global Business Sites
#
# Environmental Social Governance ESG Data At
#
# New PPA Contract for Overseas Production Sites in 2023
#
# Classification Production Sites Generation Capacity(MW) A
# Nanjing PN 68
#
# China Tianjin 10.0
#
# Solar Taizhou 70 -
# Thailand 3.2 -
#
# Vietnam 75 -
#
# Wind China Qinhuangdao _
# Total 445 -
#
# Energy Consumption Management System at Global Production Site:
# LG Electronics operates a global energy consumption management system to moi
# and cost of each type of energy used in its Korean and overseas business sites or
# utilized to calculate Scope 1 and 2 GHG emissions, and serves as a foundation f
#
# energy-efficient production facilities within our subsidiaries.
#
# Energy Management System (ISO 50001) Certification
#
# LG Electronics is continuously expanding its acquisition of ISO 50001 certification t
# improve efficiency, and systematize management at both Korean and overse
# continuous and standardized management, we have established the 'Energy and (
# Standards and Rules’ and will enhance our energy management by regularly inspe
#
# management systems at our business sites.
#
# vit 2021 2022 2023 Number of ISO 50001 Certified Production
# - 36,786 56,110 (Ascii)
# 64,588 58,961 65,159 Classification Acquisition / Renewal Total
# vn 513 4,336 5141 Korea 5 5
# 69,701 100,083 126,410 Overseas 14 25*
# 6 46 82 101 * Excluding new subsidiaries (2 in the US, 1 in Mexico) that have not started mass production
#
#  cs Sustainability Report
#
# : Change Policy
# 1ange Organizations and Initiatives
#
# ies related to climate change, such as the Paris Agreement” and the IPCC,”
# vith Korean and international climate change-related specialized institutions,
# to introduce and implement climate change policies. We continuously review
# I
#
# jes of participating organizations to ensure they align with LG Electronics’
# nd if discrepancies are identified, we actively engage with the organizations
# egularly assess the stances and activities of participating organizations and
# ant discrepancies persist. Through this efforts, we aim to establish an effective
# dressing climate change issues to achieve shared goals.
#
# pted on December 12, 2015 by 195 countries at the 21st Conference of the Parties to the United Nations
# ange, held from November 30 through December 11, 2015 in Paris, France
# nate Change
#
# je Initiatives
#
# Implementation
# 1 the ‘K-EV100” campaign led by the Ministry of Environment since April 2021
#
# ion, we plan to gradually increase the proportion environment-friendly motor vehicles”
#
# or leased vehicles aiming for a 100% transition to environment-friendly motor vehicles
#
# an (K-EV100): A campaign organized by the Ministry of Environment that declares and phases in a
# their owned or leased vehicles to 100% zero-emission vehicles by 2030
# Vehicles that meet zero- or low-emission standards and are energy efficient
#
# Environmental Social Governance ESG Data At
#
# Resource Circulation
#
# E-Waste Collection and Disposal
# E-Waste Collection and Compliance to Recycling/Regulations
#
# LG Electronics supports the concept of Individual Producer Responsibility (IPR) whi
# of producers in taking back e-waste and is enhancing the reusability and recyclab
# reducing the environmental impact during the disposal process. Notably, proactive
# and collects e-waste in compliance with the regulations in countries where we op
# management, including global e-waste collection and disposal policies and reg
#
# systems, is publicly available on our website.
#
# Global E-Waste Local (
#
# Cumulative E-Was
# Performance
# (Since 2006, Unit: 10,00¢
#
# E-Waste Recovery/Disposal Results by Region
#
# Region Unit 2021 2022 ©2023
# Europe” 155,598 151,920 126,739
# Korea 124764 116,491 131,506
# North America” 26,576 23125 30,979 -
# 352 402
# Asia? ton 112705 148,041 134,061
# Russia (CIS) 22,602 23677 10,291
# Garttellqns Semtin 3008 3694 51,530
# America
# Africa? - 1542 7,298
#
# 1) Estimated figures are used for some European countries
#
# 2) North America: U.S,, Canada
#
# 3) Asia‘ Japan, India, Australia, Singapore
#
# 4) Central and South America: Brazil, Colombia, Mexico, Peru, Panama
# 5) Africa: Republic of South Africa
#
# * As countries in some re
# reporting recovery, if d
# of publication of the re
# the previous year's recc
# of neighboring countri
# slight adjustments whe
#  cs Sustainability Report
#
# ervice (Korea) — How It Works
#
# cipating in the Producer Responsibility Recycling System since its implementation
# ree-of-charge take-back service for discarded electronic products. We strive to
# -waste and mitigate the environmental impact of landfills and incineration in the
# recyclability assessments from the development to ensure our products are more
#
# Large Appliances
#
# E-waste collected by
# stallation specialists vi
# customer's home
#
# Disassemble and
#
# Recycle as
#
# sort out e-waste material
# Small Appliances
#
# --waste collected through a
# designated recovery box at
# LG Electronics service
# centers
#
# Recycling Center)
#
# (CRC) was established in the Gyeongnam region in 2001 to recycle e-waste and
# - recycles resources while ensuring the environmentally conscious recycling or
#
# ed in waste appliances.
#
# Social Governance ESG Data At
#
# Collection of Small and Medium-sized Electronic Products
#
# Since July 2022, LG Electronics has been collecting small and medium-sized ele
# of brand through its e-waste collection boxes at all LG Best Shop stores, base
# Environment Corporation, E-Cycle Governance, and home appliance manufacturer
# the collection rate of small and medium-sized e-waste. This has laid the foundatior
# for small and medium-sized e-waste, which typically have a low collection rate.
#
# Collection and Recycling of Small Secondary Batteries
# In May 2024, LG Electro
# for the collection and recycling of small secondary batteries, pledging to cooperate
#
# s signed an MOU with the Korea Environment Corpor:
#
# economy, including the establishment and operation of a resource circulation syste
# also encourage customers to participate in the resource circulation by collecting
# vacuum cleaner and offering discounts on new batteries through the “BatteReturn
# been held twice a year since 2022 and is currently in its Sth cycle, with a total of 6:
# collecting about 51.2 tons of waste batteries.
#
# [A7| AAPA As DRA] 274A
#
# ~ AY
#
# LG Electronics CEO participating in e-waste
# collection batteries
#
# MOU to collect and recycle small secondary Bat
#
# E-Waste Collection and Treatment Service (Overseas)
#
# LG Electronics collects waste electronic products in accordance with the WEEE (V
# Equipment) regulations and the requirements of each country, and as of the |
# electronic product collection and treatment services in 89 locations in 54 co
# recycling policies in new regions, we introduce services after conducting a regulatoi
# governments and industry organizations in the target countries.
#  cs Sustainability Report
#
# fficiency
# Structure and Material
#
# elopment stage, LG Electronics focuses on improving materials and structures to
# n addition, we have established a collaborative system with recycling companies to
# ing and sorting. In 2023, we modified the material of our TV model (S50UQ8300ENF),
# tion in product weight (approx. 2.8 kg), a 7% reduction in product volume (0.013
# ‘kaging material weight (0.11 kg) compared to the previous model (SOLF6500). We
# f our products, reducing the number of fastening parts which measures ease of
# 0 26. To reduce waste and improve resource efficiency, we will enhance our efforts
#
# scious products and improve the design of existing products.
#
# 1d material for a TV model (model name: SOUQ8300ENF)
#
# Structure Change
#
# Number of
# packaging material fastening parts
#
# 3% reduction 21% reduction
#
# (0.11kg) (from 33 to 26)
#
# Product volume Weight of
#
# 7% reduction
#
# (0.013m*)
#
# Environmental Social Governance ESG Data At
#
# Use of Recycled Plastic
#
# LG Electronics recycles plastic from collected waste electronics and uses it to mal
# the goal of using 600,000 tons of recycled plastic from 2021 to 2030; by 2023, we
#
# Classification Unit 2021 2022
# Amount of recycled plastic 26,545 32;
# A ton
# Amount of raw materials used 12533 16,
# for recycled plastic
# Cumulative amount of recycled 10,000 27
#
# plastic tons
#
# E-Cycle Certification Status
#
# LG Electronics has obtained E-Cycle Excellent Product Certification for six f
# refrigerator (45 models), two air purifiers (16 models), and one vacuum cleaner (1
# Product Certification is a certification system that is awarded to excellent products
# (sponsored by the Ministry of Environment) by evaluating 12 criteria across five
# (material reduction, ease of decomposition, percentage of recycled plastic, etc.)
#
# LG OLED TVs, which recognized as a 2023 Product of the Year, are resource-efficier
# a backlight, which means they have fewer parts and a simpler structure than cor
# OLED evo uses environmentally conscious composite fiber materials and metal inst
# use of about 40% less plastic than an LCD TV of the same size. Manufacturing |
# 16,000 tons less plastic to manufacture OLED TVs compared to the same number
# from the production and transportation of plastic are projected to be reduced b
# Additionally, we use 30% recycled plastic for the back cover of our TVs, further cont
# LG OLED TVs have been recognized for their resource efficiency by leading Korear
# were recently awarded environmental product certifications for a fourth consecutiv
#
# non-profit certification institution in the UK, and Société Générale de Surveillance (
#
# second consecutive year by Intertek, the UK's non-profit certification organization.

# %%
combined_text = " ".join(extracted_text)
output_file_path = "/Users/jeremiahtay/DSA3101/LG_Sustainability Report.txt"

# Open the file in write mode and save the text
with open(output_file_path, "w", encoding="utf-8") as file:
    file.write(combined_text)

print(combined_text)

# %%
combined_text
# Out:
# 'LG Electronics Sustainability Report\n\nBETTER\n\nLIFE\n\nFOR ALL\n\nLife’s\nGood.\n cs Sustainability Report [overview Environmental Social Governance ESG Data AY\nts\n\nEnvironmental 12 ~~ Social 29 Governance 80 ESG Data 100 = Appendi:\n\n3 Environmental Management Policy 13 Human Rights 30 Corporate Governance 81 Sustainability Management Data 101 GRI Inde»\n\n4 Addressing Climate Change 15 Employee 44 — Jeong-Do Management 86 = Membership-Awards & Recognition 124 — SASB Ind\n\n8 Resource Circulation 18 Supply Chain 56 Compliance Management 88  SHEE-Quality Certification Status 125 UN SDGs\n\n10 Product Stewardship 23. Customer 66 — Risk Management 92 Materiality Assessment 126 ~—TCFD Ref\n\nBusiness Sites Operation 26 ~~ Local Community 75 Information Security 95 Stakeholder Communication 129 Greenhot\n\nStatemer\n\nIndepend\n\nits commitment to making changes that will help it to achieve sustainable growth and\ntablished and implemented goals and action plans to realize them. In the Sustainability\nits management approach (MA), goals, activities, progress, and performance on tasks and\nonment, society, and governance. These are linked to the material issues derived from the\nElectronics’ six ESG strategic tasks. LG Electronics will continue to transparently disclose\nctivities and performance through the publication of this report each year.\n\nindards\n\nstainability Report adheres to GRI Standards 2021, an international standard guideline,\ndards and frameworks set forth by the Sustainability Accounting Standards Board (SASB)\nrelated Financial Disclosures (TCFD). We also reported out progress in implementing The\nations Global Compact (UNGC) in four areas: human rights, labor, environment, and anti-\nst the four principles of inclusivity, materiality, responsiveness, and impact as outlined in\ny Principles Standard), which also outlines the obligation of companies to disclose their\nnagement.\n\nReporting Period\nThis report covers our activities from January 2023 through December 2023, and for some key\nthrough the first half of 2024. For quantitative performance, we provide three years of data fror\nperformance trends,\n\nScope of Report\n\nThe scope of this report covers the headquarters, production sites in Korea and overseas,\nby LG Electronics. Financial information is presented on a consolidated financial statement t\nInternational Financial Reporting Standards (K-IFRS), and some financial information pr\nstatement basis is presented in the footnotes. All financial information in USD has been calc\nexchange rate. Where there are limitations in data collection or changes to the calculati\nreporting scope and the reason for the change in the footnotes.\n\nThird Party Assurance\n\nTo ensure the accuracy, objectivity and reliability of the report preparation process and\nElectronics commissioned an independent assurance organization (Korea Managemer\nassurance in accordance with international assurance standards. The results of the third-\nin detail on page 149 of this report. The financial information in this report has beer\n\nof greenhouse gas emissions and energy usage was conducted in accordance with tt\n\nAdministrative Guideline for the Greenhouse Gas Target Management System,\n cs Sustainability Report\n\ne CEO\n\nSocial Governance\n\nESG Data A\n\nmpany, LG Electronics will promote sustainable management to ensure a ‘Better Life for All’\n\nakeholders,\n\nplagued the global market with prolonged\n2S, leading to a slowdown in consumption.\nscarbonization and digital transformation\nand customers are pursuing engagement-\nS experience consumption. To proactively\n; in the market and with customers,\nsion last year to transform from a ‘Global\nd\' to a ‘Smart Life Solution Company’ that\n\nse experiences of customers.\n2 appliances to a Smart Life Solution\n\niture, LG Electronics is focusing on the\nn, digitalization and electrification. During\nvew touch points and pursue changes to\n3C 2S\' (Connectivity, ...
